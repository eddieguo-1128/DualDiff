# %% [markdown]
# # SSVEP Character Classification with DiffE

# %%
#!pip install ema-pytorch

# %%
import os
import sys

#!git clone https://github.com/diffe2023/Diff-E.git
#sys.path.append('/content/Diff-E')
sys.path.append(r'C:\Users\shaoy\Diff-E')
#sys.path.append(r'C:\Users\shaoy\arl-eegmodels')

# %%
import math
from einops import reduce
from functools import partial
import random
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader
from ema_pytorch import EMA
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score,
    top_k_accuracy_score,
)

# %%
# Uncomment this if you want to use Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# #load and preprocess data

# %% [markdown]
# We retain the original SSVEP data preprocessing procedures, including:
#
#     Chebyshev bandpass filtering (6–90 Hz),
#     Noise removal and segmentation using a sliding window of 250 samples, followed by manual channel-wise standardization (subtracting the mean and dividing by the standard deviation),
#     Downsampling from 1000 Hz to 250 Hz.
#
# In this work, we directly load the preprocessed character-level files "S#_chars.npy" for subsequent training.
#
# Unlike the original setup where models are trained separately for each subject, we train a single model jointly across all subjects by concatenating all subjects' data.

# %%
# Define a function to perform z-score normalization on the data
def zscore_norm(data):
    # Calculate the mean and standard deviation for each channel in each batch
    mean = torch.mean(data, dim=(1, 2))
    std = torch.std(data, dim=(1, 2))

    # Subtract the mean from each channel in each batch and divide by the standard deviation
    norm_data = (data - mean[:, None, None]) / std[:, None, None]

    return norm_data


# Define a function to perform min-max normalization on the data
def minmax_norm(data):
    # Calculate the minimum and maximum values for each channel and sequence in the batch
    min_vals = torch.min(data, dim=-1)[0]
    max_vals = torch.max(data, dim=-1)[0]

    # Scale the data to the range [0, 1]
    norm_data = (data - min_vals.unsqueeze(-1)) / (
        max_vals.unsqueeze(-1) - min_vals.unsqueeze(-1)
    )

    return norm_data

# %%
class EEGDataset(Dataset):
    "Characterizes a dataset for PyTorch"

    def __init__(self, X, Y, transform=None):
        "Initialization"
        self.X = X
        self.Y = Y
        self.transform = transform

    def __len__(self):
        "Denotes the total number of samples"
        return len(self.X)

    def __getitem__(self, index):
        "Generates one sample of data"
        # Load data and get label
        x = self.X[index]
        y = self.Y[index]
        if self.transform:
            x = self.transform(x)
        return x.squeeze(), y

# %%
#define spectrogram
#time_frames = 1 + (signal_length - n_fft) // hop_length
#1 + (250 - 64) // 16 = 12 time frame
spectrogram_transform = T.Spectrogram(
    n_fft=64,       # width of window. original: 128, but then the time_frame will become 0 when downsampling
    win_length=None, # default: n_fft
    hop_length=16, # default: win_length // 2
    normalized=True
)

# %%
def load_data_by_session(root_dir, subject_id, session_idx_list):
    data = np.load(os.path.join(root_dir, f"S{subject_id}_chars.npy"))  # [26, 6, 64, 250]
    data = data[:, session_idx_list]  # [26, len(session), 64, 250]
    X = data.reshape(-1, 64, 250)  # [samples, 64, 250]
    Y = np.repeat(np.arange(26), len(session_idx_list))

    # transform to spectrogram
    X_spectrogram = []
    for sample in X:  # sample: [64, 250]
        spec_per_channel = []
        for ch in sample:
            ch_tensor = torch.tensor(ch, dtype=torch.float32)
            spec = spectrogram_transform(ch_tensor)  # [freq, time]
            spec_per_channel.append(spec)
        spec_tensor = torch.stack(spec_per_channel)  # [64, freq, time]
        X_spectrogram.append(spec_tensor)

    X_spectrogram = torch.stack(X_spectrogram)  # [samples, 64, freq, time]
    Y = torch.tensor(Y, dtype=torch.long)

    print("X shape after Spectrogram:", X_spectrogram.shape)  # [B, 64, freq≈33, time≈12]

    return X_spectrogram, Y


def load_split_dataset(root_dir, num_seen=25, seed=43, cache_dir='processed_by_session'):
    os.makedirs(cache_dir, exist_ok=True)
    random.seed(seed)

    all_subjects = list(range(1, 36))
    seen_subjects = random.sample(all_subjects, num_seen)#25 seen
    unseen_subjects = [sid for sid in all_subjects if sid not in seen_subjects]#10 unseen

    split_cfg = {
        "train":  [(sid, [0, 1, 2, 3]) for sid in seen_subjects],
        "val":    [(sid, [4]) for sid in seen_subjects],
        "test1":  [(sid, [5]) for sid in seen_subjects],
        "test2":  [(sid, [0, 1, 2, 3, 4, 5]) for sid in unseen_subjects]
    }

    print(f"[Split] Seen subjects (train/val/test1): {seen_subjects}")
    print(f"[Split] Unseen subjects (test2): {unseen_subjects}")

    loaders = {}
    for split, sid_sess in split_cfg.items():
        X_all, Y_all = [], []
        for sid, sess in sid_sess:
            sess_str = ''.join(str(s) for s in sess)
            
            cache_X_path = os.path.join(cache_dir, f"S{sid:02d}_sess_{sess_str}_X.npy")
            cache_Y_path = os.path.join(cache_dir, f"S{sid:02d}_sess_{sess_str}_Y.npy")

            if os.path.exists(cache_X_path) and os.path.exists(cache_Y_path):
                X = torch.tensor(np.load(cache_X_path))
                Y = torch.tensor(np.load(cache_Y_path))
                print(f"[Cache] Loaded S{sid:02d} sessions {sess_str} from cache")
            else:
                X, Y = load_data_by_session(root_dir, sid, sess)
                np.save(cache_X_path, X.cpu().numpy())
                np.save(cache_Y_path, Y.cpu().numpy())
                print(f"[Cache] Saved S{sid:02d} sessions {sess_str} to cache")
                
            X_all.append(X)
            Y_all.append(Y)
        X_all = torch.cat(X_all, dim=0)
        Y_all = torch.cat(Y_all, dim=0)
        dataset = EEGDataset(X_all, Y_all)
        loaders[split] = DataLoader(dataset, batch_size=32, shuffle=(split == "train"))
    return loaders

# %%
seed = 44
random.seed(seed)
torch.manual_seed(seed)
print("Random Seed: ", seed)
# Out:
# Random Seed:  44

# %%
#subject_chars_dir = '/content/drive/MyDrive/project/dataset/ssvep/chars' # Where to store all character data
subject_chars_dir = r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\chars' # Where to store all character data
subject_ids = list(range(1, 36)) #35 samples + 1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 256
batch_size2 = 256
seed = 44
shuffle = True

# load all subjects' data
loaders = load_split_dataset(subject_chars_dir, num_seen=20, seed=seed)
train_loader = loaders["train"]
val_loader   = loaders["val"]
test1_loader = loaders["test1"]
test2_loader = loaders["test2"]
# Out:
# [Split] Seen subjects (train/val/test1): [27, 34, 8, 12, 13, 33, 10, 1, 30, 4, 19, 28, 26, 6, 17, 29, 31, 25, 11, 32]
# [Split] Unseen subjects (test2): [2, 3, 5, 7, 9, 14, 15, 16, 18, 20, 21, 22, 23, 24, 35]
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S27 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S34 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S08 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S12 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S13 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S33 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S10 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S01 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S30 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S04 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S19 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S28 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S26 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S06 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S17 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S29 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S31 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S25 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S11 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([104, 64, 33, 16])
# [Cache] Saved S32 sessions 0123 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S27 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S34 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S08 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S12 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S13 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S33 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S10 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S01 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S30 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S04 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S19 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S28 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S26 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S06 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S17 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S29 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S31 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S25 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S11 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S32 sessions 4 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S27 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S34 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S08 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S12 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S13 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S33 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S10 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S01 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S30 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S04 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S19 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S28 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S26 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S06 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S17 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S29 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S31 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S25 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S11 sessions 5 to cache
# X shape after Spectrogram: torch.Size([26, 64, 33, 16])
# [Cache] Saved S32 sessions 5 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S02 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S03 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S05 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S07 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S09 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S14 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S15 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S16 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S18 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S20 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S21 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S22 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S23 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S24 sessions 012345 to cache
# X shape after Spectrogram: torch.Size([156, 64, 33, 16])
# [Cache] Saved S35 sessions 012345 to cache

# %%
print(len(train_loader.dataset), len(val_loader.dataset), len(test1_loader.dataset), len(test2_loader.dataset))

for x, y in train_loader:
    print("X shape:", x.shape)
    print("Y shape:", y.shape)
    break  # the first batch
# Out:
# 2080 520 520 2340
# X shape: torch.Size([32, 64, 33, 16])
# Y shape: torch.Size([32])

# %% [markdown]
# train: 20 seen subjects × 4 session × 26 = 2080
#
# val: 20 × 1 × 26 = 520
#
# test1: 20 × 1 × 26 = 520
#
# test2: 15 unseen × 6 session × 26 = 2340

# %% [markdown]
# random choose 25 subjects as seen, the rest 10 as unseen
#
# | Group Name | Subject Range   | Sessions Used         | Purpose                                  |
# |------------|------------------|------------------------|-------------------------------------------|
# | train      | seen subjects    | sessions [0, 1, 2, 3]  | Training (4 sessions)                     |
# | val        | seen subjects    | session [4]            | Validation                                |
# | test1      | seen subjects    | session [5]            | Test on unseen session of seen subjects  |
# | test2      | unseen subjects  | sessions [0–5] (all)   | Test on unseen subjects                   |

# %% [markdown]
# #model

# %% [markdown]
# The overall model follows the original GitHub implementation, with a few necessary adjustments to align tensor time dimensions. Specifically, we aligned the temporal dimensions between up2 + temb and down1, up3 and x, and x_hat and x. These changes are clearly marked with comments in the code.

# %% [markdown]
# ```
# #transform from 1D to 2D:
# current input: [batch_size, channels, freq_bins, time_frames]
# original input: [batch_size, channels, time]
#
# Replace all instances of Conv1d, MaxPool1d, and AvgPool1d with Conv2d, MaxPool2d, and AvgPool2d, respectively.
# Also modify the AvgPool1d and MaxPool1d used in the Encoder and Decoder.
# ```

# %%
def safe_cat_and_add(a, b, temb):
    """
    Interpolates `a` to align with `b`, then adds `temb` (broadcasted) to `a`, and finally concatenates with `b`.

    Inputs:
        a: decoder upsampled output [B, C, F, T]
        b: encoder skip connection [B, C, F, T]
        temb: time embedding output, supports [B, C], [B, C, 1], etc., auto-adapts shape

    Output:
        Concatenated result [B, C_concat, F, T]
    """
    # Align spatial dimensions (freq, time)
    if a.shape[2:] != b.shape[2:]:
        a = F.interpolate(a, size=b.shape[2:], mode='nearest')

    # Normalize temb to shape [B, C, 1, 1]
    while temb.dim() < 4:
        temb = temb.unsqueeze(-1)
    if temb.dim() > 4:
        temb = temb.squeeze(-1)

    # Broadcast to shape [B, C, F, T]
    temb = temb.expand(-1, -1, a.shape[2], a.shape[3])

    # Element-wise addition and concatenation
    return torch.cat([a + temb, b], dim=1)

def safe_align_2d(x1, x2):
    """
    Align two 4D tensors in frequency and time dimensions (2D spatial alignment).

    Inputs:
        x1, x2: [B, C, F, T]

    Returns:
        Aligned x1, x2
    """
    target_freq = min(x1.shape[2], x2.shape[2])
    target_time = min(x1.shape[3], x2.shape[3])
    x1 = F.interpolate(x1, size=(target_freq, target_time), mode='nearest')
    x2 = F.interpolate(x2, size=(target_freq, target_time), mode='nearest')
    return x1, x2

# %%
#define diffE model
def get_padding(kernel_size, dilation=1):
    return int((kernel_size * dilation - dilation) / 2)


# Swish activation function
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)


class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, x):
        device = x.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = x[:, None] * emb[None, :]
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)
        return emb


class WeightStandardizedConv2d(nn.Conv2d):
    def forward(self, x):
        eps = 1e-5 if x.dtype == torch.float32 else 1e-3
        weight = self.weight
        mean = weight.mean(dim=(1,2,3), keepdim=True)
        var = weight.var(dim=(1,2,3), keepdim=True, unbiased=False)
        weight = (weight - mean) / (var + eps).sqrt()
        return F.conv2d(x, weight, self.bias, self.stride, self.padding, self.dilation, self.groups)


class ResidualConvBlock(nn.Module):
    def __init__(self, inc, outc, kernel_size, stride=1, gn=8):
        super().__init__()
        self.same_channels = inc == outc
        padding = kernel_size // 2
        self.conv = nn.Sequential(
            WeightStandardizedConv2d(inc, outc, kernel_size, stride, padding),
            nn.GroupNorm(gn, outc),
            nn.PReLU(),
        )

    def forward(self, x):
        x1 = self.conv(x)
        return (x + x1) / 2 if self.same_channels else x1


class UnetDown(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, gn=8, factor=2):
        super().__init__()
        self.pool = nn.MaxPool2d(kernel_size=factor)
        self.layer = ResidualConvBlock(in_channels, out_channels, kernel_size, gn=gn)

    def forward(self, x):
        x = self.layer(x)
        return self.pool(x)


class UnetUp(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, gn=8, factor=2):
        super().__init__()
        self.upsample = nn.Upsample(scale_factor=factor, mode='nearest')
        self.layer = ResidualConvBlock(in_channels, out_channels, kernel_size, gn=gn)

    def forward(self, x):
        return self.layer(self.upsample(x))


class EmbedFC(nn.Module):
    def __init__(self, input_dim, emb_dim):
        super(EmbedFC, self).__init__()
        """
        generic one layer FC NN for embedding things
        """
        self.input_dim = input_dim
        layers = [
            nn.Linear(input_dim, emb_dim),
            nn.PReLU(),
            nn.Linear(emb_dim, emb_dim),
        ]
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(-1, self.input_dim)
        return self.model(x)


class ConditionalUNet(nn.Module):
    def __init__(self, in_channels, n_feat=256):
        super(ConditionalUNet, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat

        self.d1_out = n_feat * 1
        self.d2_out = n_feat * 2
        self.d3_out = n_feat * 3
        self.d4_out = n_feat * 4

        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = in_channels

        self.sin_emb = SinusoidalPosEmb(n_feat)
        # self.timeembed1 = EmbedFC(n_feat, self.u1_out)
        # self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        # self.timeembed3 = EmbedFC(n_feat, self.u3_out)

        self.down1 = UnetDown(in_channels, self.d1_out, 1, gn=8, factor=2)
        self.down2 = UnetDown(self.d1_out, self.d2_out, 1, gn=8, factor=2)
        self.down3 = UnetDown(self.d2_out, self.d3_out, 1, gn=8, factor=2)

        self.up2 = UnetUp(self.d3_out, self.u2_out, 1, gn=8, factor=2)
        self.up3 = UnetUp(self.u2_out + self.d2_out, self.u3_out, 1, gn=8, factor=2)
        self.up4 = UnetUp(self.u3_out + self.d1_out, self.u4_out, 1, gn=8, factor=2)
        self.out = nn.Conv2d(self.u4_out + in_channels, in_channels, kernel_size=1)

    def forward(self, x, t):
        down1 = self.down1(x)  # 2000 -> 1000
        down2 = self.down2(down1)  # 1000 -> 500
        down3 = self.down3(down2)  # 500 -> 250

        temb = self.sin_emb(t).view(-1, self.n_feat, 1)  # [b, n_feat, 1]

        up1 = self.up2(down3)  # 250 -> 500
        #up2 = self.up3(torch.cat([up1 + temb, down2], 1))  # 500 -> 1000
        up2 = self.up3(safe_cat_and_add(up1, down2, temb))

        #up3 = self.up4(torch.cat([up2 + temb, down1], 1))  # 1000 -> 2000
        up3 = self.up4(safe_cat_and_add(up2, down1, temb))

        # Align the temporal dimension of up3 and x
        if up3.shape[-1] != x.shape[-1]:
            target_len = min(up3.shape[-1], x.shape[-1])
            up3 = F.interpolate(up3, size=target_len)
            x = F.interpolate(x, size=target_len)

        #out = self.out(torch.cat([up3, x], 1))  # 2000 -> 2000
        if x.shape[2:] != up3.shape[2:]:
            x = F.interpolate(x, size=up3.shape[2:], mode='nearest')

        out = self.out(torch.cat([up3, x], 1))

        down = (down1, down2, down3)
        up = (up1, up2, up3)
        return out, down, up


class Encoder(nn.Module):
    def __init__(self, in_channels, dim=512):
        super(Encoder, self).__init__()

        self.in_channels = in_channels
        self.e1_out = dim
        self.e2_out = dim
        self.e3_out = dim

        self.down1 = UnetDown(in_channels, self.e1_out, 1, gn=8, factor=2)
        self.down2 = UnetDown(self.e1_out, self.e2_out, 1, gn=8, factor=2)
        self.down3 = UnetDown(self.e2_out, self.e3_out, 1, gn=8, factor=2)

        self.avg_pooling = nn.AdaptiveAvgPool2d((1,1))
        self.max_pooling = nn.AdaptiveMaxPool2d((1,1))
        self.act = nn.Tanh()

    def forward(self, x0):
        # Down sampling
        dn1 = self.down1(x0)  # 2048 -> 1024
        dn2 = self.down2(dn1)  # 1024 -> 512
        dn3 = self.down3(dn2)  # 512 -> 256
        z = self.avg_pooling(dn3).view(-1, self.e3_out)  # [b, features]
        down = (dn1, dn2, dn3)
        out = (down, z)
        return out


class Decoder(nn.Module):
    def __init__(self, in_channels, n_feat=256, encoder_dim=512, n_classes=13):
        super(Decoder, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat
        self.n_classes = n_classes
        self.e1_out = encoder_dim
        self.e2_out = encoder_dim
        self.e3_out = encoder_dim
        self.d1_out = n_feat
        self.d2_out = n_feat * 2
        self.d3_out = n_feat * 3
        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = in_channels

        # self.sin_emb = SinusoidalPosEmb(n_feat)
        # self.timeembed1 = EmbedFC(n_feat, self.e3_out)
        # self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        # self.timeembed3 = EmbedFC(n_feat, self.u3_out)
        # self.contextembed1 = EmbedFC(self.e3_out, self.e3_out)
        # self.contextembed2 = EmbedFC(self.e3_out, self.u2_out)
        # self.contextembed3 = EmbedFC(self.e3_out, self.u3_out)

        # Unet up sampling
        self.up1 = UnetUp(self.d3_out + self.e3_out, self.u2_out, 1, gn=8, factor=2)
        self.up2 = UnetUp(self.d2_out + self.u2_out, self.u3_out, 1, gn=8, factor=2)
        self.up3 = nn.Sequential(
            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(self.d1_out + self.u3_out + in_channels * 2, in_channels, kernel_size=1),
        )

        # self.out = nn.Conv1d(self.u4_out+in_channels, in_channels, 1)
        self.pool = nn.AvgPool2d(kernel_size=2)

    def forward(self, x0, encoder_out, diffusion_out):
        # Encoder output
        down, z = encoder_out
        dn1, dn2, dn3 = down

        # DDPM output
        x_hat, down_ddpm, up, t = diffusion_out
        dn11, dn22, dn33 = down_ddpm

        # embed context, time step
        # temb = self.sin_emb(t).view(-1, self.n_feat, 1) # [b, n_feat, 1]
        # temb1 = self.timeembed1(temb).view(-1, self.e3_out, 1) # [b, features]
        # temb2 = self.timeembed2(temb).view(-1, self.u2_out, 1) # [b, features]
        # temb3 = self.timeembed3(temb).view(-1, self.u3_out, 1) # [b, features]
        # ct2 = self.contextembed2(z).view(-1, self.u2_out, 1) # [b, n_feat, 1]
        # ct3 = self.contextembed3(z).view(-1, self.u3_out, 1) # [b, n_feat, 1]

        # Up sampling
        up1 = self.up1(torch.cat([dn3, dn33.detach()], 1))
        up2 = self.up2(torch.cat([up1, dn22.detach()], 1))
        out = self.up3(
            torch.cat([self.pool(x0), self.pool(x_hat.detach()), up2, dn11.detach()], 1)
        )
        return out


class DiffE(nn.Module):
    def __init__(self, encoder, decoder, fc):
        super(DiffE, self).__init__()

        self.encoder = encoder
        self.decoder = decoder
        self.fc = fc

    def forward(self, x0, ddpm_out):
        encoder_out = self.encoder(x0)
        decoder_out = self.decoder(x0, encoder_out, ddpm_out)
        fc_out = self.fc(encoder_out[1])
        return decoder_out, fc_out


class DecoderNoDiff(nn.Module):
    def __init__(self, in_channels, n_feat=256, encoder_dim=512, n_classes=13):
        super(DecoderNoDiff, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat
        self.n_classes = n_classes
        self.e1_out = encoder_dim
        self.e2_out = encoder_dim
        self.e3_out = encoder_dim
        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = n_feat

        self.sin_emb = SinusoidalPosEmb(n_feat)
        self.timeembed1 = EmbedFC(n_feat, self.e3_out)
        self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        self.timeembed3 = EmbedFC(n_feat, self.u3_out)
        self.contextembed1 = EmbedFC(self.e3_out, self.e3_out)
        self.contextembed2 = EmbedFC(self.e3_out, self.u2_out)
        self.contextembed3 = EmbedFC(self.e3_out, self.u3_out)

        # Unet up sampling
        self.up2 = UnetUp(self.e3_out, self.u2_out, 1, gn=8, factor=2)
        self.up3 = UnetUp(self.e2_out + self.u2_out, self.u3_out, 1, gn=8, factor=2)
        # self.up4 = UnetUp(self.e1_out+self.u3_out, self.u4_out, 1, 1, gn=in_channels, factor=2, is_res=True)
        self.up4 = nn.Sequential(
            nn.Upsample(scale_factor=(2, 1), mode="nearest"),  # freq
            nn.Conv2d(self.u3_out + self.e1_out + in_channels, in_channels, kernel_size=1)
        )

        self.out = nn.Conv2d(self.u4_out, in_channels, kernel_size=1)
        self.pool = nn.AvgPool2d(kernel_size=(2, 1))  #  freq

    def forward(self, x0, x_hat, encoder_out, t):
        down, z = encoder_out
        dn1, dn2, dn3 = down
        tembd = self.sin_emb(t).view(-1, self.n_feat, 1)  # [b, n_feat, 1]
        tembd1 = self.timeembed1(self.sin_emb(t)).view(
            -1, self.e3_out, 1
        )  # [b, n_feat, 1]
        tembd2 = self.timeembed2(self.sin_emb(t)).view(
            -1, self.u2_out, 1
        )  # [b, n_feat, 1]
        tembd3 = self.timeembed3(self.sin_emb(t)).view(
            -1, self.u3_out, 1
        )  # [b, n_feat, 1]

        # Up sampling
        ddpm_loss = F.l1_loss(x0, x_hat, reduction="none")

        up2 = self.up2(dn3)  # 256 -> 512
        up3 = self.up3(torch.cat([up2, dn2], 1))  # 512 -> 1024
        out = self.up4(
            torch.cat([self.pool(x0), self.pool(x_hat), up3, dn1], 1)
        )  # 1024 -> 2048
        # out = self.out(torch.cat([out, x_hat], 1)) # 2048 -> 2048
        # out = self.out(out)
        return out


class LinearClassifier(nn.Module):
    def __init__(self, in_dim, latent_dim, emb_dim):
        super().__init__()
        self.linear_out = nn.Sequential(
            nn.Linear(in_features=in_dim, out_features=latent_dim),
            nn.GroupNorm(4, latent_dim),
            nn.PReLU(),
            nn.Linear(in_features=latent_dim, out_features=latent_dim),
            nn.GroupNorm(4, latent_dim),
            nn.PReLU(),
            nn.Linear(in_features=latent_dim, out_features=emb_dim),
        )

    def forward(self, x):
        x = self.linear_out(x)
        return x


def cosine_beta_schedule(timesteps, s=0.008):
    """
    cosine schedule
    as proposed in https://openreview.net/forum?id=-NEXDKk8gZ
    """
    steps = timesteps + 1
    t = torch.linspace(0, timesteps, steps, dtype=torch.float64) / timesteps
    alphas_cumprod = torch.cos((t + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)


def sigmoid_beta_schedule(timesteps, start=-3, end=3, tau=1, clamp_min=1e-5):
    """
    sigmoid schedule
    proposed in https://arxiv.org/abs/2212.11972 - Figure 8
    """
    steps = timesteps + 1
    t = torch.linspace(0, timesteps, steps, dtype=torch.float64) / timesteps
    v_start = torch.tensor(start / tau).sigmoid()
    v_end = torch.tensor(end / tau).sigmoid()
    alphas_cumprod = (-((t * (end - start) + start) / tau).sigmoid() + v_end) / (
        v_end - v_start
    )
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)


def ddpm_schedules(beta1, beta2, T):
    # assert beta1 < beta2 < 1.0, "beta1 and beta2 must be in (0, 1)"
    # beta_t = (beta2 - beta1) * torch.arange(0, T + 1, dtype=torch.float32) / T + beta1
    beta_t = cosine_beta_schedule(T, s=0.008).float()
    # beta_t = sigmoid_beta_schedule(T).float()

    alpha_t = 1 - beta_t

    log_alpha_t = torch.log(alpha_t)
    alphabar_t = torch.cumsum(log_alpha_t, dim=0).exp()

    sqrtab = torch.sqrt(alphabar_t)

    sqrtmab = torch.sqrt(1 - alphabar_t)

    return {
        "sqrtab": sqrtab,  # \sqrt{\bar{\alpha_t}}
        "sqrtmab": sqrtmab,  # \sqrt{1-\bar{\alpha_t}}
    }


class DDPM(nn.Module):
    def __init__(self, nn_model, betas, n_T, device):
        super(DDPM, self).__init__()
        self.nn_model = nn_model.to(device)

        for k, v in ddpm_schedules(betas[0], betas[1], n_T).items():
            self.register_buffer(k, v)

        self.n_T = n_T
        self.device = device

    def forward(self, x):
        _ts = torch.randint(1, self.n_T, (x.shape[0],)).to(
            self.device
        )  # t ~ Uniform(0, n_T)
        noise = torch.randn_like(x)  # eps ~ N(0, 1)
        #x_t = self.sqrtab[_ts, None, None] * x + self.sqrtmab[_ts, None, None] * noise
        x_t = self.sqrtab[_ts].view(-1, 1, 1, 1) * x + self.sqrtmab[_ts].view(-1, 1, 1, 1) * noise
        times = _ts / self.n_T
        output, down, up = self.nn_model(x_t, times)
        return output, down, up, noise, times

# %%
for x, y in train_loader:
    channels = x.shape[1]
    timepoints = x.shape[2]
    print(f"Sample input shape: {x.shape}  → Channels: {channels}, Timepoints: {timepoints}")
    break

num_classes = 26
ddpm_dim = 128
encoder_dim = 256
fc_dim = 512
n_T = 1000

ddpm_model = ConditionalUNet(in_channels=channels, n_feat=ddpm_dim).to(device)
ddpm = DDPM(nn_model=ddpm_model, betas=(1e-6, 1e-2), n_T=n_T, device=device).to(device)

encoder = Encoder(in_channels=channels, dim=encoder_dim).to(device)
decoder = Decoder(in_channels=channels, n_feat=ddpm_dim, encoder_dim=encoder_dim).to(device)
# Out:
# Sample input shape: torch.Size([32, 64, 33, 16])  → Channels: 64, Timepoints: 33

# %%
fc = LinearClassifier(encoder_dim, fc_dim, emb_dim=num_classes).to(device)

diffe = DiffE(encoder, decoder, fc).to(device)

print(" Model initialized with:")
print(" - Input channels       :", channels)
print(" - Timepoints           :", timepoints)
print(" - ddpm total params    :", sum(p.numel() for p in ddpm.parameters()))
print(" - encoder total params :", sum(p.numel() for p in encoder.parameters()))
print(" - decoder total params :", sum(p.numel() for p in decoder.parameters()))
print(" - classifier params    :", sum(p.numel() for p in fc.parameters()))
print(" - total DiffE params   :", sum(p.numel() for p in diffe.parameters()))
# Out:
#  Model initialized with:
#  - Input channels       : 64
#  - Timepoints           : 33
#  - ddpm total params    : 265478
#  - encoder total params : 149763
#  - decoder total params : 156482
#  - classifier params    : 409628
#  - total DiffE params   : 715873

# %% [markdown]
# #train

# %%
# Criterion
criterion = nn.L1Loss()
criterion_class = nn.MSELoss()

# Define optimizer
base_lr, lr = 9e-5, 1.5e-3
optim1 = optim.RMSprop(ddpm.parameters(), lr=base_lr)
optim2 = optim.RMSprop(diffe.parameters(), lr=base_lr)

# EMAs
fc_ema = EMA(diffe.fc, beta=0.95, update_after_step=100, update_every=10,)

step_size = 150
scheduler1 = optim.lr_scheduler.CyclicLR(
    optimizer=optim1,
    base_lr=base_lr,
    max_lr=lr,
    step_size_up=step_size,
    mode="exp_range",
    cycle_momentum=False,
    gamma=0.9998,
)
scheduler2 = optim.lr_scheduler.CyclicLR(
    optimizer=optim2,
    base_lr=base_lr,
    max_lr=lr,
    step_size_up=step_size,
    mode="exp_range",
    cycle_momentum=False,
    gamma=0.9998,
)

# %%
# Evaluate function
def evaluate(encoder, fc, generator, device):
    labels = np.arange(0, 26)
    Y = []
    Y_hat = []
    for x, y in generator:
        x, y = x.to(device), y.type(torch.LongTensor).to(device)
        encoder_out = encoder(x)
        y_hat = fc(encoder_out[1])
        y_hat = F.softmax(y_hat, dim=1)

        Y.append(y.detach().cpu())
        Y_hat.append(y_hat.detach().cpu())

    # List of tensors to tensor to numpy
    Y = torch.cat(Y, dim=0).numpy()  # (N, )
    Y_hat = torch.cat(Y_hat, dim=0).numpy()  # (N, 13): has to sum to 1 for each row

    # Accuracy and Confusion Matrix
    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    f1 = f1_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    recall = recall_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    precision = precision_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels, zero_division=0)
    auc = roc_auc_score(Y, Y_hat, average="macro", multi_class="ovo", labels=labels)

    metrics = {
        "accuracy": accuracy,
        "f1": f1,
        "recall": recall,
        "precision": precision,
        "auc": auc,
    }
    # df_cm = pd.DataFrame(confusion_matrix(Y, Y_hat.argmax(axis=1)))
    return metrics

# %%
from torchsummary import summary

class EEGNet(nn.Module):
    def __init__(self, nb_classes, Chans=64, Samples=128, 
                 dropoutRate=0.25, kernLength=64, F1=8, D=2, F2=16):
        super(EEGNet, self).__init__()

        self.nb_classes = nb_classes
        self.Chans = Chans
        self.Samples = Samples
        self.F1 = F1
        self.D = D
        self.F2 = F2
        self.dropoutRate = dropoutRate

        # Block 1: Temporal Convolution
        self.conv1 = nn.Conv2d(1, F1, (1, kernLength), padding=(0, kernLength // 2), bias=False)
        self.batchnorm1 = nn.BatchNorm2d(F1)

        # Block 1: Depthwise Convolution (Spatial Filtering)
        self.depthwiseConv = nn.Conv2d(F1, F1*D, (Chans, 1), groups=F1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(F1*D)
        self.elu = nn.ELU()
        self.avgpool1 = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(dropoutRate)

        # Block 2: Separable Convolution
        self.separableConv = nn.Conv2d(F1*D, F2, (1, 16), padding=(0, 8), bias=False)
        self.batchnorm3 = nn.BatchNorm2d(F2)
        self.avgpool2 = nn.AvgPool2d((1, 8))

        # Classification Layer
        self.classify = nn.Linear(self._calc_out_features(), nb_classes)

    def _calc_out_features(self):
        # Helper to calculate output size after convolutions/pooling
        with torch.no_grad():
            x = torch.zeros(1, 1, self.Chans, self.Samples)
            x = self.conv1(x)
            x = self.batchnorm1(x)
            x = self.depthwiseConv(x)
            x = self.batchnorm2(x)
            x = self.elu(x)
            x = self.avgpool1(x)
            x = self.dropout(x)

            x = self.separableConv(x)
            x = self.batchnorm3(x)
            x = self.elu(x)
            x = self.avgpool2(x)
            x = self.dropout(x)

            return x.numel()

    def forward(self, x):
        # x shape: (batch_size, Chans, Samples)
        x = x.unsqueeze(1)  # shape: (batch_size, 1, Chans, Samples)

        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv(x)
        x = self.batchnorm2(x)
        x = self.elu(x)
        x = self.avgpool1(x)
        x = self.dropout(x)

        x = self.separableConv(x)
        x = self.batchnorm3(x)
        x = self.elu(x)
        x = self.avgpool2(x)
        x = self.dropout(x)

        x = x.reshape(x.size(0), -1)
        x = self.classify(x)

        return x


eegnet_model = EEGNet(nb_classes=num_classes, Chans=64, Samples=512, dropoutRate=0.5)

eegnet_model = eegnet_model.to(device)

optimizer_eeg = torch.optim.Adam(eegnet_model.parameters(), lr=0.001)
criterion_eeg = nn.CrossEntropyLoss()
scheduler_eeg = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_eeg, mode='min', factor=0.5, patience=5, verbose=True)

summary(eegnet_model, input_size=(64, 512))
# Out:
# C:\Users\shaoy\anaconda3\envs\pytorch_env_p11\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 8, 64, 513]             512
#        BatchNorm2d-2           [-1, 8, 64, 513]              16
#             Conv2d-3           [-1, 16, 1, 513]           1,024
#        BatchNorm2d-4           [-1, 16, 1, 513]              32
#                ELU-5           [-1, 16, 1, 513]               0
#          AvgPool2d-6           [-1, 16, 1, 128]               0
#            Dropout-7           [-1, 16, 1, 128]               0
#             Conv2d-8           [-1, 16, 1, 129]           4,096
#        BatchNorm2d-9           [-1, 16, 1, 129]              32
#               ELU-10           [-1, 16, 1, 129]               0
#         AvgPool2d-11            [-1, 16, 1, 16]               0
#           Dropout-12            [-1, 16, 1, 16]               0
#            Linear-13                   [-1, 26]           6,682
# ================================================================
# Total params: 12,394
# Trainable params: 12,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 4.28
# Params size (MB): 0.05
# Estimated Total Size (MB): 4.45
# ----------------------------------------------------------------

# %%
'''Initiate Wandb.'''
# Out:
# 'Initiate Wandb.'

# %%
import wandb

# Use wandb? Resume Training?
USE_WANDB = True

RESUME_LOGGING = False # Set this to true if you are resuming training from a previous run

# Create your wandb run

run_name = '{}_project_ssvep_diff_eegnet_CAE_x_hat_train_with_CAE_out_and_original_x'.format('Ben')

# If you are resuming an old run
if USE_WANDB:

    wandb.login(key="207d89e5e9cdfc415370f05503c72a11d5065073") #TODO

    if RESUME_LOGGING:
        run = wandb.init(
            id     = "diff-CAE(fc)-EEG", ### Insert specific run id here if you want to resume a previous run
            resume = "must", ### You need this to resume previous runs
            project = "project_ssvep-ablations", ### Project should be created in your wandb
            settings = wandb.Settings(_service_wait=300)
        )


    else:
        run = wandb.init(
            name    = run_name, ### Wandb creates random run names if you skip this field, we recommend you give useful names
            reinit  = True, ### Allows reinitalizing runs when you re-run this cell
            project = "project_ssvep-ablations", ### Project should be created in your wandb account
            #config  = config ### Wandb Config for your run
        )

        ### Save your model architecture as a string with str(model)
        model_arch  = str([ddpm, diffe, eegnet_model])
        ### Save it in a txt file
        arch_file   = open("model_arch.txt", "w")
        file_write  = arch_file.write(model_arch)
        arch_file.close()

        ### log it in your wandb run with wandb.save()
        wandb.save('model_arch.txt')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\shaoy\_netrc
# wandb: Currently logged in as: yucheng_shao (yucheng_shao-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>C:\LTI 11785 Introduction to deep learning\project\SSVEP\wandb\run-20250413_125531-uijfloa6</code>
# Syncing run <strong><a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/uijfloa6' target="_blank">Ben_project_ssvep_diff_eegnet_CAE_x_hat_train_with_CAE_out_and_original_x</a></strong> to <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations</a>
#  View run at <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/uijfloa6' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/uijfloa6</a>

# %%
# CLEAR RAM!!
import gc


torch.cuda.empty_cache()
gc.collect()
# Out:
# 59

# %%
def save_model(model, optimizer, scheduler, metrics, epoch, path):
    torch.save(
        {'model_state_dict'         : model.state_dict(),
         'optimizer_state_dict'     : optimizer.state_dict(),
         'scheduler_state_dict'     : scheduler.state_dict(),
         'metric'                   : metrics,
         'epoch'                    : epoch},
         path)

# %%
# Train & Evaluate
checkpoint_dir = r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated'

args = argparse.Namespace()
args.device = device
args.subject = "ALL"
args.root_dir = subject_chars_dir
subject = args.subject

num_epochs = 500
test_period = 1
start_test = test_period
alpha = 0
beta = 1

best_acc = 0
best_f1 = 0
best_recall = 0
best_precision = 0
best_auc = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}

with tqdm(total=num_epochs, desc=f"Method ALL - Joint Training on All Subjects - Autoencoders") as pbar:
    for epoch in range(num_epochs):
        ddpm.train()
        diffe.train()

        epoch_loss = 0
        num_batches = 0
        epoch_acc = 0
        total_samples = 0

        ############################## Train ###########################################
        for x, y in train_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)
            # Train DDPM
            optim1.zero_grad()
            x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            x_hat, x = safe_align_2d(x_hat, x)

            # needed if we wish to use x_hat again after first backward call
            x_hat_detached = x_hat.detach()

            loss_ddpm = F.l1_loss(x_hat, x, reduction="none")
            loss_ddpm.mean().backward()
            optim1.step()
            ddpm_out = x_hat, down, up, t

            # Train Diff-E
            optim2.zero_grad()
            decoder_out, fc_out = diffe(x, ddpm_out)

            #loss_gap = criterion(decoder_out, loss_ddpm.detach())
            loss_gap = criterion(decoder_out, x_hat_detached)
            loss_c = criterion_class(fc_out, y_cat)
            loss = beta * loss_gap + alpha * loss_c
            loss.backward()
            optim2.step()

            # Optimizer scheduler step
            scheduler1.step()
            scheduler2.step()

            # EMA update
            fc_ema.update()

            epoch_loss += loss.item()
            num_batches += 1

            pred_labels = torch.argmax(fc_out, dim=1)
            correct = (pred_labels == y).sum().item()
            epoch_acc += correct
            total_samples += y.size(0)

        history["train_loss"].append(epoch_loss / num_batches)
        history["train_acc"].append(epoch_acc / total_samples)

        metrics = {
            'train_loss': history["train_loss"][-1],
            'train_acc': history["train_acc"][-1],
        }

        ############################## validation ###########################################
        with torch.no_grad():
            if epoch > start_test:
                test_period = 1
            if epoch % test_period == 0:
                ddpm.eval()
                diffe.eval()

                metrics_val = evaluate(diffe.encoder, fc_ema, val_loader, device)

                val_acc = metrics_val["accuracy"]
                history["val_acc"].append(val_acc)
                f1 = metrics_val["f1"]
                recall = metrics_val["recall"]
                precision = metrics_val["precision"]
                auc = metrics_val["auc"]

                val_loss = 0
                with torch.no_grad():
                    for x, y in val_loader:
                        x, y = x.to(device), y.type(torch.LongTensor).to(device)
                        y_cat = F.one_hot(y, num_classes=26).float().to(device)

                        x_hat, down, up, noise, t = ddpm(x)
                        ddpm_out = x_hat, down, up, t

                        # Align the temporal dimension of x_hat and x
                        x_hat, x = safe_align_2d(x_hat, x)

                        loss_ddpm = F.l1_loss(x_hat, x, reduction="none")
                        decoder_out, fc_out = diffe(x, ddpm_out)

                        #loss_gap = criterion(decoder_out, loss_ddpm)
                        loss_gap = criterion(decoder_out, x_hat)
                        loss_c = criterion_class(fc_out, y_cat)

                        val_loss += (beta * loss_gap + alpha * loss_c).item()
                history["val_loss"].append(val_loss / len(val_loader))

                metrics.update({
                    'valid_loss': history["val_loss"][-1],
                    'valid_acc': val_acc,
                })

                best_acc_bool = val_acc > best_acc
                best_f1_bool = f1 > best_f1
                best_recall_bool = recall > best_recall
                best_precision_bool = precision > best_precision
                best_auc_bool = auc > best_auc

                save_model(ddpm, optim1, scheduler1, metrics, epoch, os.path.join(checkpoint_dir, 'ddpm_all_subjects.pth'))
                save_model(diffe, optim2, scheduler2, metrics, epoch, os.path.join(checkpoint_dir, 'diffe_all_subjects.pth'))

                if best_acc_bool:
                    best_acc = val_acc
                    #torch.save(diffe.state_dict(), f'/content/drive/MyDrive/project/model/ssvep/diffe_{subject}.pth')
                    #torch.save(ddpm.state_dict(), os.path.join(checkpoint_dir, 'ddpm_all_subjects.pth'))
                    save_model(ddpm, optim1, scheduler1, metrics, epoch, os.path.join(checkpoint_dir, 'best_ddpm_all_subjects.pth'))
                    save_model(diffe, optim2, scheduler2, metrics, epoch, os.path.join(checkpoint_dir, 'best_diffe_all_subjects.pth'))
                    #torch.save(diffe.state_dict(), r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated\diffe_all_subjects.pth')

                    wandb.save(os.path.join(checkpoint_dir, 'best_ddpm_all_subjects.pth'))
                    wandb.save(os.path.join(checkpoint_dir, 'best_diffe_all_subjects.pth'))
                    
                if best_f1_bool:
                    best_f1 = f1
                if best_recall_bool:
                    best_recall = recall
                if best_precision_bool:
                    best_precision = precision
                if best_auc_bool:
                    best_auc = auc

                description = f"Val Accuracy: {val_acc*100:.2f}% | Best: {best_acc*100:.2f}%"
                pbar.set_description(f"Method ALL – Processing subject {subject} – {description}"
                )
        #print(f"[Epoch {epoch+1}/{num_epochs}] Train Loss: {history['train_loss'][-1]:.4f} | Val Acc: {val_acc*100:.2f}%")
        print(f"[Epoch {epoch+1}/{num_epochs}]")
        print(f"Train Loss: {history['train_loss'][-1]:.4f} | Train Acc: {history['train_acc'][-1]*100:.2f}%")
        print(f"Valid Loss: {history['val_loss'][-1]:.4f} | Valid Acc: {val_acc*100:.2f}%")
        pbar.update(1)

        if run is not None:
            run.log(metrics)
# Out:
# Method ALL - Joint Training on All Subjects - Autoencoders:   0%|          | 0/500 [00:00<?, ?it/s]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# [Epoch 1/500]
# Train Loss: 0.4404 | Train Acc: 4.09%
# Valid Loss: 0.4316 | Valid Acc: 2.88%
# [Epoch 2/500]
# Train Loss: 0.4288 | Train Acc: 3.94%
# Valid Loss: 0.4308 | Valid Acc: 3.27%
# [Epoch 3/500]
# Train Loss: 0.4332 | Train Acc: 3.99%
# Valid Loss: 0.4237 | Valid Acc: 3.27%
# [Epoch 4/500]
# Train Loss: 0.4222 | Train Acc: 3.70%
# Valid Loss: 0.4237 | Valid Acc: 2.69%
# [Epoch 5/500]
# Train Loss: 0.4298 | Train Acc: 3.70%
# Valid Loss: 0.4193 | Valid Acc: 3.27%
# [Epoch 6/500]
# Train Loss: 0.4383 | Train Acc: 3.75%
# Valid Loss: 0.4552 | Valid Acc: 2.88%
# [Epoch 7/500]
# Train Loss: 0.4652 | Train Acc: 3.32%
# Valid Loss: 0.4742 | Valid Acc: 3.65%
# [Epoch 8/500]
# Train Loss: 0.4465 | Train Acc: 3.80%
# Valid Loss: 0.4447 | Valid Acc: 3.08%
# [Epoch 9/500]
# Train Loss: 0.4440 | Train Acc: 3.75%
# Valid Loss: 0.4453 | Valid Acc: 3.46%
# [Epoch 10/500]
# Train Loss: 0.4444 | Train Acc: 3.89%
# Valid Loss: 0.4557 | Valid Acc: 3.65%
# [Epoch 11/500]
# Train Loss: 0.4630 | Train Acc: 3.70%
# Valid Loss: 0.4594 | Valid Acc: 3.46%
# [Epoch 12/500]
# Train Loss: 0.4654 | Train Acc: 3.61%
# Valid Loss: 0.4401 | Valid Acc: 3.65%
# [Epoch 13/500]
# Train Loss: 0.4467 | Train Acc: 3.94%
# Valid Loss: 0.4458 | Valid Acc: 3.65%
# [Epoch 14/500]
# Train Loss: 0.4453 | Train Acc: 3.75%
# Valid Loss: 0.4496 | Valid Acc: 3.65%
# [Epoch 15/500]
# Train Loss: 0.4537 | Train Acc: 3.41%
# Valid Loss: 0.4636 | Valid Acc: 3.46%
# [Epoch 16/500]
# Train Loss: 0.4752 | Train Acc: 3.41%
# Valid Loss: 0.4517 | Valid Acc: 3.85%
# [Epoch 17/500]
# Train Loss: 0.4598 | Train Acc: 3.70%
# Valid Loss: 0.4546 | Valid Acc: 3.46%
# [Epoch 18/500]
# Train Loss: 0.4505 | Train Acc: 3.51%
# Valid Loss: 0.4449 | Valid Acc: 3.46%
# [Epoch 19/500]
# Train Loss: 0.4499 | Train Acc: 3.51%
# Valid Loss: 0.4525 | Valid Acc: 3.65%
# [Epoch 20/500]
# Train Loss: 0.4616 | Train Acc: 3.56%
# Valid Loss: 0.4753 | Valid Acc: 3.85%
# [Epoch 21/500]
# Train Loss: 0.4724 | Train Acc: 3.75%
# Valid Loss: 0.4395 | Valid Acc: 3.85%
# [Epoch 22/500]
# Train Loss: 0.4489 | Train Acc: 3.75%
# Valid Loss: 0.4513 | Valid Acc: 3.85%
# [Epoch 23/500]
# Train Loss: 0.4481 | Train Acc: 3.70%
# Valid Loss: 0.4413 | Valid Acc: 3.65%
# [Epoch 24/500]
# Train Loss: 0.4507 | Train Acc: 3.65%
# Valid Loss: 0.4520 | Valid Acc: 3.85%
# [Epoch 25/500]
# Train Loss: 0.4599 | Train Acc: 3.89%
# Valid Loss: 0.4790 | Valid Acc: 3.46%
# [Epoch 26/500]
# Train Loss: 0.4633 | Train Acc: 3.85%
# Valid Loss: 0.4449 | Valid Acc: 3.65%
# [Epoch 27/500]
# Train Loss: 0.4486 | Train Acc: 3.75%
# Valid Loss: 0.4455 | Valid Acc: 3.46%
# [Epoch 28/500]
# Train Loss: 0.4459 | Train Acc: 3.94%
# Valid Loss: 0.4408 | Valid Acc: 3.46%
# [Epoch 29/500]
# Train Loss: 0.4537 | Train Acc: 3.85%
# Valid Loss: 0.4525 | Valid Acc: 4.42%
# [Epoch 30/500]
# Train Loss: 0.4659 | Train Acc: 3.70%
# Valid Loss: 0.4769 | Valid Acc: 3.85%
# [Epoch 31/500]
# Train Loss: 0.4589 | Train Acc: 3.80%
# Valid Loss: 0.4409 | Valid Acc: 3.46%
# [Epoch 32/500]
# Train Loss: 0.4485 | Train Acc: 3.65%
# Valid Loss: 0.4378 | Valid Acc: 3.46%
# [Epoch 33/500]
# Train Loss: 0.4495 | Train Acc: 3.61%
# Valid Loss: 0.4483 | Valid Acc: 3.46%
# [Epoch 34/500]
# Train Loss: 0.4547 | Train Acc: 3.75%
# Valid Loss: 0.4732 | Valid Acc: 3.65%
# [Epoch 35/500]
# Train Loss: 0.4618 | Train Acc: 3.75%
# Valid Loss: 0.4462 | Valid Acc: 3.85%
# [Epoch 36/500]
# Train Loss: 0.4439 | Train Acc: 3.94%
# Valid Loss: 0.4444 | Valid Acc: 3.65%
# [Epoch 37/500]
# Train Loss: 0.4504 | Train Acc: 3.75%
# Valid Loss: 0.4432 | Valid Acc: 3.65%
# [Epoch 38/500]
# Train Loss: 0.4442 | Train Acc: 3.61%
# Valid Loss: 0.4542 | Valid Acc: 3.46%
# [Epoch 39/500]
# Train Loss: 0.4600 | Train Acc: 3.75%
# Valid Loss: 0.4631 | Valid Acc: 3.85%
# [Epoch 40/500]
# Train Loss: 0.4567 | Train Acc: 3.85%
# Valid Loss: 0.4412 | Valid Acc: 3.85%
# [Epoch 41/500]
# Train Loss: 0.4484 | Train Acc: 3.80%
# Valid Loss: 0.4516 | Valid Acc: 3.85%
# [Epoch 42/500]
# Train Loss: 0.4485 | Train Acc: 3.70%
# Valid Loss: 0.4377 | Valid Acc: 3.85%
# [Epoch 43/500]
# Train Loss: 0.4471 | Train Acc: 3.46%
# Valid Loss: 0.4576 | Valid Acc: 3.65%
# [Epoch 44/500]
# Train Loss: 0.4579 | Train Acc: 3.70%
# Valid Loss: 0.4545 | Valid Acc: 3.65%
# [Epoch 45/500]
# Train Loss: 0.4478 | Train Acc: 3.61%
# Valid Loss: 0.4487 | Valid Acc: 3.46%
# [Epoch 46/500]
# Train Loss: 0.4447 | Train Acc: 3.80%
# Valid Loss: 0.4432 | Valid Acc: 3.65%
# [Epoch 47/500]
# Train Loss: 0.4467 | Train Acc: 3.75%
# Valid Loss: 0.4537 | Valid Acc: 3.46%
# [Epoch 48/500]
# Train Loss: 0.4516 | Train Acc: 3.41%
# Valid Loss: 0.4425 | Valid Acc: 3.27%
# [Epoch 49/500]
# Train Loss: 0.4559 | Train Acc: 3.51%
# Valid Loss: 0.4483 | Valid Acc: 3.65%
# [Epoch 50/500]
# Train Loss: 0.4439 | Train Acc: 3.46%
# Valid Loss: 0.4362 | Valid Acc: 3.46%
# [Epoch 51/500]
# Train Loss: 0.4417 | Train Acc: 3.61%
# Valid Loss: 0.4484 | Valid Acc: 3.46%
# [Epoch 52/500]
# Train Loss: 0.4429 | Train Acc: 3.51%
# Valid Loss: 0.4478 | Valid Acc: 3.65%
# [Epoch 53/500]
# Train Loss: 0.4534 | Train Acc: 3.61%
# Valid Loss: 0.4548 | Valid Acc: 3.27%
# [Epoch 54/500]
# Train Loss: 0.4489 | Train Acc: 3.51%
# Valid Loss: 0.4438 | Valid Acc: 3.27%
# [Epoch 55/500]
# Train Loss: 0.4428 | Train Acc: 3.51%
# Valid Loss: 0.4404 | Valid Acc: 3.46%
# [Epoch 56/500]
# Train Loss: 0.4433 | Train Acc: 3.56%
# Valid Loss: 0.4489 | Valid Acc: 3.46%
# [Epoch 57/500]
# Train Loss: 0.4505 | Train Acc: 3.65%
# Valid Loss: 0.4417 | Valid Acc: 3.46%
# [Epoch 58/500]
# Train Loss: 0.4536 | Train Acc: 3.56%
# Valid Loss: 0.4442 | Valid Acc: 3.85%
# [Epoch 59/500]
# Train Loss: 0.4463 | Train Acc: 3.85%
# Valid Loss: 0.4481 | Valid Acc: 3.27%
# [Epoch 60/500]
# Train Loss: 0.4450 | Train Acc: 3.80%
# Valid Loss: 0.4382 | Valid Acc: 3.27%
# [Epoch 61/500]
# Train Loss: 0.4444 | Train Acc: 3.80%
# Valid Loss: 0.4441 | Valid Acc: 3.65%
# [Epoch 62/500]
# Train Loss: 0.4516 | Train Acc: 3.75%
# Valid Loss: 0.4452 | Valid Acc: 3.46%
# [Epoch 63/500]
# Train Loss: 0.4464 | Train Acc: 3.41%
# Valid Loss: 0.4387 | Valid Acc: 3.27%
# [Epoch 64/500]
# Train Loss: 0.4436 | Train Acc: 3.70%
# Valid Loss: 0.4496 | Valid Acc: 3.46%
# [Epoch 65/500]
# Train Loss: 0.4423 | Train Acc: 3.89%
# Valid Loss: 0.4459 | Valid Acc: 3.27%
# [Epoch 66/500]
# Train Loss: 0.4455 | Train Acc: 3.94%
# Valid Loss: 0.4443 | Valid Acc: 3.65%
# [Epoch 67/500]
# Train Loss: 0.4513 | Train Acc: 3.56%
# Valid Loss: 0.4589 | Valid Acc: 3.27%
# [Epoch 68/500]
# Train Loss: 0.4414 | Train Acc: 3.85%
# Valid Loss: 0.4372 | Valid Acc: 3.27%
# [Epoch 69/500]
# Train Loss: 0.4419 | Train Acc: 3.80%
# Valid Loss: 0.4429 | Valid Acc: 3.27%
# [Epoch 70/500]
# Train Loss: 0.4412 | Train Acc: 3.80%
# Valid Loss: 0.4349 | Valid Acc: 3.27%
# [Epoch 71/500]
# Train Loss: 0.4438 | Train Acc: 3.85%
# Valid Loss: 0.4485 | Valid Acc: 2.88%
# [Epoch 72/500]
# Train Loss: 0.4443 | Train Acc: 3.65%
# Valid Loss: 0.4402 | Valid Acc: 3.65%
# [Epoch 73/500]
# Train Loss: 0.4433 | Train Acc: 3.75%
# Valid Loss: 0.4417 | Valid Acc: 3.27%
# [Epoch 74/500]
# Train Loss: 0.4425 | Train Acc: 3.75%
# Valid Loss: 0.4363 | Valid Acc: 3.46%
# [Epoch 75/500]
# Train Loss: 0.4455 | Train Acc: 3.70%
# Valid Loss: 0.4470 | Valid Acc: 3.46%
# [Epoch 76/500]
# Train Loss: 0.4489 | Train Acc: 3.65%
# Valid Loss: 0.4467 | Valid Acc: 3.08%
# [Epoch 77/500]
# Train Loss: 0.4430 | Train Acc: 3.56%
# Valid Loss: 0.4404 | Valid Acc: 3.27%
# [Epoch 78/500]
# Train Loss: 0.4429 | Train Acc: 3.46%
# Valid Loss: 0.4383 | Valid Acc: 3.27%
# [Epoch 79/500]
# Train Loss: 0.4402 | Train Acc: 3.61%
# Valid Loss: 0.4473 | Valid Acc: 3.27%
# [Epoch 80/500]
# Train Loss: 0.4457 | Train Acc: 3.46%
# Valid Loss: 0.4366 | Valid Acc: 3.46%
# [Epoch 81/500]
# Train Loss: 0.4495 | Train Acc: 3.56%
# Valid Loss: 0.4397 | Valid Acc: 3.27%
# [Epoch 82/500]
# Train Loss: 0.4459 | Train Acc: 3.56%
# Valid Loss: 0.4436 | Valid Acc: 3.27%
# [Epoch 83/500]
# Train Loss: 0.4399 | Train Acc: 3.65%
# Valid Loss: 0.4459 | Valid Acc: 3.27%
# [Epoch 84/500]
# Train Loss: 0.4415 | Train Acc: 3.46%
# Valid Loss: 0.4410 | Valid Acc: 3.08%
# [Epoch 85/500]
# Train Loss: 0.4481 | Train Acc: 3.56%
# Valid Loss: 0.4541 | Valid Acc: 3.27%
# [Epoch 86/500]
# Train Loss: 0.4465 | Train Acc: 3.51%
# Valid Loss: 0.4410 | Valid Acc: 3.08%
# [Epoch 87/500]
# Train Loss: 0.4406 | Train Acc: 3.51%
# Valid Loss: 0.4475 | Valid Acc: 3.65%
# [Epoch 88/500]
# Train Loss: 0.4416 | Train Acc: 3.56%
# Valid Loss: 0.4397 | Valid Acc: 3.46%
# [Epoch 89/500]
# Train Loss: 0.4426 | Train Acc: 3.51%
# Valid Loss: 0.4419 | Valid Acc: 3.27%
# [Epoch 90/500]
# Train Loss: 0.4512 | Train Acc: 3.65%
# Valid Loss: 0.4545 | Valid Acc: 3.46%
# [Epoch 91/500]
# Train Loss: 0.4459 | Train Acc: 3.61%
# Valid Loss: 0.4396 | Valid Acc: 3.27%
# [Epoch 92/500]
# Train Loss: 0.4406 | Train Acc: 3.56%
# Valid Loss: 0.4409 | Valid Acc: 3.27%
# [Epoch 93/500]
# Train Loss: 0.4411 | Train Acc: 3.56%
# Valid Loss: 0.4379 | Valid Acc: 3.46%
# [Epoch 94/500]
# Train Loss: 0.4470 | Train Acc: 3.61%
# Valid Loss: 0.4448 | Valid Acc: 3.27%
# [Epoch 95/500]
# Train Loss: 0.4472 | Train Acc: 3.61%
# Valid Loss: 0.4455 | Valid Acc: 3.27%
# [Epoch 96/500]
# Train Loss: 0.4445 | Train Acc: 3.61%
# Valid Loss: 0.4366 | Valid Acc: 3.27%
# [Epoch 97/500]
# Train Loss: 0.4420 | Train Acc: 3.65%
# Valid Loss: 0.4472 | Valid Acc: 3.27%
# [Epoch 98/500]
# Train Loss: 0.4476 | Train Acc: 3.65%
# Valid Loss: 0.4432 | Valid Acc: 3.46%
# [Epoch 99/500]
# Train Loss: 0.4474 | Train Acc: 3.65%
# Valid Loss: 0.4535 | Valid Acc: 3.27%
# [Epoch 100/500]
# Train Loss: 0.4479 | Train Acc: 3.51%
# Valid Loss: 0.4431 | Valid Acc: 3.27%
# [Epoch 101/500]
# Train Loss: 0.4400 | Train Acc: 3.61%
# Valid Loss: 0.4341 | Valid Acc: 3.27%
# [Epoch 102/500]
# Train Loss: 0.4432 | Train Acc: 3.61%
# Valid Loss: 0.4411 | Valid Acc: 3.27%
# [Epoch 103/500]
# Train Loss: 0.4432 | Train Acc: 3.61%
# Valid Loss: 0.4366 | Valid Acc: 3.46%
# [Epoch 104/500]
# Train Loss: 0.4439 | Train Acc: 3.41%
# Valid Loss: 0.4427 | Valid Acc: 3.27%
# [Epoch 105/500]
# Train Loss: 0.4404 | Train Acc: 3.46%
# Valid Loss: 0.4438 | Valid Acc: 3.27%
# [Epoch 106/500]
# Train Loss: 0.4409 | Train Acc: 3.61%
# Valid Loss: 0.4367 | Valid Acc: 3.27%
# [Epoch 107/500]
# Train Loss: 0.4408 | Train Acc: 3.70%
# Valid Loss: 0.4389 | Valid Acc: 3.46%
# [Epoch 108/500]
# Train Loss: 0.4444 | Train Acc: 3.75%
# Valid Loss: 0.4531 | Valid Acc: 3.27%
# [Epoch 109/500]
# Train Loss: 0.4441 | Train Acc: 3.75%
# Valid Loss: 0.4378 | Valid Acc: 3.27%
# [Epoch 110/500]
# Train Loss: 0.4401 | Train Acc: 3.65%
# Valid Loss: 0.4376 | Valid Acc: 3.65%
# [Epoch 111/500]
# Train Loss: 0.4401 | Train Acc: 3.65%
# Valid Loss: 0.4348 | Valid Acc: 3.46%
# [Epoch 112/500]
# Train Loss: 0.4427 | Train Acc: 3.61%
# Valid Loss: 0.4479 | Valid Acc: 3.85%
# [Epoch 113/500]
# Train Loss: 0.4419 | Train Acc: 3.65%
# Valid Loss: 0.4393 | Valid Acc: 3.08%
# [Epoch 114/500]
# Train Loss: 0.4376 | Train Acc: 3.65%
# Valid Loss: 0.4403 | Valid Acc: 3.85%
# [Epoch 115/500]
# Train Loss: 0.4412 | Train Acc: 3.46%
# Valid Loss: 0.4391 | Valid Acc: 3.27%
# [Epoch 116/500]
# Train Loss: 0.4385 | Train Acc: 3.46%
# Valid Loss: 0.4376 | Valid Acc: 3.85%
# [Epoch 117/500]
# Train Loss: 0.4411 | Train Acc: 3.51%
# Valid Loss: 0.4383 | Valid Acc: 3.08%
# [Epoch 118/500]
# Train Loss: 0.4418 | Train Acc: 3.56%
# Valid Loss: 0.4388 | Valid Acc: 2.88%
# [Epoch 119/500]
# Train Loss: 0.4425 | Train Acc: 3.70%
# Valid Loss: 0.4352 | Valid Acc: 3.08%
# [Epoch 120/500]
# Train Loss: 0.4407 | Train Acc: 3.61%
# Valid Loss: 0.4373 | Valid Acc: 3.65%
# [Epoch 121/500]
# Train Loss: 0.4412 | Train Acc: 3.65%
# Valid Loss: 0.4470 | Valid Acc: 3.85%
# [Epoch 122/500]
# Train Loss: 0.4446 | Train Acc: 3.51%
# Valid Loss: 0.4467 | Valid Acc: 3.27%
# [Epoch 123/500]
# Train Loss: 0.4441 | Train Acc: 3.75%
# Valid Loss: 0.4306 | Valid Acc: 4.23%
# [Epoch 124/500]
# Train Loss: 0.4408 | Train Acc: 3.70%
# Valid Loss: 0.4474 | Valid Acc: 3.85%
# [Epoch 125/500]
# Train Loss: 0.4438 | Train Acc: 3.65%
# Valid Loss: 0.4404 | Valid Acc: 4.04%
# [Epoch 126/500]
# Train Loss: 0.4421 | Train Acc: 3.61%
# Valid Loss: 0.4481 | Valid Acc: 4.23%
# [Epoch 127/500]
# Train Loss: 0.4386 | Train Acc: 3.56%
# Valid Loss: 0.4419 | Valid Acc: 4.23%
# [Epoch 128/500]
# Train Loss: 0.4401 | Train Acc: 3.51%
# Valid Loss: 0.4330 | Valid Acc: 3.85%
# [Epoch 129/500]
# Train Loss: 0.4393 | Train Acc: 3.65%
# Valid Loss: 0.4514 | Valid Acc: 4.04%
# [Epoch 130/500]
# Train Loss: 0.4430 | Train Acc: 3.46%
# Valid Loss: 0.4320 | Valid Acc: 4.42%
# [Epoch 131/500]
# Train Loss: 0.4415 | Train Acc: 3.56%
# Valid Loss: 0.4433 | Valid Acc: 4.23%
# [Epoch 132/500]
# Train Loss: 0.4415 | Train Acc: 3.51%
# Valid Loss: 0.4361 | Valid Acc: 4.04%
# [Epoch 133/500]
# Train Loss: 0.4394 | Train Acc: 3.61%
# Valid Loss: 0.4433 | Valid Acc: 4.42%
# [Epoch 134/500]
# Train Loss: 0.4403 | Train Acc: 3.61%
# Valid Loss: 0.4386 | Valid Acc: 4.62%
# [Epoch 135/500]
# Train Loss: 0.4410 | Train Acc: 3.56%
# Valid Loss: 0.4489 | Valid Acc: 4.42%
# [Epoch 136/500]
# Train Loss: 0.4426 | Train Acc: 3.51%
# Valid Loss: 0.4443 | Valid Acc: 4.23%
# [Epoch 137/500]
# Train Loss: 0.4408 | Train Acc: 3.46%
# Valid Loss: 0.4371 | Valid Acc: 4.62%
# [Epoch 138/500]
# Train Loss: 0.4419 | Train Acc: 3.75%
# Valid Loss: 0.4300 | Valid Acc: 4.62%
# [Epoch 139/500]
# Train Loss: 0.4411 | Train Acc: 3.70%
# Valid Loss: 0.4333 | Valid Acc: 4.81%
# [Epoch 140/500]
# Train Loss: 0.4402 | Train Acc: 3.56%
# Valid Loss: 0.4443 | Valid Acc: 4.62%
# [Epoch 141/500]
# Train Loss: 0.4419 | Train Acc: 3.65%
# Valid Loss: 0.4410 | Valid Acc: 4.62%
# [Epoch 142/500]
# Train Loss: 0.4402 | Train Acc: 3.85%
# Valid Loss: 0.4426 | Valid Acc: 4.42%
# [Epoch 143/500]
# Train Loss: 0.4422 | Train Acc: 3.65%
# Valid Loss: 0.4379 | Valid Acc: 4.81%
# [Epoch 144/500]
# Train Loss: 0.4408 | Train Acc: 3.65%
# Valid Loss: 0.4423 | Valid Acc: 4.04%
# [Epoch 145/500]
# Train Loss: 0.4437 | Train Acc: 3.70%
# Valid Loss: 0.4425 | Valid Acc: 4.81%
# [Epoch 146/500]
# Train Loss: 0.4446 | Train Acc: 3.65%
# Valid Loss: 0.4398 | Valid Acc: 4.62%
# [Epoch 147/500]
# Train Loss: 0.4429 | Train Acc: 3.94%
# Valid Loss: 0.4381 | Valid Acc: 4.62%
# [Epoch 148/500]
# Train Loss: 0.4421 | Train Acc: 3.85%
# Valid Loss: 0.4453 | Valid Acc: 4.62%
# [Epoch 149/500]
# Train Loss: 0.4410 | Train Acc: 3.94%
# Valid Loss: 0.4385 | Valid Acc: 4.62%
# [Epoch 150/500]
# Train Loss: 0.4450 | Train Acc: 3.61%
# Valid Loss: 0.4414 | Valid Acc: 4.23%
# [Epoch 151/500]
# Train Loss: 0.4469 | Train Acc: 3.65%
# Valid Loss: 0.4506 | Valid Acc: 4.81%
# [Epoch 152/500]
# Train Loss: 0.4449 | Train Acc: 3.51%
# Valid Loss: 0.4447 | Valid Acc: 4.62%
# [Epoch 153/500]
# Train Loss: 0.4467 | Train Acc: 3.65%
# Valid Loss: 0.4472 | Valid Acc: 4.62%
# [Epoch 154/500]
# Train Loss: 0.4426 | Train Acc: 3.70%
# Valid Loss: 0.4428 | Valid Acc: 4.81%
# [Epoch 155/500]
# Train Loss: 0.4382 | Train Acc: 3.65%
# Valid Loss: 0.4441 | Valid Acc: 4.81%
# [Epoch 156/500]
# Train Loss: 0.4430 | Train Acc: 3.61%
# Valid Loss: 0.4433 | Valid Acc: 4.81%
# [Epoch 157/500]
# Train Loss: 0.4424 | Train Acc: 3.70%
# Valid Loss: 0.4409 | Valid Acc: 4.81%
# [Epoch 158/500]
# Train Loss: 0.4424 | Train Acc: 3.65%
# Valid Loss: 0.4430 | Valid Acc: 4.81%
# [Epoch 159/500]
# Train Loss: 0.4434 | Train Acc: 3.65%
# Valid Loss: 0.4432 | Valid Acc: 4.62%
# [Epoch 160/500]
# Train Loss: 0.4424 | Train Acc: 3.70%
# Valid Loss: 0.4445 | Valid Acc: 4.81%
# [Epoch 161/500]
# Train Loss: 0.4400 | Train Acc: 3.85%
# Valid Loss: 0.4375 | Valid Acc: 4.62%
# [Epoch 162/500]
# Train Loss: 0.4394 | Train Acc: 3.85%
# Valid Loss: 0.4471 | Valid Acc: 4.81%
# [Epoch 163/500]
# Train Loss: 0.4441 | Train Acc: 3.80%
# Valid Loss: 0.4397 | Valid Acc: 4.81%
# [Epoch 164/500]
# Train Loss: 0.4423 | Train Acc: 3.75%
# Valid Loss: 0.4343 | Valid Acc: 4.62%
# [Epoch 165/500]
# Train Loss: 0.4444 | Train Acc: 3.89%
# Valid Loss: 0.4450 | Valid Acc: 4.81%
# [Epoch 166/500]
# Train Loss: 0.4386 | Train Acc: 3.80%
# Valid Loss: 0.4422 | Valid Acc: 4.81%
# [Epoch 167/500]
# Train Loss: 0.4435 | Train Acc: 3.85%
# Valid Loss: 0.4455 | Valid Acc: 4.81%
# [Epoch 168/500]
# Train Loss: 0.4414 | Train Acc: 3.80%
# Valid Loss: 0.4398 | Valid Acc: 4.81%
# [Epoch 169/500]
# Train Loss: 0.4412 | Train Acc: 3.80%
# Valid Loss: 0.4406 | Valid Acc: 4.81%
# [Epoch 170/500]
# Train Loss: 0.4366 | Train Acc: 3.80%
# Valid Loss: 0.4371 | Valid Acc: 4.81%
# [Epoch 171/500]
# Train Loss: 0.4383 | Train Acc: 3.80%
# Valid Loss: 0.4363 | Valid Acc: 4.81%
# [Epoch 172/500]
# Train Loss: 0.4407 | Train Acc: 3.80%
# Valid Loss: 0.4406 | Valid Acc: 4.62%
# [Epoch 173/500]
# Train Loss: 0.4404 | Train Acc: 3.75%
# Valid Loss: 0.4333 | Valid Acc: 4.81%
# [Epoch 174/500]
# Train Loss: 0.4407 | Train Acc: 3.75%
# Valid Loss: 0.4382 | Valid Acc: 4.62%
# [Epoch 175/500]
# Train Loss: 0.4402 | Train Acc: 3.75%
# Valid Loss: 0.4304 | Valid Acc: 4.81%
# [Epoch 176/500]
# Train Loss: 0.4377 | Train Acc: 3.80%
# Valid Loss: 0.4380 | Valid Acc: 4.42%
# [Epoch 177/500]
# Train Loss: 0.4406 | Train Acc: 3.85%
# Valid Loss: 0.4454 | Valid Acc: 4.62%
# [Epoch 178/500]
# Train Loss: 0.4405 | Train Acc: 3.80%
# Valid Loss: 0.4402 | Valid Acc: 4.81%
# [Epoch 179/500]
# Train Loss: 0.4398 | Train Acc: 3.89%
# Valid Loss: 0.4402 | Valid Acc: 4.42%
# [Epoch 180/500]
# Train Loss: 0.4383 | Train Acc: 3.85%
# Valid Loss: 0.4394 | Valid Acc: 4.62%
# [Epoch 181/500]
# Train Loss: 0.4380 | Train Acc: 3.85%
# Valid Loss: 0.4340 | Valid Acc: 4.62%
# [Epoch 182/500]
# Train Loss: 0.4409 | Train Acc: 3.70%
# Valid Loss: 0.4416 | Valid Acc: 4.42%
# [Epoch 183/500]
# Train Loss: 0.4399 | Train Acc: 3.80%
# Valid Loss: 0.4385 | Valid Acc: 4.42%
# [Epoch 184/500]
# Train Loss: 0.4384 | Train Acc: 3.85%
# Valid Loss: 0.4348 | Valid Acc: 4.42%
# [Epoch 185/500]
# Train Loss: 0.4411 | Train Acc: 3.94%
# Valid Loss: 0.4409 | Valid Acc: 4.42%
# [Epoch 186/500]
# Train Loss: 0.4440 | Train Acc: 3.85%
# Valid Loss: 0.4385 | Valid Acc: 4.42%
# [Epoch 187/500]
# Train Loss: 0.4420 | Train Acc: 3.99%
# Valid Loss: 0.4398 | Valid Acc: 4.62%
# [Epoch 188/500]
# Train Loss: 0.4401 | Train Acc: 3.89%
# Valid Loss: 0.4434 | Valid Acc: 4.62%
# [Epoch 189/500]
# Train Loss: 0.4422 | Train Acc: 3.85%
# Valid Loss: 0.4441 | Valid Acc: 4.62%
# [Epoch 190/500]
# Train Loss: 0.4409 | Train Acc: 3.80%
# Valid Loss: 0.4447 | Valid Acc: 4.42%
# [Epoch 191/500]
# Train Loss: 0.4422 | Train Acc: 4.04%
# Valid Loss: 0.4374 | Valid Acc: 4.62%
# [Epoch 192/500]
# Train Loss: 0.4419 | Train Acc: 3.94%
# Valid Loss: 0.4417 | Valid Acc: 4.42%
# [Epoch 193/500]
# Train Loss: 0.4420 | Train Acc: 3.75%
# Valid Loss: 0.4477 | Valid Acc: 4.42%
# [Epoch 194/500]
# Train Loss: 0.4446 | Train Acc: 3.94%
# Valid Loss: 0.4417 | Valid Acc: 4.42%
# [Epoch 195/500]
# Train Loss: 0.4446 | Train Acc: 4.04%
# Valid Loss: 0.4456 | Valid Acc: 4.42%
# [Epoch 196/500]
# Train Loss: 0.4405 | Train Acc: 3.94%
# Valid Loss: 0.4341 | Valid Acc: 4.23%
# [Epoch 197/500]
# Train Loss: 0.4401 | Train Acc: 3.85%
# Valid Loss: 0.4334 | Valid Acc: 4.23%
# [Epoch 198/500]
# Train Loss: 0.4393 | Train Acc: 3.80%
# Valid Loss: 0.4448 | Valid Acc: 4.23%
# [Epoch 199/500]
# Train Loss: 0.4408 | Train Acc: 3.89%
# Valid Loss: 0.4329 | Valid Acc: 4.23%
# [Epoch 200/500]
# Train Loss: 0.4439 | Train Acc: 3.85%
# Valid Loss: 0.4402 | Valid Acc: 4.42%
# [Epoch 201/500]
# Train Loss: 0.4431 | Train Acc: 3.94%
# Valid Loss: 0.4405 | Valid Acc: 4.23%
# [Epoch 202/500]
# Train Loss: 0.4413 | Train Acc: 3.99%
# Valid Loss: 0.4355 | Valid Acc: 4.04%
# [Epoch 203/500]
# Train Loss: 0.4410 | Train Acc: 3.99%
# Valid Loss: 0.4417 | Valid Acc: 4.04%
# [Epoch 204/500]
# Train Loss: 0.4408 | Train Acc: 3.94%
# Valid Loss: 0.4428 | Valid Acc: 4.23%
# [Epoch 205/500]
# Train Loss: 0.4428 | Train Acc: 3.94%
# Valid Loss: 0.4374 | Valid Acc: 4.42%
# [Epoch 206/500]
# Train Loss: 0.4389 | Train Acc: 3.94%
# Valid Loss: 0.4397 | Valid Acc: 3.85%
# [Epoch 207/500]
# Train Loss: 0.4421 | Train Acc: 3.94%
# Valid Loss: 0.4418 | Valid Acc: 4.23%
# [Epoch 208/500]
# Train Loss: 0.4393 | Train Acc: 3.99%
# Valid Loss: 0.4375 | Valid Acc: 4.23%
# [Epoch 209/500]
# Train Loss: 0.4331 | Train Acc: 3.99%
# Valid Loss: 0.4368 | Valid Acc: 4.04%
# [Epoch 210/500]
# Train Loss: 0.4406 | Train Acc: 3.94%
# Valid Loss: 0.4482 | Valid Acc: 4.04%
# [Epoch 211/500]
# Train Loss: 0.4397 | Train Acc: 4.04%
# Valid Loss: 0.4334 | Valid Acc: 4.23%
# [Epoch 212/500]
# Train Loss: 0.4443 | Train Acc: 3.99%
# Valid Loss: 0.4486 | Valid Acc: 3.85%
# [Epoch 213/500]
# Train Loss: 0.4414 | Train Acc: 4.09%
# Valid Loss: 0.4431 | Valid Acc: 4.04%
# [Epoch 214/500]
# Train Loss: 0.4418 | Train Acc: 3.85%
# Valid Loss: 0.4404 | Valid Acc: 4.04%
# [Epoch 215/500]
# Train Loss: 0.4394 | Train Acc: 4.04%
# Valid Loss: 0.4429 | Valid Acc: 4.23%
# [Epoch 216/500]
# Train Loss: 0.4419 | Train Acc: 3.94%
# Valid Loss: 0.4416 | Valid Acc: 4.04%
# [Epoch 217/500]
# Train Loss: 0.4400 | Train Acc: 3.99%
# Valid Loss: 0.4407 | Valid Acc: 4.04%
# [Epoch 218/500]
# Train Loss: 0.4411 | Train Acc: 3.94%
# Valid Loss: 0.4431 | Valid Acc: 4.04%
# [Epoch 219/500]
# Train Loss: 0.4391 | Train Acc: 3.94%
# Valid Loss: 0.4382 | Valid Acc: 4.04%
# [Epoch 220/500]
# Train Loss: 0.4393 | Train Acc: 3.94%
# Valid Loss: 0.4411 | Valid Acc: 4.23%
# [Epoch 221/500]
# Train Loss: 0.4367 | Train Acc: 4.04%
# Valid Loss: 0.4356 | Valid Acc: 3.85%
# [Epoch 222/500]
# Train Loss: 0.4393 | Train Acc: 3.99%
# Valid Loss: 0.4403 | Valid Acc: 4.04%
# [Epoch 223/500]
# Train Loss: 0.4382 | Train Acc: 3.89%
# Valid Loss: 0.4402 | Valid Acc: 4.04%
# [Epoch 224/500]
# Train Loss: 0.4432 | Train Acc: 3.99%
# Valid Loss: 0.4376 | Valid Acc: 4.04%
# [Epoch 225/500]
# Train Loss: 0.4385 | Train Acc: 4.04%
# Valid Loss: 0.4357 | Valid Acc: 4.04%
# [Epoch 226/500]
# Train Loss: 0.4362 | Train Acc: 3.94%
# Valid Loss: 0.4420 | Valid Acc: 4.04%
# [Epoch 227/500]
# Train Loss: 0.4379 | Train Acc: 3.89%
# Valid Loss: 0.4378 | Valid Acc: 4.04%
# [Epoch 228/500]
# Train Loss: 0.4356 | Train Acc: 3.99%
# Valid Loss: 0.4363 | Valid Acc: 4.04%
# [Epoch 229/500]
# Train Loss: 0.4404 | Train Acc: 3.99%
# Valid Loss: 0.4389 | Valid Acc: 4.04%
# [Epoch 230/500]
# Train Loss: 0.4373 | Train Acc: 3.94%
# Valid Loss: 0.4455 | Valid Acc: 4.04%
# [Epoch 231/500]
# Train Loss: 0.4423 | Train Acc: 4.04%
# Valid Loss: 0.4424 | Valid Acc: 3.85%
# [Epoch 232/500]
# Train Loss: 0.4396 | Train Acc: 3.99%
# Valid Loss: 0.4413 | Valid Acc: 4.04%
# [Epoch 233/500]
# Train Loss: 0.4426 | Train Acc: 4.09%
# Valid Loss: 0.4400 | Valid Acc: 4.04%
# [Epoch 234/500]
# Train Loss: 0.4400 | Train Acc: 3.99%
# Valid Loss: 0.4380 | Valid Acc: 4.04%
# [Epoch 235/500]
# Train Loss: 0.4374 | Train Acc: 3.94%
# Valid Loss: 0.4432 | Valid Acc: 3.85%
# [Epoch 236/500]
# Train Loss: 0.4416 | Train Acc: 3.99%
# Valid Loss: 0.4341 | Valid Acc: 3.85%
# [Epoch 237/500]
# Train Loss: 0.4423 | Train Acc: 4.04%
# Valid Loss: 0.4398 | Valid Acc: 3.85%
# [Epoch 238/500]
# Train Loss: 0.4414 | Train Acc: 3.89%
# Valid Loss: 0.4382 | Valid Acc: 3.65%
# [Epoch 239/500]
# Train Loss: 0.4404 | Train Acc: 3.94%
# Valid Loss: 0.4401 | Valid Acc: 3.65%
# [Epoch 240/500]
# Train Loss: 0.4386 | Train Acc: 3.89%
# Valid Loss: 0.4451 | Valid Acc: 4.04%
# [Epoch 241/500]
# Train Loss: 0.4406 | Train Acc: 3.89%
# Valid Loss: 0.4458 | Valid Acc: 4.04%
# [Epoch 242/500]
# Train Loss: 0.4387 | Train Acc: 3.89%
# Valid Loss: 0.4347 | Valid Acc: 3.85%
# [Epoch 243/500]
# Train Loss: 0.4409 | Train Acc: 3.85%
# Valid Loss: 0.4380 | Valid Acc: 3.85%
# [Epoch 244/500]
# Train Loss: 0.4403 | Train Acc: 3.89%
# Valid Loss: 0.4416 | Valid Acc: 3.85%
# [Epoch 245/500]
# Train Loss: 0.4390 | Train Acc: 3.80%
# Valid Loss: 0.4360 | Valid Acc: 3.85%
# [Epoch 246/500]
# Train Loss: 0.4381 | Train Acc: 3.80%
# Valid Loss: 0.4359 | Valid Acc: 3.85%
# [Epoch 247/500]
# Train Loss: 0.4391 | Train Acc: 3.85%
# Valid Loss: 0.4393 | Valid Acc: 3.85%
# [Epoch 248/500]
# Train Loss: 0.4377 | Train Acc: 3.94%
# Valid Loss: 0.4371 | Valid Acc: 3.85%
# [Epoch 249/500]
# Train Loss: 0.4408 | Train Acc: 3.85%
# Valid Loss: 0.4496 | Valid Acc: 4.04%
# [Epoch 250/500]
# Train Loss: 0.4421 | Train Acc: 3.94%
# Valid Loss: 0.4480 | Valid Acc: 4.04%
# [Epoch 251/500]
# Train Loss: 0.4416 | Train Acc: 3.94%
# Valid Loss: 0.4424 | Valid Acc: 4.04%
# [Epoch 252/500]
# Train Loss: 0.4376 | Train Acc: 3.80%
# Valid Loss: 0.4375 | Valid Acc: 4.04%
# [Epoch 253/500]
# Train Loss: 0.4430 | Train Acc: 3.85%
# Valid Loss: 0.4464 | Valid Acc: 3.85%
# [Epoch 254/500]
# Train Loss: 0.4406 | Train Acc: 3.89%
# Valid Loss: 0.4427 | Valid Acc: 3.85%
# [Epoch 255/500]
# Train Loss: 0.4398 | Train Acc: 3.80%
# Valid Loss: 0.4350 | Valid Acc: 3.85%
# [Epoch 256/500]
# Train Loss: 0.4403 | Train Acc: 3.94%
# Valid Loss: 0.4392 | Valid Acc: 4.04%
# [Epoch 257/500]
# Train Loss: 0.4381 | Train Acc: 3.89%
# Valid Loss: 0.4324 | Valid Acc: 4.04%
# [Epoch 258/500]
# Train Loss: 0.4402 | Train Acc: 3.94%
# Valid Loss: 0.4420 | Valid Acc: 3.85%
# [Epoch 259/500]
# Train Loss: 0.4409 | Train Acc: 3.99%
# Valid Loss: 0.4379 | Valid Acc: 4.04%
# [Epoch 260/500]
# Train Loss: 0.4379 | Train Acc: 3.99%
# Valid Loss: 0.4383 | Valid Acc: 4.04%
# [Epoch 261/500]
# Train Loss: 0.4369 | Train Acc: 4.13%
# Valid Loss: 0.4366 | Valid Acc: 4.04%
# [Epoch 262/500]
# Train Loss: 0.4396 | Train Acc: 3.85%
# Valid Loss: 0.4362 | Valid Acc: 4.04%
# [Epoch 263/500]
# Train Loss: 0.4382 | Train Acc: 3.94%
# Valid Loss: 0.4449 | Valid Acc: 4.04%
# [Epoch 264/500]
# Train Loss: 0.4433 | Train Acc: 3.94%
# Valid Loss: 0.4386 | Valid Acc: 4.04%
# [Epoch 265/500]
# Train Loss: 0.4374 | Train Acc: 3.94%
# Valid Loss: 0.4357 | Valid Acc: 4.04%
# [Epoch 266/500]
# Train Loss: 0.4373 | Train Acc: 3.94%
# Valid Loss: 0.4407 | Valid Acc: 4.04%
# [Epoch 267/500]
# Train Loss: 0.4398 | Train Acc: 3.99%
# Valid Loss: 0.4431 | Valid Acc: 4.04%
# [Epoch 268/500]
# Train Loss: 0.4394 | Train Acc: 3.94%
# Valid Loss: 0.4310 | Valid Acc: 4.04%
# [Epoch 269/500]
# Train Loss: 0.4386 | Train Acc: 3.99%
# Valid Loss: 0.4392 | Valid Acc: 4.04%
# [Epoch 270/500]
# Train Loss: 0.4390 | Train Acc: 4.09%
# Valid Loss: 0.4367 | Valid Acc: 4.04%
# [Epoch 271/500]
# Train Loss: 0.4393 | Train Acc: 4.09%
# Valid Loss: 0.4423 | Valid Acc: 4.04%
# [Epoch 272/500]
# Train Loss: 0.4380 | Train Acc: 3.99%
# Valid Loss: 0.4445 | Valid Acc: 4.04%
# [Epoch 273/500]
# Train Loss: 0.4386 | Train Acc: 3.94%
# Valid Loss: 0.4446 | Valid Acc: 4.04%
# [Epoch 274/500]
# Train Loss: 0.4380 | Train Acc: 3.94%
# Valid Loss: 0.4388 | Valid Acc: 4.04%
# [Epoch 275/500]
# Train Loss: 0.4384 | Train Acc: 4.04%
# Valid Loss: 0.4461 | Valid Acc: 4.04%
# [Epoch 276/500]
# Train Loss: 0.4384 | Train Acc: 3.99%
# Valid Loss: 0.4369 | Valid Acc: 4.23%
# [Epoch 277/500]
# Train Loss: 0.4370 | Train Acc: 3.85%
# Valid Loss: 0.4407 | Valid Acc: 4.23%
# [Epoch 278/500]
# Train Loss: 0.4379 | Train Acc: 3.94%
# Valid Loss: 0.4420 | Valid Acc: 4.23%
# [Epoch 279/500]
# Train Loss: 0.4404 | Train Acc: 3.99%
# Valid Loss: 0.4379 | Valid Acc: 4.04%
# [Epoch 280/500]
# Train Loss: 0.4400 | Train Acc: 3.89%
# Valid Loss: 0.4448 | Valid Acc: 4.23%
# [Epoch 281/500]
# Train Loss: 0.4351 | Train Acc: 3.99%
# Valid Loss: 0.4292 | Valid Acc: 4.23%
# [Epoch 282/500]
# Train Loss: 0.4404 | Train Acc: 3.99%
# Valid Loss: 0.4348 | Valid Acc: 4.04%
# [Epoch 283/500]
# Train Loss: 0.4390 | Train Acc: 3.99%
# Valid Loss: 0.4358 | Valid Acc: 4.04%
# [Epoch 284/500]
# Train Loss: 0.4385 | Train Acc: 3.89%
# Valid Loss: 0.4385 | Valid Acc: 4.04%
# [Epoch 285/500]
# Train Loss: 0.4425 | Train Acc: 3.99%
# Valid Loss: 0.4336 | Valid Acc: 4.23%
# [Epoch 286/500]
# Train Loss: 0.4373 | Train Acc: 3.94%
# Valid Loss: 0.4389 | Valid Acc: 4.23%
# [Epoch 287/500]
# Train Loss: 0.4396 | Train Acc: 4.04%
# Valid Loss: 0.4340 | Valid Acc: 4.23%
# [Epoch 288/500]
# Train Loss: 0.4398 | Train Acc: 4.04%
# Valid Loss: 0.4383 | Valid Acc: 4.04%
# [Epoch 289/500]
# Train Loss: 0.4387 | Train Acc: 4.18%
# Valid Loss: 0.4379 | Valid Acc: 4.23%
# [Epoch 290/500]
# Train Loss: 0.4415 | Train Acc: 4.04%
# Valid Loss: 0.4332 | Valid Acc: 4.23%
# [Epoch 291/500]
# Train Loss: 0.4403 | Train Acc: 4.13%
# Valid Loss: 0.4427 | Valid Acc: 4.23%
# [Epoch 292/500]
# Train Loss: 0.4428 | Train Acc: 4.09%
# Valid Loss: 0.4371 | Valid Acc: 4.23%
# [Epoch 293/500]
# Train Loss: 0.4421 | Train Acc: 4.18%
# Valid Loss: 0.4341 | Valid Acc: 4.23%
# [Epoch 294/500]
# Train Loss: 0.4399 | Train Acc: 4.28%
# Valid Loss: 0.4435 | Valid Acc: 4.23%
# [Epoch 295/500]
# Train Loss: 0.4410 | Train Acc: 4.09%
# Valid Loss: 0.4448 | Valid Acc: 4.23%
# [Epoch 296/500]
# Train Loss: 0.4385 | Train Acc: 4.09%
# Valid Loss: 0.4397 | Valid Acc: 4.23%
# [Epoch 297/500]
# Train Loss: 0.4399 | Train Acc: 4.09%
# Valid Loss: 0.4381 | Valid Acc: 4.23%
# [Epoch 298/500]
# Train Loss: 0.4417 | Train Acc: 4.13%
# Valid Loss: 0.4438 | Valid Acc: 4.23%
# [Epoch 299/500]
# Train Loss: 0.4399 | Train Acc: 4.04%
# Valid Loss: 0.4442 | Valid Acc: 4.23%
# [Epoch 300/500]
# Train Loss: 0.4387 | Train Acc: 4.28%
# Valid Loss: 0.4319 | Valid Acc: 4.23%
# [Epoch 301/500]
# Train Loss: 0.4374 | Train Acc: 4.13%
# Valid Loss: 0.4458 | Valid Acc: 4.23%
# [Epoch 302/500]
# Train Loss: 0.4392 | Train Acc: 4.13%
# Valid Loss: 0.4420 | Valid Acc: 4.23%
# [Epoch 303/500]
# Train Loss: 0.4376 | Train Acc: 4.23%
# Valid Loss: 0.4408 | Valid Acc: 4.23%
# [Epoch 304/500]
# Train Loss: 0.4389 | Train Acc: 4.23%
# Valid Loss: 0.4342 | Valid Acc: 4.23%
# [Epoch 305/500]
# Train Loss: 0.4385 | Train Acc: 4.13%
# Valid Loss: 0.4331 | Valid Acc: 4.23%
# [Epoch 306/500]
# Train Loss: 0.4404 | Train Acc: 4.09%
# Valid Loss: 0.4431 | Valid Acc: 4.23%
# [Epoch 307/500]
# Train Loss: 0.4403 | Train Acc: 4.09%
# Valid Loss: 0.4455 | Valid Acc: 4.23%
# [Epoch 308/500]
# Train Loss: 0.4406 | Train Acc: 3.99%
# Valid Loss: 0.4395 | Valid Acc: 4.23%
# [Epoch 309/500]
# Train Loss: 0.4374 | Train Acc: 4.04%
# Valid Loss: 0.4398 | Valid Acc: 4.23%
# [Epoch 310/500]
# Train Loss: 0.4403 | Train Acc: 4.04%
# Valid Loss: 0.4416 | Valid Acc: 4.23%
# [Epoch 311/500]
# Train Loss: 0.4402 | Train Acc: 4.04%
# Valid Loss: 0.4390 | Valid Acc: 4.23%
# [Epoch 312/500]
# Train Loss: 0.4386 | Train Acc: 4.09%
# Valid Loss: 0.4393 | Valid Acc: 4.23%
# [Epoch 313/500]
# Train Loss: 0.4394 | Train Acc: 4.09%
# Valid Loss: 0.4351 | Valid Acc: 4.23%
# [Epoch 314/500]
# Train Loss: 0.4362 | Train Acc: 4.04%
# Valid Loss: 0.4393 | Valid Acc: 4.23%
# [Epoch 315/500]
# Train Loss: 0.4378 | Train Acc: 4.13%
# Valid Loss: 0.4404 | Valid Acc: 4.23%
# [Epoch 316/500]
# Train Loss: 0.4387 | Train Acc: 4.13%
# Valid Loss: 0.4405 | Valid Acc: 4.23%
# [Epoch 317/500]
# Train Loss: 0.4391 | Train Acc: 4.09%
# Valid Loss: 0.4340 | Valid Acc: 4.23%
# [Epoch 318/500]
# Train Loss: 0.4390 | Train Acc: 4.13%
# Valid Loss: 0.4432 | Valid Acc: 4.23%
# [Epoch 319/500]
# Train Loss: 0.4400 | Train Acc: 4.18%
# Valid Loss: 0.4419 | Valid Acc: 4.23%
# [Epoch 320/500]
# Train Loss: 0.4351 | Train Acc: 4.13%
# Valid Loss: 0.4376 | Valid Acc: 4.23%
# [Epoch 321/500]
# Train Loss: 0.4401 | Train Acc: 4.23%
# Valid Loss: 0.4412 | Valid Acc: 4.23%
# [Epoch 322/500]
# Train Loss: 0.4414 | Train Acc: 4.18%
# Valid Loss: 0.4381 | Valid Acc: 4.23%
# [Epoch 323/500]
# Train Loss: 0.4390 | Train Acc: 4.13%
# Valid Loss: 0.4436 | Valid Acc: 4.23%
# [Epoch 324/500]
# Train Loss: 0.4400 | Train Acc: 4.09%
# Valid Loss: 0.4299 | Valid Acc: 4.23%
# [Epoch 325/500]
# Train Loss: 0.4409 | Train Acc: 4.13%
# Valid Loss: 0.4443 | Valid Acc: 4.23%
# [Epoch 326/500]
# Train Loss: 0.4415 | Train Acc: 4.23%
# Valid Loss: 0.4440 | Valid Acc: 4.23%
# [Epoch 327/500]
# Train Loss: 0.4378 | Train Acc: 4.28%
# Valid Loss: 0.4397 | Valid Acc: 4.23%
# [Epoch 328/500]
# Train Loss: 0.4379 | Train Acc: 4.38%
# Valid Loss: 0.4392 | Valid Acc: 4.23%
# [Epoch 329/500]
# Train Loss: 0.4391 | Train Acc: 4.28%
# Valid Loss: 0.4403 | Valid Acc: 4.23%
# [Epoch 330/500]
# Train Loss: 0.4378 | Train Acc: 4.33%
# Valid Loss: 0.4372 | Valid Acc: 4.23%
# [Epoch 331/500]
# Train Loss: 0.4422 | Train Acc: 4.13%
# Valid Loss: 0.4505 | Valid Acc: 4.23%
# [Epoch 332/500]
# Train Loss: 0.4361 | Train Acc: 4.18%
# Valid Loss: 0.4363 | Valid Acc: 4.23%
# [Epoch 333/500]
# Train Loss: 0.4416 | Train Acc: 4.23%
# Valid Loss: 0.4426 | Valid Acc: 4.23%
# [Epoch 334/500]
# Train Loss: 0.4386 | Train Acc: 4.28%
# Valid Loss: 0.4372 | Valid Acc: 4.23%
# [Epoch 335/500]
# Train Loss: 0.4375 | Train Acc: 4.28%
# Valid Loss: 0.4371 | Valid Acc: 4.23%
# [Epoch 336/500]
# Train Loss: 0.4385 | Train Acc: 4.28%
# Valid Loss: 0.4393 | Valid Acc: 4.23%
# [Epoch 337/500]
# Train Loss: 0.4353 | Train Acc: 4.13%
# Valid Loss: 0.4324 | Valid Acc: 4.23%
# [Epoch 338/500]
# Train Loss: 0.4377 | Train Acc: 4.33%
# Valid Loss: 0.4394 | Valid Acc: 4.23%
# [Epoch 339/500]
# Train Loss: 0.4376 | Train Acc: 4.23%
# Valid Loss: 0.4354 | Valid Acc: 4.23%
# [Epoch 340/500]
# Train Loss: 0.4382 | Train Acc: 4.23%
# Valid Loss: 0.4360 | Valid Acc: 4.23%
# [Epoch 341/500]
# Train Loss: 0.4400 | Train Acc: 4.23%
# Valid Loss: 0.4441 | Valid Acc: 4.23%
# [Epoch 342/500]
# Train Loss: 0.4361 | Train Acc: 4.18%
# Valid Loss: 0.4373 | Valid Acc: 4.04%
# [Epoch 343/500]
# Train Loss: 0.4393 | Train Acc: 4.23%
# Valid Loss: 0.4360 | Valid Acc: 4.23%
# [Epoch 344/500]
# Train Loss: 0.4427 | Train Acc: 4.23%
# Valid Loss: 0.4445 | Valid Acc: 4.42%
# [Epoch 345/500]
# Train Loss: 0.4411 | Train Acc: 4.33%
# Valid Loss: 0.4465 | Valid Acc: 4.04%
# [Epoch 346/500]
# Train Loss: 0.4399 | Train Acc: 4.33%
# Valid Loss: 0.4353 | Valid Acc: 4.04%
# [Epoch 347/500]
# Train Loss: 0.4389 | Train Acc: 4.33%
# Valid Loss: 0.4346 | Valid Acc: 4.23%
# [Epoch 348/500]
# Train Loss: 0.4380 | Train Acc: 4.38%
# Valid Loss: 0.4415 | Valid Acc: 4.04%
# [Epoch 349/500]
# Train Loss: 0.4378 | Train Acc: 4.23%
# Valid Loss: 0.4378 | Valid Acc: 4.23%
# [Epoch 350/500]
# Train Loss: 0.4424 | Train Acc: 4.23%
# Valid Loss: 0.4392 | Valid Acc: 4.04%
# [Epoch 351/500]
# Train Loss: 0.4409 | Train Acc: 4.28%
# Valid Loss: 0.4426 | Valid Acc: 4.04%
# [Epoch 352/500]
# Train Loss: 0.4401 | Train Acc: 4.23%
# Valid Loss: 0.4429 | Valid Acc: 4.04%
# [Epoch 353/500]
# Train Loss: 0.4365 | Train Acc: 4.28%
# Valid Loss: 0.4415 | Valid Acc: 4.04%
# [Epoch 354/500]
# Train Loss: 0.4388 | Train Acc: 4.18%
# Valid Loss: 0.4431 | Valid Acc: 4.04%
# [Epoch 355/500]
# Train Loss: 0.4369 | Train Acc: 4.13%
# Valid Loss: 0.4415 | Valid Acc: 4.42%
# [Epoch 356/500]
# Train Loss: 0.4390 | Train Acc: 4.13%
# Valid Loss: 0.4369 | Valid Acc: 4.42%
# [Epoch 357/500]
# Train Loss: 0.4377 | Train Acc: 4.23%
# Valid Loss: 0.4402 | Valid Acc: 4.23%
# [Epoch 358/500]
# Train Loss: 0.4400 | Train Acc: 4.18%
# Valid Loss: 0.4360 | Valid Acc: 4.23%
# [Epoch 359/500]
# Train Loss: 0.4362 | Train Acc: 4.18%
# Valid Loss: 0.4408 | Valid Acc: 4.23%
# [Epoch 360/500]
# Train Loss: 0.4361 | Train Acc: 4.09%
# Valid Loss: 0.4390 | Valid Acc: 4.04%
# [Epoch 361/500]
# Train Loss: 0.4350 | Train Acc: 4.13%
# Valid Loss: 0.4294 | Valid Acc: 4.04%
# [Epoch 362/500]
# Train Loss: 0.4385 | Train Acc: 4.13%
# Valid Loss: 0.4445 | Valid Acc: 4.23%
# [Epoch 363/500]
# Train Loss: 0.4380 | Train Acc: 4.18%
# Valid Loss: 0.4422 | Valid Acc: 4.23%
# [Epoch 364/500]
# Train Loss: 0.4388 | Train Acc: 4.09%
# Valid Loss: 0.4354 | Valid Acc: 4.23%
# [Epoch 365/500]
# Train Loss: 0.4405 | Train Acc: 4.28%
# Valid Loss: 0.4367 | Valid Acc: 4.04%
# [Epoch 366/500]
# Train Loss: 0.4390 | Train Acc: 4.28%
# Valid Loss: 0.4354 | Valid Acc: 4.23%
# [Epoch 367/500]
# Train Loss: 0.4400 | Train Acc: 4.28%
# Valid Loss: 0.4383 | Valid Acc: 4.23%
# [Epoch 368/500]
# Train Loss: 0.4369 | Train Acc: 4.28%
# Valid Loss: 0.4376 | Valid Acc: 4.23%
# [Epoch 369/500]
# Train Loss: 0.4338 | Train Acc: 4.13%
# Valid Loss: 0.4334 | Valid Acc: 4.23%
# [Epoch 370/500]
# Train Loss: 0.4389 | Train Acc: 4.13%
# Valid Loss: 0.4375 | Valid Acc: 4.04%
# [Epoch 371/500]
# Train Loss: 0.4400 | Train Acc: 4.28%
# Valid Loss: 0.4353 | Valid Acc: 4.04%
# [Epoch 372/500]
# Train Loss: 0.4359 | Train Acc: 4.18%
# Valid Loss: 0.4349 | Valid Acc: 4.04%
# [Epoch 373/500]
# Train Loss: 0.4385 | Train Acc: 4.13%
# Valid Loss: 0.4360 | Valid Acc: 4.23%
# [Epoch 374/500]
# Train Loss: 0.4385 | Train Acc: 4.18%
# Valid Loss: 0.4385 | Valid Acc: 4.23%
# [Epoch 375/500]
# Train Loss: 0.4379 | Train Acc: 4.18%
# Valid Loss: 0.4349 | Valid Acc: 4.23%
# [Epoch 376/500]
# Train Loss: 0.4385 | Train Acc: 4.33%
# Valid Loss: 0.4436 | Valid Acc: 4.23%
# [Epoch 377/500]
# Train Loss: 0.4377 | Train Acc: 4.18%
# Valid Loss: 0.4394 | Valid Acc: 4.23%
# [Epoch 378/500]
# Train Loss: 0.4350 | Train Acc: 4.13%
# Valid Loss: 0.4429 | Valid Acc: 4.23%
# [Epoch 379/500]
# Train Loss: 0.4394 | Train Acc: 4.09%
# Valid Loss: 0.4300 | Valid Acc: 4.23%
# [Epoch 380/500]
# Train Loss: 0.4407 | Train Acc: 4.23%
# Valid Loss: 0.4285 | Valid Acc: 4.23%
# [Epoch 381/500]
# Train Loss: 0.4371 | Train Acc: 4.13%
# Valid Loss: 0.4337 | Valid Acc: 4.23%
# [Epoch 382/500]
# Train Loss: 0.4378 | Train Acc: 4.18%
# Valid Loss: 0.4440 | Valid Acc: 4.23%
# [Epoch 383/500]
# Train Loss: 0.4393 | Train Acc: 4.23%
# Valid Loss: 0.4384 | Valid Acc: 4.04%
# [Epoch 384/500]
# Train Loss: 0.4388 | Train Acc: 4.33%
# Valid Loss: 0.4441 | Valid Acc: 4.04%
# [Epoch 385/500]
# Train Loss: 0.4391 | Train Acc: 4.18%
# Valid Loss: 0.4344 | Valid Acc: 4.04%
# [Epoch 386/500]
# Train Loss: 0.4346 | Train Acc: 4.23%
# Valid Loss: 0.4398 | Valid Acc: 4.04%
# [Epoch 387/500]
# Train Loss: 0.4434 | Train Acc: 4.18%
# Valid Loss: 0.4325 | Valid Acc: 4.23%
# [Epoch 388/500]
# Train Loss: 0.4403 | Train Acc: 4.13%
# Valid Loss: 0.4363 | Valid Acc: 4.04%
# [Epoch 389/500]
# Train Loss: 0.4376 | Train Acc: 4.04%
# Valid Loss: 0.4376 | Valid Acc: 4.04%
# [Epoch 390/500]
# Train Loss: 0.4404 | Train Acc: 4.09%
# Valid Loss: 0.4430 | Valid Acc: 4.04%
# [Epoch 391/500]
# Train Loss: 0.4394 | Train Acc: 4.09%
# Valid Loss: 0.4421 | Valid Acc: 4.04%
# [Epoch 392/500]
# Train Loss: 0.4359 | Train Acc: 4.04%
# Valid Loss: 0.4432 | Valid Acc: 4.04%
# [Epoch 393/500]
# Train Loss: 0.4379 | Train Acc: 4.23%
# Valid Loss: 0.4357 | Valid Acc: 3.85%
# [Epoch 394/500]
# Train Loss: 0.4377 | Train Acc: 4.09%
# Valid Loss: 0.4336 | Valid Acc: 4.04%
# [Epoch 395/500]
# Train Loss: 0.4389 | Train Acc: 4.13%
# Valid Loss: 0.4411 | Valid Acc: 4.04%
# [Epoch 396/500]
# Train Loss: 0.4373 | Train Acc: 4.09%
# Valid Loss: 0.4316 | Valid Acc: 4.04%
# [Epoch 397/500]
# Train Loss: 0.4390 | Train Acc: 4.09%
# Valid Loss: 0.4410 | Valid Acc: 3.85%
# [Epoch 398/500]
# Train Loss: 0.4406 | Train Acc: 4.09%
# Valid Loss: 0.4465 | Valid Acc: 4.04%
# [Epoch 399/500]
# Train Loss: 0.4385 | Train Acc: 4.09%
# Valid Loss: 0.4411 | Valid Acc: 4.04%
# [Epoch 400/500]
# Train Loss: 0.4403 | Train Acc: 4.13%
# Valid Loss: 0.4410 | Valid Acc: 4.04%
# [Epoch 401/500]
# Train Loss: 0.4398 | Train Acc: 4.13%
# Valid Loss: 0.4323 | Valid Acc: 4.04%
# [Epoch 402/500]
# Train Loss: 0.4388 | Train Acc: 4.13%
# Valid Loss: 0.4445 | Valid Acc: 4.04%
# [Epoch 403/500]
# Train Loss: 0.4354 | Train Acc: 4.18%
# Valid Loss: 0.4352 | Valid Acc: 4.23%
# [Epoch 404/500]
# Train Loss: 0.4375 | Train Acc: 4.28%
# Valid Loss: 0.4359 | Valid Acc: 4.23%
# [Epoch 405/500]
# Train Loss: 0.4375 | Train Acc: 4.18%
# Valid Loss: 0.4345 | Valid Acc: 4.23%
# [Epoch 406/500]
# Train Loss: 0.4393 | Train Acc: 4.18%
# Valid Loss: 0.4408 | Valid Acc: 4.23%
# [Epoch 407/500]
# Train Loss: 0.4391 | Train Acc: 4.23%
# Valid Loss: 0.4396 | Valid Acc: 4.23%
# [Epoch 408/500]
# Train Loss: 0.4355 | Train Acc: 4.09%
# Valid Loss: 0.4351 | Valid Acc: 4.23%
# [Epoch 409/500]
# Train Loss: 0.4366 | Train Acc: 4.09%
# Valid Loss: 0.4459 | Valid Acc: 4.04%
# [Epoch 410/500]
# Train Loss: 0.4401 | Train Acc: 4.18%
# Valid Loss: 0.4398 | Valid Acc: 4.23%
# [Epoch 411/500]
# Train Loss: 0.4392 | Train Acc: 4.09%
# Valid Loss: 0.4429 | Valid Acc: 4.04%
# [Epoch 412/500]
# Train Loss: 0.4403 | Train Acc: 4.23%
# Valid Loss: 0.4459 | Valid Acc: 4.23%
# [Epoch 413/500]
# Train Loss: 0.4398 | Train Acc: 4.09%
# Valid Loss: 0.4331 | Valid Acc: 4.23%
# [Epoch 414/500]
# Train Loss: 0.4380 | Train Acc: 4.23%
# Valid Loss: 0.4462 | Valid Acc: 4.23%
# [Epoch 415/500]
# Train Loss: 0.4386 | Train Acc: 4.28%
# Valid Loss: 0.4411 | Valid Acc: 4.23%
# [Epoch 416/500]
# Train Loss: 0.4403 | Train Acc: 4.04%
# Valid Loss: 0.4363 | Valid Acc: 4.23%
# [Epoch 417/500]
# Train Loss: 0.4366 | Train Acc: 4.18%
# Valid Loss: 0.4370 | Valid Acc: 4.23%
# [Epoch 418/500]
# Train Loss: 0.4369 | Train Acc: 4.18%
# Valid Loss: 0.4318 | Valid Acc: 4.04%
# [Epoch 419/500]
# Train Loss: 0.4411 | Train Acc: 4.18%
# Valid Loss: 0.4395 | Valid Acc: 4.04%
# [Epoch 420/500]
# Train Loss: 0.4393 | Train Acc: 4.13%
# Valid Loss: 0.4425 | Valid Acc: 4.23%
# [Epoch 421/500]
# Train Loss: 0.4389 | Train Acc: 4.13%
# Valid Loss: 0.4404 | Valid Acc: 4.04%
# [Epoch 422/500]
# Train Loss: 0.4419 | Train Acc: 4.33%
# Valid Loss: 0.4426 | Valid Acc: 4.04%
# [Epoch 423/500]
# Train Loss: 0.4434 | Train Acc: 4.28%
# Valid Loss: 0.4393 | Valid Acc: 4.04%
# [Epoch 424/500]
# Train Loss: 0.4384 | Train Acc: 4.28%
# Valid Loss: 0.4338 | Valid Acc: 4.04%
# [Epoch 425/500]
# Train Loss: 0.4413 | Train Acc: 4.23%
# Valid Loss: 0.4357 | Valid Acc: 3.85%
# [Epoch 426/500]
# Train Loss: 0.4395 | Train Acc: 4.33%
# Valid Loss: 0.4339 | Valid Acc: 4.04%
# [Epoch 427/500]
# Train Loss: 0.4404 | Train Acc: 4.18%
# Valid Loss: 0.4359 | Valid Acc: 4.23%
# [Epoch 428/500]
# Train Loss: 0.4361 | Train Acc: 4.28%
# Valid Loss: 0.4408 | Valid Acc: 4.04%
# [Epoch 429/500]
# Train Loss: 0.4391 | Train Acc: 4.18%
# Valid Loss: 0.4347 | Valid Acc: 4.23%
# [Epoch 430/500]
# Train Loss: 0.4429 | Train Acc: 4.23%
# Valid Loss: 0.4456 | Valid Acc: 3.85%
# [Epoch 431/500]
# Train Loss: 0.4419 | Train Acc: 4.09%
# Valid Loss: 0.4344 | Valid Acc: 3.85%
# [Epoch 432/500]
# Train Loss: 0.4403 | Train Acc: 4.13%
# Valid Loss: 0.4509 | Valid Acc: 3.85%
# [Epoch 433/500]
# Train Loss: 0.4412 | Train Acc: 4.18%
# Valid Loss: 0.4442 | Valid Acc: 4.04%
# [Epoch 434/500]
# Train Loss: 0.4407 | Train Acc: 4.23%
# Valid Loss: 0.4453 | Valid Acc: 4.04%
# [Epoch 435/500]
# Train Loss: 0.4372 | Train Acc: 4.28%
# Valid Loss: 0.4398 | Valid Acc: 4.04%
# [Epoch 436/500]
# Train Loss: 0.4407 | Train Acc: 4.23%
# Valid Loss: 0.4403 | Valid Acc: 3.85%
# [Epoch 437/500]
# Train Loss: 0.4383 | Train Acc: 4.13%
# Valid Loss: 0.4381 | Valid Acc: 4.04%
# [Epoch 438/500]
# Train Loss: 0.4396 | Train Acc: 4.18%
# Valid Loss: 0.4396 | Valid Acc: 4.04%
# [Epoch 439/500]
# Train Loss: 0.4401 | Train Acc: 4.28%
# Valid Loss: 0.4470 | Valid Acc: 3.85%
# [Epoch 440/500]
# Train Loss: 0.4387 | Train Acc: 4.18%
# Valid Loss: 0.4445 | Valid Acc: 4.04%
# [Epoch 441/500]
# Train Loss: 0.4401 | Train Acc: 4.18%
# Valid Loss: 0.4394 | Valid Acc: 3.85%
# [Epoch 442/500]
# Train Loss: 0.4415 | Train Acc: 4.13%
# Valid Loss: 0.4423 | Valid Acc: 3.85%
# [Epoch 443/500]
# Train Loss: 0.4384 | Train Acc: 4.09%
# Valid Loss: 0.4416 | Valid Acc: 3.65%
# [Epoch 444/500]
# Train Loss: 0.4385 | Train Acc: 4.13%
# Valid Loss: 0.4342 | Valid Acc: 3.85%
# [Epoch 445/500]
# Train Loss: 0.4358 | Train Acc: 4.23%
# Valid Loss: 0.4404 | Valid Acc: 4.04%
# [Epoch 446/500]
# Train Loss: 0.4391 | Train Acc: 4.23%
# Valid Loss: 0.4365 | Valid Acc: 4.04%
# [Epoch 447/500]
# Train Loss: 0.4364 | Train Acc: 4.23%
# Valid Loss: 0.4437 | Valid Acc: 4.04%
# [Epoch 448/500]
# Train Loss: 0.4374 | Train Acc: 4.13%
# Valid Loss: 0.4400 | Valid Acc: 4.04%
# [Epoch 449/500]
# Train Loss: 0.4384 | Train Acc: 4.18%
# Valid Loss: 0.4355 | Valid Acc: 4.04%
# [Epoch 450/500]
# Train Loss: 0.4364 | Train Acc: 4.28%
# Valid Loss: 0.4358 | Valid Acc: 3.85%
# [Epoch 451/500]
# Train Loss: 0.4340 | Train Acc: 4.04%
# Valid Loss: 0.4341 | Valid Acc: 4.42%
# [Epoch 452/500]
# Train Loss: 0.4382 | Train Acc: 4.28%
# Valid Loss: 0.4400 | Valid Acc: 3.85%
# [Epoch 453/500]
# Train Loss: 0.4352 | Train Acc: 4.18%
# Valid Loss: 0.4391 | Valid Acc: 4.04%
# [Epoch 454/500]
# Train Loss: 0.4387 | Train Acc: 4.13%
# Valid Loss: 0.4372 | Valid Acc: 3.85%
# [Epoch 455/500]
# Train Loss: 0.4368 | Train Acc: 4.18%
# Valid Loss: 0.4405 | Valid Acc: 4.23%
# [Epoch 456/500]
# Train Loss: 0.4332 | Train Acc: 4.13%
# Valid Loss: 0.4451 | Valid Acc: 4.23%
# [Epoch 457/500]
# Train Loss: 0.4381 | Train Acc: 4.18%
# Valid Loss: 0.4394 | Valid Acc: 3.85%
# [Epoch 458/500]
# Train Loss: 0.4364 | Train Acc: 4.18%
# Valid Loss: 0.4432 | Valid Acc: 4.23%
# [Epoch 459/500]
# Train Loss: 0.4356 | Train Acc: 4.18%
# Valid Loss: 0.4431 | Valid Acc: 3.85%
# [Epoch 460/500]
# Train Loss: 0.4344 | Train Acc: 4.13%
# Valid Loss: 0.4339 | Valid Acc: 4.42%
# [Epoch 461/500]
# Train Loss: 0.4391 | Train Acc: 4.23%
# Valid Loss: 0.4427 | Valid Acc: 4.23%
# [Epoch 462/500]
# Train Loss: 0.4388 | Train Acc: 4.23%
# Valid Loss: 0.4338 | Valid Acc: 4.42%
# [Epoch 463/500]
# Train Loss: 0.4370 | Train Acc: 4.18%
# Valid Loss: 0.4317 | Valid Acc: 4.23%
# [Epoch 464/500]
# Train Loss: 0.4372 | Train Acc: 4.28%
# Valid Loss: 0.4396 | Valid Acc: 4.04%
# [Epoch 465/500]
# Train Loss: 0.4384 | Train Acc: 4.23%
# Valid Loss: 0.4424 | Valid Acc: 4.23%
# [Epoch 466/500]
# Train Loss: 0.4364 | Train Acc: 4.28%
# Valid Loss: 0.4394 | Valid Acc: 4.04%
# [Epoch 467/500]
# Train Loss: 0.4381 | Train Acc: 4.18%
# Valid Loss: 0.4401 | Valid Acc: 4.23%
# [Epoch 468/500]
# Train Loss: 0.4381 | Train Acc: 4.23%
# Valid Loss: 0.4430 | Valid Acc: 4.23%
# [Epoch 469/500]
# Train Loss: 0.4409 | Train Acc: 4.28%
# Valid Loss: 0.4382 | Valid Acc: 4.04%
# [Epoch 470/500]
# Train Loss: 0.4390 | Train Acc: 4.18%
# Valid Loss: 0.4417 | Valid Acc: 4.04%
# [Epoch 471/500]
# Train Loss: 0.4433 | Train Acc: 4.18%
# Valid Loss: 0.4354 | Valid Acc: 4.23%
# [Epoch 472/500]
# Train Loss: 0.4363 | Train Acc: 4.28%
# Valid Loss: 0.4385 | Valid Acc: 4.23%
# [Epoch 473/500]
# Train Loss: 0.4361 | Train Acc: 4.09%
# Valid Loss: 0.4376 | Valid Acc: 4.04%
# [Epoch 474/500]
# Train Loss: 0.4354 | Train Acc: 4.13%
# Valid Loss: 0.4361 | Valid Acc: 4.04%
# [Epoch 475/500]
# Train Loss: 0.4373 | Train Acc: 4.04%
# Valid Loss: 0.4281 | Valid Acc: 3.85%
# [Epoch 476/500]
# Train Loss: 0.4418 | Train Acc: 4.04%
# Valid Loss: 0.4336 | Valid Acc: 3.85%
# [Epoch 477/500]
# Train Loss: 0.4376 | Train Acc: 4.13%
# Valid Loss: 0.4437 | Valid Acc: 4.04%
# [Epoch 478/500]
# Train Loss: 0.4353 | Train Acc: 4.13%
# Valid Loss: 0.4404 | Valid Acc: 4.04%
# [Epoch 479/500]
# Train Loss: 0.4396 | Train Acc: 4.23%
# Valid Loss: 0.4391 | Valid Acc: 4.23%
# [Epoch 480/500]
# Train Loss: 0.4400 | Train Acc: 4.09%
# Valid Loss: 0.4353 | Valid Acc: 4.04%
# [Epoch 481/500]
# Train Loss: 0.4397 | Train Acc: 4.13%
# Valid Loss: 0.4386 | Valid Acc: 4.04%
# [Epoch 482/500]
# Train Loss: 0.4426 | Train Acc: 4.23%
# Valid Loss: 0.4369 | Valid Acc: 4.23%
# [Epoch 483/500]
# Train Loss: 0.4369 | Train Acc: 4.13%
# Valid Loss: 0.4402 | Valid Acc: 4.04%
# [Epoch 484/500]
# Train Loss: 0.4381 | Train Acc: 4.18%
# Valid Loss: 0.4439 | Valid Acc: 4.04%
# [Epoch 485/500]
# Train Loss: 0.4394 | Train Acc: 4.18%
# Valid Loss: 0.4509 | Valid Acc: 3.85%
# [Epoch 486/500]
# Train Loss: 0.4426 | Train Acc: 4.13%
# Valid Loss: 0.4446 | Valid Acc: 3.85%
# [Epoch 487/500]
# Train Loss: 0.4397 | Train Acc: 4.13%
# Valid Loss: 0.4414 | Valid Acc: 4.23%
# [Epoch 488/500]
# Train Loss: 0.4401 | Train Acc: 4.23%
# Valid Loss: 0.4367 | Valid Acc: 4.04%
# [Epoch 489/500]
# Train Loss: 0.4395 | Train Acc: 4.23%
# Valid Loss: 0.4375 | Valid Acc: 4.04%
# [Epoch 490/500]
# Train Loss: 0.4361 | Train Acc: 4.23%
# Valid Loss: 0.4409 | Valid Acc: 4.04%
# [Epoch 491/500]
# Train Loss: 0.4394 | Train Acc: 4.23%
# Valid Loss: 0.4398 | Valid Acc: 4.04%
# [Epoch 492/500]
# Train Loss: 0.4397 | Train Acc: 4.28%
# Valid Loss: 0.4369 | Valid Acc: 4.04%
# [Epoch 493/500]
# Train Loss: 0.4373 | Train Acc: 4.28%
# Valid Loss: 0.4430 | Valid Acc: 4.04%
# [Epoch 494/500]
# Train Loss: 0.4362 | Train Acc: 4.23%
# Valid Loss: 0.4391 | Valid Acc: 4.04%
# [Epoch 495/500]
# Train Loss: 0.4398 | Train Acc: 4.33%
# Valid Loss: 0.4368 | Valid Acc: 4.23%
# [Epoch 496/500]
# Train Loss: 0.4378 | Train Acc: 4.28%
# Valid Loss: 0.4416 | Valid Acc: 4.04%
# [Epoch 497/500]
# Train Loss: 0.4353 | Train Acc: 4.28%
# Valid Loss: 0.4433 | Valid Acc: 4.04%
# [Epoch 498/500]
# Train Loss: 0.4391 | Train Acc: 4.33%
# Valid Loss: 0.4358 | Valid Acc: 4.04%
# [Epoch 499/500]
# Train Loss: 0.4371 | Train Acc: 4.33%
# Valid Loss: 0.4346 | Valid Acc: 3.85%
# [Epoch 500/500]
# Train Loss: 0.4381 | Train Acc: 4.18%
# Valid Loss: 0.4380 | Valid Acc: 4.04%

# %%
#val_losses = []
#val_accuracies = []
#initializer = RandomNormal(mean=0.0, stddev=0.1)

# %%
def evaluate2(diffe, ddpm, EEGNet, generator, device):
    labels = np.arange(0, 26)
    Y = []
    Y_hat = []
    for x, y in generator:
        x, y = x.to(device), y.type(torch.LongTensor).to(device)
        y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

        x_hat, down, up, noise, t = ddpm(x)

        # Align the temporal dimension of x_hat and x
        x_hat, x = safe_align_2d(x_hat, x)

        ddpm_out = x_hat, down, up, t
        #ddpm_out = x, down, up, t

        decoder_out, fc_out = diffe(x, ddpm_out)
        
        X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
        #X_eegnet = x.view(x.size(0), 64, -1)
        y_hat = EEGNet(X_eegnet)
        
        y_hat = F.softmax(y_hat, dim=1)

        Y.append(y.detach().cpu())
        Y_hat.append(y_hat.detach().cpu())

    # List of tensors to tensor to numpy
    Y = torch.cat(Y, dim=0).numpy()  # (N, )
    Y_hat = torch.cat(Y_hat, dim=0).numpy()  # (N, 13): has to sum to 1 for each row

    # Accuracy and Confusion Matrix
    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    f1 = f1_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    recall = recall_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    precision = precision_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels, zero_division=0)
    auc = roc_auc_score(Y, Y_hat, average="macro", multi_class="ovo", labels=labels)

    metrics = {
        "accuracy": accuracy,
        "f1": f1,
        "recall": recall,
        "precision": precision,
        "auc": auc,
    }
    # df_cm = pd.DataFrame(confusion_matrix(Y, Y_hat.argmax(axis=1)))
    return metrics

# %%
# Train & Evaluate
'''args = argparse.Namespace()
args.device = device
args.subject = "ALL"
args.root_dir = subject_chars_dir
subject = args.subject'''

num_epochs = 100
test_period = 1
start_test = test_period
alpha = 1
beta = 0

'''best_acc = 0
best_f1 = 0
best_recall = 0
best_precision = 0
best_auc = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}'''

with tqdm(total=num_epochs, desc=f"Method ALL - Joint Training on All Subjects - EEGNet") as pbar:
    for epoch in range(num_epochs):
        ddpm.train()
        diffe.train()
        eegnet_model.train()

        epoch_loss = 0
        num_batches = 0
        epoch_acc = 0
        total_samples = 0

        ############################## Train ###########################################
        for x, y in train_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

            x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            x_hat, x = safe_align_2d(x_hat, x)

            ddpm_out = x_hat, down, up, t

            # Train Diff-E
            decoder_out, fc_out = diffe(x, ddpm_out)

            # EMA update
            #fc_ema.update()
            #print(decoder_out.shape)
            X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
            #print(X_eegnet.shape)
            outputs = eegnet_model(X_eegnet)

            X_eegnet2 = x.view(x.size(0), 64, -1)
            outputs2 = eegnet_model(X_eegnet2)
            
            loss = criterion_eeg(outputs, y_cat) + criterion_eeg(outputs2, y_cat)
            optimizer_eeg.zero_grad()
            loss.backward()
            optimizer_eeg.step()

            epoch_loss += loss.item()
            num_batches += 1

            pred_labels = torch.argmax(outputs, dim=1)
            correct = (pred_labels == y).sum().item()
            epoch_acc += correct
            total_samples += y.size(0)

        history["train_loss"].append(epoch_loss / num_batches)
        history["train_acc"].append(epoch_acc / total_samples)

        metrics = {
            'train_loss': history["train_loss"][-1],
            'train_acc': history["train_acc"][-1],
        }

        ############################## validation ###########################################
        eegnet_model.eval()
        with torch.no_grad():
            if epoch > start_test:
                test_period = 1
            if epoch % test_period == 0:
                ddpm.eval()
                diffe.eval()

                metrics_val = evaluate2(diffe, ddpm, eegnet_model, val_loader, device)

                val_acc = metrics_val["accuracy"]
                history["val_acc"].append(val_acc)
                f1 = metrics_val["f1"]
                recall = metrics_val["recall"]
                precision = metrics_val["precision"]
                auc = metrics_val["auc"]

                val_loss = 0
                with torch.no_grad():
                    for x, y in val_loader:
                        x, y = x.to(device), y.type(torch.LongTensor).to(device)
                        y_cat = F.one_hot(y, num_classes=26).float().to(device)

                        x_hat, down, up, noise, t = ddpm(x)
                        
                        # Align the temporal dimension of x_hat and x
                        x_hat, x = safe_align_2d(x_hat, x)
                        
                        ddpm_out = x_hat, down, up, t
                        #ddpm_out = x, down, up, t

                        decoder_out, fc_out = diffe(x, ddpm_out)

                        X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
                        #X_eegnet = x.view(x.size(0), 64, -1)
                        outputs = eegnet_model(X_eegnet)

                        val_loss += criterion_eeg(outputs, y).item()

                history["val_loss"].append(val_loss / len(val_loader))


                metrics.update({
                    'valid_loss': history["val_loss"][-1],
                    'valid_acc': val_acc,
                })

                best_acc_bool = val_acc > best_acc
                best_f1_bool = f1 > best_f1
                best_recall_bool = recall > best_recall
                best_precision_bool = precision > best_precision
                best_auc_bool = auc > best_auc

                save_model(eegnet_model, optimizer_eeg, scheduler_eeg, metrics, epoch, os.path.join(checkpoint_dir, 'eegnet_all_subjects.pth'))

                if best_acc_bool:
                    best_acc = val_acc
                    #torch.save(diffe.state_dict(), f'/content/drive/MyDrive/project/model/ssvep/diffe_{subject}.pth')
                    #torch.save(diffe.state_dict(), '/content/drive/MyDrive/project/model/ssvep/diffe_all_subjects.pth')
                    #torch.save(eegnet_model.state_dict(), r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated\eegnet_model_all_subjects.pth')
                    save_model(eegnet_model, optimizer_eeg, scheduler_eeg, metrics, epoch, os.path.join(checkpoint_dir, 'best_eegnet_all_subjects.pth'))
                if best_f1_bool:
                    best_f1 = f1
                if best_recall_bool:
                    best_recall = recall
                if best_precision_bool:
                    best_precision = precision
                if best_auc_bool:
                    best_auc = auc

                description = f"Val Accuracy: {val_acc*100:.2f}% | Best: {best_acc*100:.2f}%"
                pbar.set_description(f"Method ALL – Processing subject {subject} – {description}"
                )
        print(f"[Epoch {epoch+1}/{num_epochs}]")
        print(f"Train Loss: {history['train_loss'][-1]:.4f} | Train Acc: {history['train_acc'][-1]*100:.2f}%")
        print(f"Valid Loss: {history['val_loss'][-1]:.4f} | Valid Acc: {val_acc*100:.2f}%")
        pbar.update(1)

        if run is not None:
            run.log(metrics)
# Out:
# Method ALL - Joint Training on All Subjects - EEGNet:   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 1/100]
# Train Loss: 6.5386 | Train Acc: 4.81%
# Valid Loss: 3.1841 | Valid Acc: 10.58%
# [Epoch 2/100]
# Train Loss: 5.8415 | Train Acc: 11.63%
# Valid Loss: 2.6974 | Valid Acc: 20.96%
# [Epoch 3/100]
# Train Loss: 4.9957 | Train Acc: 18.99%
# Valid Loss: 2.4821 | Valid Acc: 22.31%
# [Epoch 4/100]
# Train Loss: 4.6420 | Train Acc: 21.44%
# Valid Loss: 2.3557 | Valid Acc: 25.96%
# [Epoch 5/100]
# Train Loss: 4.3985 | Train Acc: 23.89%
# Valid Loss: 2.2782 | Valid Acc: 22.88%
# [Epoch 6/100]
# Train Loss: 4.2508 | Train Acc: 25.62%
# Valid Loss: 2.2490 | Valid Acc: 28.27%
# [Epoch 7/100]
# Train Loss: 4.1068 | Train Acc: 27.40%
# Valid Loss: 2.2329 | Valid Acc: 25.58%
# [Epoch 8/100]
# Train Loss: 4.0221 | Train Acc: 28.12%
# Valid Loss: 2.1764 | Valid Acc: 27.12%
# [Epoch 9/100]
# Train Loss: 3.9594 | Train Acc: 27.45%
# Valid Loss: 2.1351 | Valid Acc: 28.46%
# [Epoch 10/100]
# Train Loss: 3.8396 | Train Acc: 30.72%
# Valid Loss: 2.0922 | Valid Acc: 30.58%
# [Epoch 11/100]
# Train Loss: 3.8265 | Train Acc: 30.19%
# Valid Loss: 2.1476 | Valid Acc: 30.19%
# [Epoch 12/100]
# Train Loss: 3.7492 | Train Acc: 30.00%
# Valid Loss: 2.1196 | Valid Acc: 30.38%
# [Epoch 13/100]
# Train Loss: 3.6858 | Train Acc: 30.14%
# Valid Loss: 2.1112 | Valid Acc: 31.35%
# [Epoch 14/100]
# Train Loss: 3.6589 | Train Acc: 32.12%
# Valid Loss: 2.0934 | Valid Acc: 27.69%
# [Epoch 15/100]
# Train Loss: 3.6511 | Train Acc: 30.63%
# Valid Loss: 2.0529 | Valid Acc: 29.81%
# [Epoch 16/100]
# Train Loss: 3.5522 | Train Acc: 33.46%
# Valid Loss: 2.1013 | Valid Acc: 31.35%
# [Epoch 17/100]
# Train Loss: 3.5642 | Train Acc: 31.73%
# Valid Loss: 2.0354 | Valid Acc: 28.85%
# [Epoch 18/100]
# Train Loss: 3.5338 | Train Acc: 33.80%
# Valid Loss: 2.0468 | Valid Acc: 29.62%
# [Epoch 19/100]
# Train Loss: 3.5226 | Train Acc: 32.84%
# Valid Loss: 2.0774 | Valid Acc: 28.85%
# [Epoch 20/100]
# Train Loss: 3.4902 | Train Acc: 33.32%
# Valid Loss: 2.0194 | Valid Acc: 31.54%
# [Epoch 21/100]
# Train Loss: 3.4139 | Train Acc: 35.00%
# Valid Loss: 2.0202 | Valid Acc: 30.58%
# [Epoch 22/100]
# Train Loss: 3.4616 | Train Acc: 34.90%
# Valid Loss: 2.0367 | Valid Acc: 30.19%
# [Epoch 23/100]
# Train Loss: 3.4112 | Train Acc: 33.99%
# Valid Loss: 2.0886 | Valid Acc: 31.54%
# [Epoch 24/100]
# Train Loss: 3.4260 | Train Acc: 33.27%
# Valid Loss: 2.0698 | Valid Acc: 31.73%
# [Epoch 25/100]
# Train Loss: 3.3945 | Train Acc: 34.57%
# Valid Loss: 2.0103 | Valid Acc: 31.73%
# [Epoch 26/100]
# Train Loss: 3.3601 | Train Acc: 33.89%
# Valid Loss: 2.0109 | Valid Acc: 31.15%
# [Epoch 27/100]
# Train Loss: 3.3122 | Train Acc: 35.67%
# Valid Loss: 2.0423 | Valid Acc: 30.58%
# [Epoch 28/100]
# Train Loss: 3.3037 | Train Acc: 36.39%
# Valid Loss: 1.9946 | Valid Acc: 30.00%
# [Epoch 29/100]
# Train Loss: 3.3460 | Train Acc: 35.62%
# Valid Loss: 1.9862 | Valid Acc: 34.04%
# [Epoch 30/100]
# Train Loss: 3.3247 | Train Acc: 35.00%
# Valid Loss: 2.0257 | Valid Acc: 32.50%
# [Epoch 31/100]
# Train Loss: 3.2625 | Train Acc: 36.20%
# Valid Loss: 2.0335 | Valid Acc: 29.81%
# [Epoch 32/100]
# Train Loss: 3.2592 | Train Acc: 37.07%
# Valid Loss: 2.0779 | Valid Acc: 32.50%
# [Epoch 33/100]
# Train Loss: 3.2596 | Train Acc: 35.29%
# Valid Loss: 1.9788 | Valid Acc: 28.65%
# [Epoch 34/100]
# Train Loss: 3.2697 | Train Acc: 34.90%
# Valid Loss: 2.0634 | Valid Acc: 28.65%
# [Epoch 35/100]
# Train Loss: 3.1931 | Train Acc: 36.39%
# Valid Loss: 2.0156 | Valid Acc: 31.73%
# [Epoch 36/100]
# Train Loss: 3.2610 | Train Acc: 34.42%
# Valid Loss: 2.0087 | Valid Acc: 29.81%
# [Epoch 37/100]
# Train Loss: 3.2384 | Train Acc: 35.43%
# Valid Loss: 2.0050 | Valid Acc: 32.12%
# [Epoch 38/100]
# Train Loss: 3.2109 | Train Acc: 36.54%
# Valid Loss: 2.0036 | Valid Acc: 33.08%
# [Epoch 39/100]
# Train Loss: 3.2011 | Train Acc: 37.21%
# Valid Loss: 2.0373 | Valid Acc: 33.46%
# [Epoch 40/100]
# Train Loss: 3.2014 | Train Acc: 36.63%
# Valid Loss: 1.9883 | Valid Acc: 32.31%
# [Epoch 41/100]
# Train Loss: 3.1629 | Train Acc: 36.59%
# Valid Loss: 1.9618 | Valid Acc: 30.58%
# [Epoch 42/100]
# Train Loss: 3.1884 | Train Acc: 35.82%
# Valid Loss: 2.0033 | Valid Acc: 29.04%
# [Epoch 43/100]
# Train Loss: 3.1689 | Train Acc: 36.39%
# Valid Loss: 1.9769 | Valid Acc: 33.65%
# [Epoch 44/100]
# Train Loss: 3.1718 | Train Acc: 36.88%
# Valid Loss: 1.9626 | Valid Acc: 31.92%
# [Epoch 45/100]
# Train Loss: 3.1249 | Train Acc: 37.60%
# Valid Loss: 2.0322 | Valid Acc: 33.08%
# [Epoch 46/100]
# Train Loss: 3.1298 | Train Acc: 37.64%
# Valid Loss: 1.9546 | Valid Acc: 32.31%
# [Epoch 47/100]
# Train Loss: 3.1543 | Train Acc: 36.68%
# Valid Loss: 1.9348 | Valid Acc: 30.38%
# [Epoch 48/100]
# Train Loss: 3.1259 | Train Acc: 38.08%
# Valid Loss: 2.0043 | Valid Acc: 33.65%
# [Epoch 49/100]
# Train Loss: 3.0789 | Train Acc: 38.56%
# Valid Loss: 1.9638 | Valid Acc: 32.88%
# [Epoch 50/100]
# Train Loss: 3.1364 | Train Acc: 37.26%
# Valid Loss: 1.9504 | Valid Acc: 30.58%
# [Epoch 51/100]
# Train Loss: 3.0714 | Train Acc: 37.07%
# Valid Loss: 1.9135 | Valid Acc: 31.92%
# [Epoch 52/100]
# Train Loss: 3.0900 | Train Acc: 37.36%
# Valid Loss: 1.9665 | Valid Acc: 33.65%
# [Epoch 53/100]
# Train Loss: 3.0930 | Train Acc: 36.73%
# Valid Loss: 1.9880 | Valid Acc: 32.12%
# [Epoch 54/100]
# Train Loss: 3.0851 | Train Acc: 37.02%
# Valid Loss: 1.9728 | Valid Acc: 34.04%
# [Epoch 55/100]
# Train Loss: 3.0964 | Train Acc: 36.49%
# Valid Loss: 1.9820 | Valid Acc: 34.04%
# [Epoch 56/100]
# Train Loss: 3.0413 | Train Acc: 37.45%
# Valid Loss: 1.9768 | Valid Acc: 35.38%
# [Epoch 57/100]
# Train Loss: 3.0779 | Train Acc: 38.12%
# Valid Loss: 1.9771 | Valid Acc: 35.19%
# [Epoch 58/100]
# Train Loss: 3.0329 | Train Acc: 38.27%
# Valid Loss: 1.9620 | Valid Acc: 34.23%
# [Epoch 59/100]
# Train Loss: 3.0159 | Train Acc: 37.02%
# Valid Loss: 1.9366 | Valid Acc: 31.92%
# [Epoch 60/100]
# Train Loss: 3.0552 | Train Acc: 37.45%
# Valid Loss: 1.9126 | Valid Acc: 34.23%
# [Epoch 61/100]
# Train Loss: 3.0095 | Train Acc: 37.26%
# Valid Loss: 1.9160 | Valid Acc: 29.42%
# [Epoch 62/100]
# Train Loss: 3.0598 | Train Acc: 36.59%
# Valid Loss: 1.9318 | Valid Acc: 34.04%
# [Epoch 63/100]
# Train Loss: 3.0220 | Train Acc: 37.98%
# Valid Loss: 1.9224 | Valid Acc: 33.08%
# [Epoch 64/100]
# Train Loss: 2.9979 | Train Acc: 38.46%
# Valid Loss: 1.9789 | Valid Acc: 30.38%
# [Epoch 65/100]
# Train Loss: 3.0222 | Train Acc: 39.13%
# Valid Loss: 1.8706 | Valid Acc: 30.19%
# [Epoch 66/100]
# Train Loss: 2.9664 | Train Acc: 40.14%
# Valid Loss: 1.9028 | Valid Acc: 27.88%
# [Epoch 67/100]
# Train Loss: 3.0121 | Train Acc: 38.08%
# Valid Loss: 1.9396 | Valid Acc: 35.00%
# [Epoch 68/100]
# Train Loss: 2.9963 | Train Acc: 39.23%
# Valid Loss: 1.9242 | Valid Acc: 32.12%
# [Epoch 69/100]
# Train Loss: 2.9324 | Train Acc: 40.34%
# Valid Loss: 1.9123 | Valid Acc: 33.85%
# [Epoch 70/100]
# Train Loss: 2.9181 | Train Acc: 40.00%
# Valid Loss: 1.9350 | Valid Acc: 31.92%
# [Epoch 71/100]
# Train Loss: 3.0032 | Train Acc: 38.03%
# Valid Loss: 1.9414 | Valid Acc: 31.92%
# [Epoch 72/100]
# Train Loss: 3.0433 | Train Acc: 36.01%
# Valid Loss: 1.9862 | Valid Acc: 30.77%
# [Epoch 73/100]
# Train Loss: 2.9972 | Train Acc: 36.97%
# Valid Loss: 1.9417 | Valid Acc: 32.31%
# [Epoch 74/100]
# Train Loss: 2.9776 | Train Acc: 38.89%
# Valid Loss: 2.0149 | Valid Acc: 34.81%
# [Epoch 75/100]
# Train Loss: 2.9492 | Train Acc: 40.19%
# Valid Loss: 1.9186 | Valid Acc: 30.00%
# [Epoch 76/100]
# Train Loss: 2.9071 | Train Acc: 39.52%
# Valid Loss: 1.9323 | Valid Acc: 30.96%
# [Epoch 77/100]
# Train Loss: 2.9743 | Train Acc: 38.37%
# Valid Loss: 1.9883 | Valid Acc: 33.46%
# [Epoch 78/100]
# Train Loss: 2.9416 | Train Acc: 38.61%
# Valid Loss: 1.9689 | Valid Acc: 32.12%
# [Epoch 79/100]
# Train Loss: 2.9315 | Train Acc: 39.81%
# Valid Loss: 1.9693 | Valid Acc: 32.69%
# [Epoch 80/100]
# Train Loss: 2.9511 | Train Acc: 40.43%
# Valid Loss: 1.9514 | Valid Acc: 34.42%
# [Epoch 81/100]
# Train Loss: 2.9664 | Train Acc: 37.79%
# Valid Loss: 1.9184 | Valid Acc: 31.15%
# [Epoch 82/100]
# Train Loss: 2.8865 | Train Acc: 40.24%
# Valid Loss: 1.9242 | Valid Acc: 34.81%
# [Epoch 83/100]
# Train Loss: 2.9325 | Train Acc: 38.61%
# Valid Loss: 1.9404 | Valid Acc: 34.62%
# [Epoch 84/100]
# Train Loss: 2.9082 | Train Acc: 38.08%
# Valid Loss: 1.9710 | Valid Acc: 34.04%
# [Epoch 85/100]
# Train Loss: 2.9163 | Train Acc: 41.59%
# Valid Loss: 1.9127 | Valid Acc: 32.88%
# [Epoch 86/100]
# Train Loss: 2.9019 | Train Acc: 37.31%
# Valid Loss: 1.9418 | Valid Acc: 34.23%
# [Epoch 87/100]
# Train Loss: 2.9119 | Train Acc: 39.23%
# Valid Loss: 1.9767 | Valid Acc: 32.88%
# [Epoch 88/100]
# Train Loss: 2.9233 | Train Acc: 39.57%
# Valid Loss: 1.9828 | Valid Acc: 33.65%
# [Epoch 89/100]
# Train Loss: 2.8990 | Train Acc: 40.29%
# Valid Loss: 1.9268 | Valid Acc: 31.92%
# [Epoch 90/100]
# Train Loss: 2.9173 | Train Acc: 39.33%
# Valid Loss: 1.9884 | Valid Acc: 32.31%
# [Epoch 91/100]
# Train Loss: 2.9179 | Train Acc: 40.00%
# Valid Loss: 1.9839 | Valid Acc: 31.15%
# [Epoch 92/100]
# Train Loss: 2.9185 | Train Acc: 37.79%
# Valid Loss: 1.9504 | Valid Acc: 31.54%
# [Epoch 93/100]
# Train Loss: 2.9375 | Train Acc: 39.57%
# Valid Loss: 1.9345 | Valid Acc: 35.19%
# [Epoch 94/100]
# Train Loss: 2.9107 | Train Acc: 37.60%
# Valid Loss: 1.9708 | Valid Acc: 34.42%
# [Epoch 95/100]
# Train Loss: 2.9189 | Train Acc: 39.42%
# Valid Loss: 1.9267 | Valid Acc: 33.08%
# [Epoch 96/100]
# Train Loss: 2.8462 | Train Acc: 40.43%
# Valid Loss: 1.9907 | Valid Acc: 31.35%
# [Epoch 97/100]
# Train Loss: 2.8928 | Train Acc: 38.37%
# Valid Loss: 1.9169 | Valid Acc: 33.08%
# [Epoch 98/100]
# Train Loss: 2.8940 | Train Acc: 37.74%
# Valid Loss: 1.8993 | Valid Acc: 35.96%
# [Epoch 99/100]
# Train Loss: 2.9040 | Train Acc: 38.41%
# Valid Loss: 1.9611 | Valid Acc: 34.42%
# [Epoch 100/100]
# Train Loss: 2.8909 | Train Acc: 38.99%
# Valid Loss: 1.9105 | Valid Acc: 33.65%

# %% [markdown]
# ###### import matplotlib.pyplot as plt
#
# plt.figure(figsize=(12, 4))
# plt.style.use('tableau-colorblind10')
#
# # Plot training & validation loss
# plt.subplot(1, 2, 1)
# plt.plot(history["train_loss"], label="Training Loss")
# plt.plot(history["val_loss"], label="Validation Loss")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.legend()
#
# # Plot training & validation accuracy
# plt.subplot(1, 2, 2)
# plt.plot([v * 100 for v in history["train_acc"]], label="Training Accuracy")
# plt.plot([v * 100 for v in history["val_acc"]], label="Validation Accuracy")
# plt.xlabel("Epoch")
# plt.ylabel("Accuracy (%)")
# plt.legend()
#
# plt.suptitle("Training Progress (Loss & Accuracy)")
# plt.tight_layout()
# plt.show()

# %%
def evaluate_on_loader(test_loader, name="test"):
    diffe.eval()
    labels = np.arange(0, 26)
    Y, Y_hat = [], []
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

            x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            x_hat, x = safe_align_2d(x_hat, x)

            ddpm_out = x_hat, down, up, t
            #ddpm_out = x, down, up, t
            decoder_out, fc_out = diffe(x, ddpm_out)

            # EMA update
            #fc_ema.update()
            #print(decoder_out.shape)
            X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
            #X_eegnet = x.view(x.size(0), 64, -1)
            #print(X_eegnet.shape)
            outputs = eegnet_model(X_eegnet)

            #encoder_out = diffe.encoder(x)
            #y_hat = diffe.fc(encoder_out[1])
            y_hat = F.softmax(outputs, dim=1)

            Y.append(y.detach().cpu())
            Y_hat.append(y_hat.detach().cpu())

    Y = torch.cat(Y, dim=0).numpy()
    Y_hat = torch.cat(Y_hat, dim=0).numpy()

    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    print(f" {name} Accuracy: {accuracy:.2%}")
    return accuracy

# %% [markdown]
# #Evaluate on test data

# %%
acc1 = evaluate_on_loader(test1_loader, name="Test1 (Seen Subject)")
acc2 = evaluate_on_loader(test2_loader, name="Test2 (Unseen Subject)")
# Out:
#  Test1 (Seen Subject) Accuracy: 32.50%
#  Test2 (Unseen Subject) Accuracy: 32.09%

# %%
if USE_WANDB:
    run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆▇▇█</td></tr><tr><td>train_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▅▅▅▅▄▄</td></tr><tr><td>valid_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆█▇█▇</td></tr><tr><td>valid_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█████▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>0.3899</td></tr><tr><td>train_loss</td><td>2.89086</td></tr><tr><td>valid_acc</td><td>0.33654</td></tr><tr><td>valid_loss</td><td>1.91054</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ben_project_ssvep_diff_eegnet_CAE_x_hat_train_with_CAE_out_and_original_x</strong> at: <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/uijfloa6' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/uijfloa6</a><br> View project at: <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>.\wandb\run-20250413_125531-uijfloa6\logs</code>
