# %% [markdown]
# # SSVEP Character Classification with DiffE

# %%
#!pip install ema-pytorch

# %%
import os
import sys

#!git clone https://github.com/diffe2023/Diff-E.git
#sys.path.append('/content/Diff-E')
sys.path.append(r'C:\Users\shaoy\Diff-E')
#sys.path.append(r'C:\Users\shaoy\arl-eegmodels')

# %%
import math
from einops import reduce
from functools import partial
import random
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchaudio.transforms as T
from torch.utils.data import Dataset, DataLoader
from ema_pytorch import EMA
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    f1_score,
    roc_auc_score,
    precision_score,
    recall_score,
    top_k_accuracy_score,
)

# %%
config = {
    'Name': 'Yucheng Shao',
    #'subset': 1,
    'batch_size': 384,
    
    'epochs_AEs': 500,
    'alpha': 0,
    'beta': 1,
    'num_classes': 26,
    'ddpm_dim': 128,
    'encoder_dim': 256,
    'fc_dim': 512,
    'n_T': 1000,
    'AE_base_lr': 9e-5,
    'AE_max_lr': 1.5e-3,

    'epochs_EEG': 300,
    'eeg_lr': 0.0012,
    'eeg_F1': 16,
    'eeg_F2': 32,
    'eeg_D': 2,
    'eeg_droupout': 0.2,
    'eeg_channels': 64,
    'eeg_samples': 512,
    'eeg_kernel_length': 64,
    'eeg_pool_1': 4,
    'eeg_pool_2': 8,

    'checkpoint_dir': r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated',
    'augument': False,
    #'num_workers': 0
    # Include other parameters as needed.
}

# %%
# Uncomment this if you want to use Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# #load and preprocess data

# %% [markdown]
# We retain the original SSVEP data preprocessing procedures, including:
#
#     Chebyshev bandpass filtering (6–90 Hz),
#     Noise removal and segmentation using a sliding window of 250 samples, followed by manual channel-wise standardization (subtracting the mean and dividing by the standard deviation),
#     Downsampling from 1000 Hz to 250 Hz.
#
# In this work, we directly load the preprocessed character-level files "S#_chars.npy" for subsequent training.
#
# Unlike the original setup where models are trained separately for each subject, we train a single model jointly across all subjects by concatenating all subjects' data.

# %%
# Define a function to perform z-score normalization on the data
def zscore_norm(data):
    # Calculate the mean and standard deviation for each channel in each batch
    mean = torch.mean(data, dim=(1, 2))
    std = torch.std(data, dim=(1, 2))

    # Subtract the mean from each channel in each batch and divide by the standard deviation
    norm_data = (data - mean[:, None, None]) / std[:, None, None]

    return norm_data


# Define a function to perform min-max normalization on the data
def minmax_norm(data):
    # Calculate the minimum and maximum values for each channel and sequence in the batch
    min_vals = torch.min(data, dim=-1)[0]
    max_vals = torch.max(data, dim=-1)[0]

    # Scale the data to the range [0, 1]
    norm_data = (data - min_vals.unsqueeze(-1)) / (
        max_vals.unsqueeze(-1) - min_vals.unsqueeze(-1)
    )

    return norm_data

# %%
class EEGDataset(Dataset):
    "Characterizes a dataset for PyTorch"

    def __init__(self, X, Y, transform=None):
        "Initialization"
        self.X = X
        self.Y = Y
        self.transform = transform

    def __len__(self):
        "Denotes the total number of samples"
        return len(self.X)

    def __getitem__(self, index):
        "Generates one sample of data"
        # Load data and get label
        x = self.X[index]
        y = self.Y[index]
        if self.transform:
            x = self.transform(x)
        return x.squeeze(), y

# %%
#define spectrogram
#time_frames = 1 + (signal_length - n_fft) // hop_length
#1 + (250 - 64) // 16 = 12 time frame
spectrogram_transform = T.Spectrogram(
    n_fft=64,       # width of window. original: 128, but then the time_frame will become 0 when downsampling
    win_length=None, # default: n_fft
    hop_length=16, # default: win_length // 2
    normalized=True
)

# %%
def load_data_by_session(root_dir, subject_id, session_idx_list):
    data = np.load(os.path.join(root_dir, f"S{subject_id}_chars.npy"))  # [26, 6, 64, 250]
    data = data[:, session_idx_list]  # [26, len(session), 64, 250]
    X = data.reshape(-1, 64, 250)  # [samples, 64, 250]
    Y = np.repeat(np.arange(26), len(session_idx_list))

    # transform to spectrogram
    X_spectrogram = []
    for sample in X:  # sample: [64, 250]
        spec_per_channel = []
        for ch in sample:
            ch_tensor = torch.tensor(ch, dtype=torch.float32)
            spec = spectrogram_transform(ch_tensor)  # [freq, time]
            spec_per_channel.append(spec)
        spec_tensor = torch.stack(spec_per_channel)  # [64, freq, time]
        X_spectrogram.append(spec_tensor)

    X_spectrogram = torch.stack(X_spectrogram)  # [samples, 64, freq, time]
    Y = torch.tensor(Y, dtype=torch.long)

    print("X shape after Spectrogram:", X_spectrogram.shape)  # [B, 64, freq≈33, time≈12]

    return X_spectrogram, Y


def load_split_dataset(root_dir, num_seen=25, seed=43, cache_dir='processed_by_session'):
    os.makedirs(cache_dir, exist_ok=True)
    random.seed(seed)

    all_subjects = list(range(1, 36))
    seen_subjects = random.sample(all_subjects, num_seen)#25 seen
    unseen_subjects = [sid for sid in all_subjects if sid not in seen_subjects]#10 unseen

    split_cfg = {
        "train":  [(sid, [0, 1, 2, 3]) for sid in seen_subjects],
        "val":    [(sid, [4]) for sid in seen_subjects],
        "test1":  [(sid, [5]) for sid in seen_subjects],
        "test2":  [(sid, [0, 1, 2, 3, 4, 5]) for sid in unseen_subjects]
    }

    print(f"[Split] Seen subjects (train/val/test1): {seen_subjects}")
    print(f"[Split] Unseen subjects (test2): {unseen_subjects}")

    loaders = {}
    for split, sid_sess in split_cfg.items():
        X_all, Y_all = [], []
        for sid, sess in sid_sess:
            sess_str = ''.join(str(s) for s in sess)
            
            cache_X_path = os.path.join(cache_dir, f"S{sid:02d}_sess_{sess_str}_X.npy")
            cache_Y_path = os.path.join(cache_dir, f"S{sid:02d}_sess_{sess_str}_Y.npy")

            if os.path.exists(cache_X_path) and os.path.exists(cache_Y_path):
                X = torch.tensor(np.load(cache_X_path))
                Y = torch.tensor(np.load(cache_Y_path))
                print(f"[Cache] Loaded S{sid:02d} sessions {sess_str} from cache")
            else:
                X, Y = load_data_by_session(root_dir, sid, sess)
                np.save(cache_X_path, X.cpu().numpy())
                np.save(cache_Y_path, Y.cpu().numpy())
                print(f"[Cache] Saved S{sid:02d} sessions {sess_str} to cache")
                
            X_all.append(X)
            Y_all.append(Y)
        X_all = torch.cat(X_all, dim=0)
        Y_all = torch.cat(Y_all, dim=0)
        dataset = EEGDataset(X_all, Y_all)
        loaders[split] = DataLoader(dataset, batch_size=32, shuffle=(split == "train"))
    return loaders

# %%
seed = 44
random.seed(seed)
torch.manual_seed(seed)
print("Random Seed: ", seed)
# Out:
# Random Seed:  44

# %%
#subject_chars_dir = '/content/drive/MyDrive/project/dataset/ssvep/chars' # Where to store all character data
subject_chars_dir = r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\chars' # Where to store all character data
subject_ids = list(range(1, 36)) #35 samples + 1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 256
batch_size2 = 256
seed = 44
shuffle = True

# load all subjects' data
loaders = load_split_dataset(subject_chars_dir, num_seen=20, seed=seed)
train_loader = loaders["train"]
val_loader   = loaders["val"]
test1_loader = loaders["test1"]
test2_loader = loaders["test2"]
# Out:
# [Split] Seen subjects (train/val/test1): [27, 34, 8, 12, 13, 33, 10, 1, 30, 4, 19, 28, 26, 6, 17, 29, 31, 25, 11, 32]
# [Split] Unseen subjects (test2): [2, 3, 5, 7, 9, 14, 15, 16, 18, 20, 21, 22, 23, 24, 35]
# [Cache] Loaded S27 sessions 0123 from cache
# [Cache] Loaded S34 sessions 0123 from cache
# [Cache] Loaded S08 sessions 0123 from cache
# [Cache] Loaded S12 sessions 0123 from cache
# [Cache] Loaded S13 sessions 0123 from cache
# [Cache] Loaded S33 sessions 0123 from cache
# [Cache] Loaded S10 sessions 0123 from cache
# [Cache] Loaded S01 sessions 0123 from cache
# [Cache] Loaded S30 sessions 0123 from cache
# [Cache] Loaded S04 sessions 0123 from cache
# [Cache] Loaded S19 sessions 0123 from cache
# [Cache] Loaded S28 sessions 0123 from cache
# [Cache] Loaded S26 sessions 0123 from cache
# [Cache] Loaded S06 sessions 0123 from cache
# [Cache] Loaded S17 sessions 0123 from cache
# [Cache] Loaded S29 sessions 0123 from cache
# [Cache] Loaded S31 sessions 0123 from cache
# [Cache] Loaded S25 sessions 0123 from cache
# [Cache] Loaded S11 sessions 0123 from cache
# [Cache] Loaded S32 sessions 0123 from cache
# [Cache] Loaded S27 sessions 4 from cache
# [Cache] Loaded S34 sessions 4 from cache
# [Cache] Loaded S08 sessions 4 from cache
# [Cache] Loaded S12 sessions 4 from cache
# [Cache] Loaded S13 sessions 4 from cache
# [Cache] Loaded S33 sessions 4 from cache
# [Cache] Loaded S10 sessions 4 from cache
# [Cache] Loaded S01 sessions 4 from cache
# [Cache] Loaded S30 sessions 4 from cache
# [Cache] Loaded S04 sessions 4 from cache
# [Cache] Loaded S19 sessions 4 from cache
# [Cache] Loaded S28 sessions 4 from cache
# [Cache] Loaded S26 sessions 4 from cache
# [Cache] Loaded S06 sessions 4 from cache
# [Cache] Loaded S17 sessions 4 from cache
# [Cache] Loaded S29 sessions 4 from cache
# [Cache] Loaded S31 sessions 4 from cache
# [Cache] Loaded S25 sessions 4 from cache
# [Cache] Loaded S11 sessions 4 from cache
# [Cache] Loaded S32 sessions 4 from cache
# [Cache] Loaded S27 sessions 5 from cache
# [Cache] Loaded S34 sessions 5 from cache
# [Cache] Loaded S08 sessions 5 from cache
# [Cache] Loaded S12 sessions 5 from cache
# [Cache] Loaded S13 sessions 5 from cache
# [Cache] Loaded S33 sessions 5 from cache
# [Cache] Loaded S10 sessions 5 from cache
# [Cache] Loaded S01 sessions 5 from cache
# [Cache] Loaded S30 sessions 5 from cache
# [Cache] Loaded S04 sessions 5 from cache
# [Cache] Loaded S19 sessions 5 from cache
# [Cache] Loaded S28 sessions 5 from cache
# [Cache] Loaded S26 sessions 5 from cache
# [Cache] Loaded S06 sessions 5 from cache
# [Cache] Loaded S17 sessions 5 from cache
# [Cache] Loaded S29 sessions 5 from cache
# [Cache] Loaded S31 sessions 5 from cache
# [Cache] Loaded S25 sessions 5 from cache
# [Cache] Loaded S11 sessions 5 from cache
# [Cache] Loaded S32 sessions 5 from cache
# [Cache] Loaded S02 sessions 012345 from cache
# [Cache] Loaded S03 sessions 012345 from cache
# [Cache] Loaded S05 sessions 012345 from cache
# [Cache] Loaded S07 sessions 012345 from cache
# [Cache] Loaded S09 sessions 012345 from cache
# [Cache] Loaded S14 sessions 012345 from cache
# [Cache] Loaded S15 sessions 012345 from cache
# [Cache] Loaded S16 sessions 012345 from cache
# [Cache] Loaded S18 sessions 012345 from cache
# [Cache] Loaded S20 sessions 012345 from cache
# [Cache] Loaded S21 sessions 012345 from cache
# [Cache] Loaded S22 sessions 012345 from cache
# [Cache] Loaded S23 sessions 012345 from cache
# [Cache] Loaded S24 sessions 012345 from cache
# [Cache] Loaded S35 sessions 012345 from cache

# %%
print(len(train_loader.dataset), len(val_loader.dataset), len(test1_loader.dataset), len(test2_loader.dataset))

for x, y in train_loader:
    print("X shape:", x.shape)
    print("Y shape:", y.shape)
    break  # the first batch
# Out:
# 2080 520 520 2340
# X shape: torch.Size([32, 64, 33, 16])
# Y shape: torch.Size([32])

# %% [markdown]
# train: 20 seen subjects × 4 session × 26 = 2080
#
# val: 20 × 1 × 26 = 520
#
# test1: 20 × 1 × 26 = 520
#
# test2: 15 unseen × 6 session × 26 = 2340

# %% [markdown]
# random choose 25 subjects as seen, the rest 10 as unseen
#
# | Group Name | Subject Range   | Sessions Used         | Purpose                                  |
# |------------|------------------|------------------------|-------------------------------------------|
# | train      | seen subjects    | sessions [0, 1, 2, 3]  | Training (4 sessions)                     |
# | val        | seen subjects    | session [4]            | Validation                                |
# | test1      | seen subjects    | session [5]            | Test on unseen session of seen subjects  |
# | test2      | unseen subjects  | sessions [0–5] (all)   | Test on unseen subjects                   |

# %% [markdown]
# #model

# %% [markdown]
# The overall model follows the original GitHub implementation, with a few necessary adjustments to align tensor time dimensions. Specifically, we aligned the temporal dimensions between up2 + temb and down1, up3 and x, and x_hat and x. These changes are clearly marked with comments in the code.

# %% [markdown]
# ```
# #transform from 1D to 2D:
# current input: [batch_size, channels, freq_bins, time_frames]
# original input: [batch_size, channels, time]
#
# Replace all instances of Conv1d, MaxPool1d, and AvgPool1d with Conv2d, MaxPool2d, and AvgPool2d, respectively.
# Also modify the AvgPool1d and MaxPool1d used in the Encoder and Decoder.
# ```

# %%
def safe_cat_and_add(a, b, temb):
    """
    Interpolates `a` to align with `b`, then adds `temb` (broadcasted) to `a`, and finally concatenates with `b`.

    Inputs:
        a: decoder upsampled output [B, C, F, T]
        b: encoder skip connection [B, C, F, T]
        temb: time embedding output, supports [B, C], [B, C, 1], etc., auto-adapts shape

    Output:
        Concatenated result [B, C_concat, F, T]
    """
    # Align spatial dimensions (freq, time)
    if a.shape[2:] != b.shape[2:]:
        a = F.interpolate(a, size=b.shape[2:], mode='nearest')

    # Normalize temb to shape [B, C, 1, 1]
    while temb.dim() < 4:
        temb = temb.unsqueeze(-1)
    if temb.dim() > 4:
        temb = temb.squeeze(-1)

    # Broadcast to shape [B, C, F, T]
    temb = temb.expand(-1, -1, a.shape[2], a.shape[3])

    # Element-wise addition and concatenation
    return torch.cat([a + temb, b], dim=1)

def safe_align_2d(x1, x2):
    """
    Align two 4D tensors in frequency and time dimensions (2D spatial alignment).

    Inputs:
        x1, x2: [B, C, F, T]

    Returns:
        Aligned x1, x2
    """
    target_freq = min(x1.shape[2], x2.shape[2])
    target_time = min(x1.shape[3], x2.shape[3])
    x1 = F.interpolate(x1, size=(target_freq, target_time), mode='nearest')
    x2 = F.interpolate(x2, size=(target_freq, target_time), mode='nearest')
    return x1, x2

# %%
#define diffE model
def get_padding(kernel_size, dilation=1):
    return int((kernel_size * dilation - dilation) / 2)


# Swish activation function
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)


class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, x):
        device = x.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = x[:, None] * emb[None, :]
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)
        return emb


class WeightStandardizedConv2d(nn.Conv2d):
    def forward(self, x):
        eps = 1e-5 if x.dtype == torch.float32 else 1e-3
        weight = self.weight
        mean = weight.mean(dim=(1,2,3), keepdim=True)
        var = weight.var(dim=(1,2,3), keepdim=True, unbiased=False)
        weight = (weight - mean) / (var + eps).sqrt()
        return F.conv2d(x, weight, self.bias, self.stride, self.padding, self.dilation, self.groups)


class ResidualConvBlock(nn.Module):
    def __init__(self, inc, outc, kernel_size, stride=1, gn=8):
        super().__init__()
        self.same_channels = inc == outc
        padding = kernel_size // 2
        self.conv = nn.Sequential(
            WeightStandardizedConv2d(inc, outc, kernel_size, stride, padding),
            nn.GroupNorm(gn, outc),
            nn.PReLU(),
        )

    def forward(self, x):
        x1 = self.conv(x)
        return (x + x1) / 2 if self.same_channels else x1


class UnetDown(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, gn=8, factor=2):
        super().__init__()
        self.pool = nn.MaxPool2d(kernel_size=factor)
        self.layer = ResidualConvBlock(in_channels, out_channels, kernel_size, gn=gn)

    def forward(self, x):
        x = self.layer(x)
        return self.pool(x)


class UnetUp(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, gn=8, factor=2):
        super().__init__()
        self.upsample = nn.Upsample(scale_factor=factor, mode='nearest')
        self.layer = ResidualConvBlock(in_channels, out_channels, kernel_size, gn=gn)

    def forward(self, x):
        return self.layer(self.upsample(x))


class EmbedFC(nn.Module):
    def __init__(self, input_dim, emb_dim):
        super(EmbedFC, self).__init__()
        """
        generic one layer FC NN for embedding things
        """
        self.input_dim = input_dim
        layers = [
            nn.Linear(input_dim, emb_dim),
            nn.PReLU(),
            nn.Linear(emb_dim, emb_dim),
        ]
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(-1, self.input_dim)
        return self.model(x)


class ConditionalUNet(nn.Module):
    def __init__(self, in_channels, n_feat=256):
        super(ConditionalUNet, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat

        self.d1_out = n_feat * 1
        self.d2_out = n_feat * 2
        self.d3_out = n_feat * 3
        self.d4_out = n_feat * 4

        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = in_channels

        self.sin_emb = SinusoidalPosEmb(n_feat)
        # self.timeembed1 = EmbedFC(n_feat, self.u1_out)
        # self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        # self.timeembed3 = EmbedFC(n_feat, self.u3_out)

        self.down1 = UnetDown(in_channels, self.d1_out, 1, gn=8, factor=2)
        self.down2 = UnetDown(self.d1_out, self.d2_out, 1, gn=8, factor=2)
        self.down3 = UnetDown(self.d2_out, self.d3_out, 1, gn=8, factor=2)

        self.up2 = UnetUp(self.d3_out, self.u2_out, 1, gn=8, factor=2)
        self.up3 = UnetUp(self.u2_out + self.d2_out, self.u3_out, 1, gn=8, factor=2)
        self.up4 = UnetUp(self.u3_out + self.d1_out, self.u4_out, 1, gn=8, factor=2)
        self.out = nn.Conv2d(self.u4_out + in_channels, in_channels, kernel_size=1)

    def forward(self, x, t):
        down1 = self.down1(x)  # 2000 -> 1000
        down2 = self.down2(down1)  # 1000 -> 500
        down3 = self.down3(down2)  # 500 -> 250

        temb = self.sin_emb(t).view(-1, self.n_feat, 1)  # [b, n_feat, 1]

        up1 = self.up2(down3)  # 250 -> 500
        #up2 = self.up3(torch.cat([up1 + temb, down2], 1))  # 500 -> 1000
        up2 = self.up3(safe_cat_and_add(up1, down2, temb))

        #up3 = self.up4(torch.cat([up2 + temb, down1], 1))  # 1000 -> 2000
        up3 = self.up4(safe_cat_and_add(up2, down1, temb))

        # Align the temporal dimension of up3 and x
        if up3.shape[-1] != x.shape[-1]:
            target_len = min(up3.shape[-1], x.shape[-1])
            up3 = F.interpolate(up3, size=target_len)
            x = F.interpolate(x, size=target_len)

        #out = self.out(torch.cat([up3, x], 1))  # 2000 -> 2000
        if x.shape[2:] != up3.shape[2:]:
            x = F.interpolate(x, size=up3.shape[2:], mode='nearest')

        out = self.out(torch.cat([up3, x], 1))

        down = (down1, down2, down3)
        up = (up1, up2, up3)
        return out, down, up


class Encoder(nn.Module):
    def __init__(self, in_channels, dim=512):
        super(Encoder, self).__init__()

        self.in_channels = in_channels
        self.e1_out = dim
        self.e2_out = dim
        self.e3_out = dim

        self.down1 = UnetDown(in_channels, self.e1_out, 1, gn=8, factor=2)
        self.down2 = UnetDown(self.e1_out, self.e2_out, 1, gn=8, factor=2)
        self.down3 = UnetDown(self.e2_out, self.e3_out, 1, gn=8, factor=2)

        self.avg_pooling = nn.AdaptiveAvgPool2d((1,1))
        self.max_pooling = nn.AdaptiveMaxPool2d((1,1))
        self.act = nn.Tanh()

    def forward(self, x0):
        # Down sampling
        dn1 = self.down1(x0)  # 2048 -> 1024
        dn2 = self.down2(dn1)  # 1024 -> 512
        dn3 = self.down3(dn2)  # 512 -> 256
        z = self.avg_pooling(dn3).view(-1, self.e3_out)  # [b, features]
        down = (dn1, dn2, dn3)
        out = (down, z)
        return out


class Decoder(nn.Module):
    def __init__(self, in_channels, n_feat=256, encoder_dim=512, n_classes=config['num_classes']):
        super(Decoder, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat
        self.n_classes = n_classes
        self.e1_out = encoder_dim
        self.e2_out = encoder_dim
        self.e3_out = encoder_dim
        self.d1_out = n_feat
        self.d2_out = n_feat * 2
        self.d3_out = n_feat * 3
        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = in_channels

        # self.sin_emb = SinusoidalPosEmb(n_feat)
        # self.timeembed1 = EmbedFC(n_feat, self.e3_out)
        # self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        # self.timeembed3 = EmbedFC(n_feat, self.u3_out)
        # self.contextembed1 = EmbedFC(self.e3_out, self.e3_out)
        # self.contextembed2 = EmbedFC(self.e3_out, self.u2_out)
        # self.contextembed3 = EmbedFC(self.e3_out, self.u3_out)

        # Unet up sampling
        self.up1 = UnetUp(self.d3_out + self.e3_out, self.u2_out, 1, gn=8, factor=2)
        self.up2 = UnetUp(self.d2_out + self.u2_out, self.u3_out, 1, gn=8, factor=2)
        self.up3 = nn.Sequential(
            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(self.d1_out + self.u3_out + in_channels * 2, in_channels, kernel_size=1),
        )

        # self.out = nn.Conv1d(self.u4_out+in_channels, in_channels, 1)
        self.pool = nn.AvgPool2d(kernel_size=2)

    def forward(self, x0, encoder_out, diffusion_out):
        # Encoder output
        down, z = encoder_out
        dn1, dn2, dn3 = down

        # DDPM output
        x_hat, down_ddpm, up, t = diffusion_out
        dn11, dn22, dn33 = down_ddpm

        # embed context, time step
        # temb = self.sin_emb(t).view(-1, self.n_feat, 1) # [b, n_feat, 1]
        # temb1 = self.timeembed1(temb).view(-1, self.e3_out, 1) # [b, features]
        # temb2 = self.timeembed2(temb).view(-1, self.u2_out, 1) # [b, features]
        # temb3 = self.timeembed3(temb).view(-1, self.u3_out, 1) # [b, features]
        # ct2 = self.contextembed2(z).view(-1, self.u2_out, 1) # [b, n_feat, 1]
        # ct3 = self.contextembed3(z).view(-1, self.u3_out, 1) # [b, n_feat, 1]

        # Up sampling
        up1 = self.up1(torch.cat([dn3, dn33.detach()], 1))
        up2 = self.up2(torch.cat([up1, dn22.detach()], 1))
        out = self.up3(
            torch.cat([self.pool(x0), self.pool(x_hat.detach()), up2, dn11.detach()], 1)
        )
        return out


class DiffE(nn.Module):
    def __init__(self, encoder, decoder, fc):
        super(DiffE, self).__init__()

        self.encoder = encoder
        self.decoder = decoder
        self.fc = fc

    def forward(self, x0, ddpm_out):
        encoder_out = self.encoder(x0)
        decoder_out = self.decoder(x0, encoder_out, ddpm_out)
        fc_out = self.fc(encoder_out[1])
        return decoder_out, fc_out


class DecoderNoDiff(nn.Module):
    def __init__(self, in_channels, n_feat=256, encoder_dim=512, n_classes=config['num_classes']):
        super(DecoderNoDiff, self).__init__()

        self.in_channels = in_channels
        self.n_feat = n_feat
        self.n_classes = n_classes
        self.e1_out = encoder_dim
        self.e2_out = encoder_dim
        self.e3_out = encoder_dim
        self.u1_out = n_feat
        self.u2_out = n_feat
        self.u3_out = n_feat
        self.u4_out = n_feat

        self.sin_emb = SinusoidalPosEmb(n_feat)
        self.timeembed1 = EmbedFC(n_feat, self.e3_out)
        self.timeembed2 = EmbedFC(n_feat, self.u2_out)
        self.timeembed3 = EmbedFC(n_feat, self.u3_out)
        self.contextembed1 = EmbedFC(self.e3_out, self.e3_out)
        self.contextembed2 = EmbedFC(self.e3_out, self.u2_out)
        self.contextembed3 = EmbedFC(self.e3_out, self.u3_out)

        # Unet up sampling
        self.up2 = UnetUp(self.e3_out, self.u2_out, 1, gn=8, factor=2)
        self.up3 = UnetUp(self.e2_out + self.u2_out, self.u3_out, 1, gn=8, factor=2)
        # self.up4 = UnetUp(self.e1_out+self.u3_out, self.u4_out, 1, 1, gn=in_channels, factor=2, is_res=True)
        self.up4 = nn.Sequential(
            nn.Upsample(scale_factor=(2, 1), mode="nearest"),  # freq
            nn.Conv2d(self.u3_out + self.e1_out + in_channels, in_channels, kernel_size=1)
        )

        self.out = nn.Conv2d(self.u4_out, in_channels, kernel_size=1)
        self.pool = nn.AvgPool2d(kernel_size=(2, 1))  #  freq

    def forward(self, x0, x_hat, encoder_out, t):
        down, z = encoder_out
        dn1, dn2, dn3 = down
        tembd = self.sin_emb(t).view(-1, self.n_feat, 1)  # [b, n_feat, 1]
        tembd1 = self.timeembed1(self.sin_emb(t)).view(
            -1, self.e3_out, 1
        )  # [b, n_feat, 1]
        tembd2 = self.timeembed2(self.sin_emb(t)).view(
            -1, self.u2_out, 1
        )  # [b, n_feat, 1]
        tembd3 = self.timeembed3(self.sin_emb(t)).view(
            -1, self.u3_out, 1
        )  # [b, n_feat, 1]

        # Up sampling
        ddpm_loss = F.l1_loss(x0, x_hat, reduction="none")

        up2 = self.up2(dn3)  # 256 -> 512
        up3 = self.up3(torch.cat([up2, dn2], 1))  # 512 -> 1024
        out = self.up4(
            torch.cat([self.pool(x0), self.pool(x_hat), up3, dn1], 1)
        )  # 1024 -> 2048
        # out = self.out(torch.cat([out, x_hat], 1)) # 2048 -> 2048
        # out = self.out(out)
        return out


class LinearClassifier(nn.Module):
    def __init__(self, in_dim, latent_dim, emb_dim):
        super().__init__()
        self.linear_out = nn.Sequential(
            nn.Linear(in_features=in_dim, out_features=latent_dim),
            nn.GroupNorm(4, latent_dim),
            nn.PReLU(),
            nn.Linear(in_features=latent_dim, out_features=latent_dim),
            nn.GroupNorm(4, latent_dim),
            nn.PReLU(),
            nn.Linear(in_features=latent_dim, out_features=emb_dim),
        )

    def forward(self, x):
        x = self.linear_out(x)
        return x


def cosine_beta_schedule(timesteps, s=0.008):
    """
    cosine schedule
    as proposed in https://openreview.net/forum?id=-NEXDKk8gZ
    """
    steps = timesteps + 1
    t = torch.linspace(0, timesteps, steps, dtype=torch.float64) / timesteps
    alphas_cumprod = torch.cos((t + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)


def sigmoid_beta_schedule(timesteps, start=-3, end=3, tau=1, clamp_min=1e-5):
    """
    sigmoid schedule
    proposed in https://arxiv.org/abs/2212.11972 - Figure 8
    """
    steps = timesteps + 1
    t = torch.linspace(0, timesteps, steps, dtype=torch.float64) / timesteps
    v_start = torch.tensor(start / tau).sigmoid()
    v_end = torch.tensor(end / tau).sigmoid()
    alphas_cumprod = (-((t * (end - start) + start) / tau).sigmoid() + v_end) / (
        v_end - v_start
    )
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)


def ddpm_schedules(beta1, beta2, T):
    # assert beta1 < beta2 < 1.0, "beta1 and beta2 must be in (0, 1)"
    # beta_t = (beta2 - beta1) * torch.arange(0, T + 1, dtype=torch.float32) / T + beta1
    beta_t = cosine_beta_schedule(T, s=0.008).float()
    # beta_t = sigmoid_beta_schedule(T).float()

    alpha_t = 1 - beta_t

    log_alpha_t = torch.log(alpha_t)
    alphabar_t = torch.cumsum(log_alpha_t, dim=0).exp()

    sqrtab = torch.sqrt(alphabar_t)

    sqrtmab = torch.sqrt(1 - alphabar_t)

    return {
        "sqrtab": sqrtab,  # \sqrt{\bar{\alpha_t}}
        "sqrtmab": sqrtmab,  # \sqrt{1-\bar{\alpha_t}}
    }


class DDPM(nn.Module):
    def __init__(self, nn_model, betas, n_T, device):
        super(DDPM, self).__init__()
        self.nn_model = nn_model.to(device)

        for k, v in ddpm_schedules(betas[0], betas[1], n_T).items():
            self.register_buffer(k, v)

        self.n_T = n_T
        self.device = device

    def forward(self, x):
        _ts = torch.randint(1, self.n_T, (x.shape[0],)).to(
            self.device
        )  # t ~ Uniform(0, n_T)
        noise = torch.randn_like(x)  # eps ~ N(0, 1)
        #x_t = self.sqrtab[_ts, None, None] * x + self.sqrtmab[_ts, None, None] * noise
        x_t = self.sqrtab[_ts].view(-1, 1, 1, 1) * x + self.sqrtmab[_ts].view(-1, 1, 1, 1) * noise
        times = _ts / self.n_T
        output, down, up = self.nn_model(x_t, times)
        return output, down, up, noise, times

# %%
for x, y in train_loader:
    channels = x.shape[1]
    timepoints = x.shape[2]
    print(f"Sample input shape: {x.shape}  → Channels: {channels}, Timepoints: {timepoints}")
    break

num_classes = config['num_classes']
ddpm_dim = config['ddpm_dim']
encoder_dim = config['encoder_dim']
fc_dim = config['fc_dim']
n_T = config['n_T']

ddpm_model = ConditionalUNet(in_channels=channels, n_feat=ddpm_dim).to(device)
ddpm = DDPM(nn_model=ddpm_model, betas=(1e-6, 1e-2), n_T=n_T, device=device).to(device)

encoder = Encoder(in_channels=channels, dim=encoder_dim).to(device)
decoder = Decoder(in_channels=channels, n_feat=ddpm_dim, encoder_dim=encoder_dim).to(device)
# Out:
# Sample input shape: torch.Size([32, 64, 33, 16])  → Channels: 64, Timepoints: 33

# %%
fc = LinearClassifier(encoder_dim, fc_dim, emb_dim=num_classes).to(device)

diffe = DiffE(encoder, decoder, fc).to(device)

print(" Model initialized with:")
print(" - Input channels       :", channels)
print(" - Timepoints           :", timepoints)
print(" - ddpm total params    :", sum(p.numel() for p in ddpm.parameters()))
print(" - encoder total params :", sum(p.numel() for p in encoder.parameters()))
print(" - decoder total params :", sum(p.numel() for p in decoder.parameters()))
print(" - classifier params    :", sum(p.numel() for p in fc.parameters()))
print(" - total DiffE params   :", sum(p.numel() for p in diffe.parameters()))
# Out:
#  Model initialized with:
#  - Input channels       : 64
#  - Timepoints           : 33
#  - ddpm total params    : 265478
#  - encoder total params : 149763
#  - decoder total params : 156482
#  - classifier params    : 409628
#  - total DiffE params   : 715873

# %% [markdown]
# #train

# %%
# Criterion
criterion = nn.L1Loss()
criterion_class = nn.MSELoss()

# Define optimizer
base_lr, lr = config['AE_base_lr'], config['AE_max_lr']
optim1 = optim.RMSprop(ddpm.parameters(), lr=base_lr)
optim2 = optim.RMSprop(diffe.parameters(), lr=base_lr)

# EMAs
fc_ema = EMA(diffe.fc, beta=0.95, update_after_step=100, update_every=10,)

step_size = 150
scheduler1 = optim.lr_scheduler.CyclicLR(
    optimizer=optim1,
    base_lr=base_lr,
    max_lr=lr,
    step_size_up=step_size,
    mode="exp_range",
    cycle_momentum=False,
    gamma=0.9998,
)
scheduler2 = optim.lr_scheduler.CyclicLR(
    optimizer=optim2,
    base_lr=base_lr,
    max_lr=lr,
    step_size_up=step_size,
    mode="exp_range",
    cycle_momentum=False,
    gamma=0.9998,
)

# %%
# Evaluate function
def evaluate(encoder, fc, generator, device):
    labels = np.arange(0, 26)
    Y = []
    Y_hat = []
    for x, y in generator:
        x, y = x.to(device), y.type(torch.LongTensor).to(device)
        encoder_out = encoder(x)
        y_hat = fc(encoder_out[1])
        y_hat = F.softmax(y_hat, dim=1)

        Y.append(y.detach().cpu())
        Y_hat.append(y_hat.detach().cpu())

    # List of tensors to tensor to numpy
    Y = torch.cat(Y, dim=0).numpy()  # (N, )
    Y_hat = torch.cat(Y_hat, dim=0).numpy()  # (N, 13): has to sum to 1 for each row

    # Accuracy and Confusion Matrix
    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    f1 = f1_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    recall = recall_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    precision = precision_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels, zero_division=0)
    auc = roc_auc_score(Y, Y_hat, average="macro", multi_class="ovo", labels=labels)

    metrics = {
        "accuracy": accuracy,
        "f1": f1,
        "recall": recall,
        "precision": precision,
        "auc": auc,
    }
    # df_cm = pd.DataFrame(confusion_matrix(Y, Y_hat.argmax(axis=1)))
    return metrics

# %%
from torchsummary import summary


class EEGNet(nn.Module):
    def __init__(self, nb_classes, Chans, Samples, 
                 dropoutRate=0.5, kernLength=64, 
                 F1=16, D=2, F2=32, 
                 pool1=4, pool2=4):
        super(EEGNet, self).__init__()
        self.nb_classes = nb_classes
        self.Chans = Chans
        self.Samples = Samples
        self.F1 = F1
        self.D = D
        self.F2 = F2
        self.dropoutRate = dropoutRate
        self.pool1 = pool1
        self.pool2 = pool2

        # Define the layers
        self.conv1 = nn.Conv2d(1, F1, (1, kernLength), padding=(0, kernLength // 2), bias=False)
        self.batchnorm1 = nn.BatchNorm2d(F1)
        self.depthwiseConv = nn.Conv2d(F1, F1*D, (Chans, 1), groups=F1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(F1 * D)
        self.elu = nn.ELU()
        self.avgpool1 = nn.AvgPool2d((1, pool1))
        self.dropout = nn.Dropout(dropoutRate)
        self.separableConv = nn.Conv2d(F1*D, F2, (1, 16), padding=(0, 8), bias=False)
        self.batchnorm3 = nn.BatchNorm2d(F2)
        self.avgpool2 = nn.AvgPool2d((1, pool2))
        self.flatten = nn.Flatten()
        self.classify = nn.Linear(self._calc_out_features(), nb_classes)
        self.softmax = nn.Softmax(dim=1)

    def _calc_out_features(self):
        # Helper to calculate output size after convolutions/pooling
        with torch.no_grad():
            x = torch.zeros(1, 1, self.Chans, self.Samples)
            x = self.conv1(x)
            x = self.batchnorm1(x)
            x = self.depthwiseConv(x)
            x = self.batchnorm2(x)
            x = self.elu(x)
            x = self.avgpool1(x)
            x = self.dropout(x)

            x = self.separableConv(x)
            x = self.batchnorm3(x)
            x = self.elu(x)
            x = self.avgpool2(x)
            x = self.dropout(x)

            # Flatten to get total number of features
            return x.numel() // x.size(0)  # Total number of features for one example

    def forward(self, x):
        x = x.unsqueeze(1)  # shape: (batch_size, 1, Chans, Samples)
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv(x)
        x = self.batchnorm2(x)
        x = self.elu(x)
        x = self.avgpool1(x)
        x = self.dropout(x)
        x = self.separableConv(x)
        x = self.batchnorm3(x)
        x = self.elu(x)
        x = self.avgpool2(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.classify(x)
        x = self.softmax(x)
        return x


eegnet_model = EEGNet(nb_classes=config['num_classes'], 
                      Chans=config['eeg_channels'], 
                      Samples=config['eeg_samples'], 
                      dropoutRate=config['eeg_droupout'],
                      kernLength=config['eeg_kernel_length'], 
                      F1=config['eeg_F1'], 
                      D=config['eeg_D'], 
                      F2=config['eeg_F2'], 
                      pool1=config['eeg_pool_1'], 
                      pool2=config['eeg_pool_2'])
#eegnet_model = EEGNet(nb_classes=config['num_classes'], Chans=64, Samples=512, dropoutRate=0.5)

eegnet_model = eegnet_model.to(device)

optimizer_eeg = torch.optim.Adam(eegnet_model.parameters(), lr=config['eeg_lr'])
criterion_eeg = nn.CrossEntropyLoss()
scheduler_eeg = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_eeg, mode='min', factor=0.5, patience=5, verbose=True)

summary(eegnet_model, input_size=(config['eeg_channels'], config['eeg_samples']))
# Out:
# C:\Users\shaoy\anaconda3\envs\pytorch_env_p11\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 16, 64, 513]           1,024
#        BatchNorm2d-2          [-1, 16, 64, 513]              32
#             Conv2d-3           [-1, 32, 1, 513]           2,048
#        BatchNorm2d-4           [-1, 32, 1, 513]              64
#                ELU-5           [-1, 32, 1, 513]               0
#          AvgPool2d-6           [-1, 32, 1, 128]               0
#            Dropout-7           [-1, 32, 1, 128]               0
#             Conv2d-8           [-1, 32, 1, 129]          16,384
#        BatchNorm2d-9           [-1, 32, 1, 129]              64
#               ELU-10           [-1, 32, 1, 129]               0
#         AvgPool2d-11            [-1, 32, 1, 16]               0
#           Dropout-12            [-1, 32, 1, 16]               0
#           Flatten-13                  [-1, 512]               0
#            Linear-14                   [-1, 26]          13,338
#           Softmax-15                   [-1, 26]               0
# ================================================================
# Total params: 32,954
# Trainable params: 32,954
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.12
# Forward/backward pass size (MB): 8.56
# Params size (MB): 0.13
# Estimated Total Size (MB): 8.81
# ----------------------------------------------------------------

# %%
'''Initiate Wandb.'''
# Out:
# 'Initiate Wandb.'

# %%
import wandb

# Use wandb? Resume Training?
USE_WANDB = True

RESUME_LOGGING = False # Set this to true if you are resuming training from a previous run

# Create your wandb run

run_name = '{}_project_ssvep_EEGNet_Baseline'.format('Ben')

# If you are resuming an old run
if USE_WANDB:

    wandb.login(key="207d89e5e9cdfc415370f05503c72a11d5065073") #TODO

    if RESUME_LOGGING:
        run = wandb.init(
            id     = "diff-CAE(fc)-EEG", ### Insert specific run id here if you want to resume a previous run
            resume = "must", ### You need this to resume previous runs
            project = "project_ssvep-ablations", ### Project should be created in your wandb
            settings = wandb.Settings(_service_wait=300)
        )


    else:
        run = wandb.init(
            name    = run_name, ### Wandb creates random run names if you skip this field, we recommend you give useful names
            reinit  = True, ### Allows reinitalizing runs when you re-run this cell
            project = "project_ssvep-ablations", ### Project should be created in your wandb account
            config  = config ### Wandb Config for your run
        )

        ### Save your model architecture as a string with str(model)
        model_arch  = str([ddpm, diffe, eegnet_model])
        ### Save it in a txt file
        arch_file   = open("model_arch.txt", "w")
        file_write  = arch_file.write(model_arch)
        arch_file.close()

        ### log it in your wandb run with wandb.save()
        wandb.save('model_arch.txt')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\shaoy\_netrc
# wandb: Currently logged in as: yucheng_shao (yucheng_shao-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>C:\LTI 11785 Introduction to deep learning\project\SSVEP\wandb\run-20250416_112152-c3899hua</code>
# Syncing run <strong><a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/c3899hua' target="_blank">Ben_project_ssvep_EEGNet_Baseline</a></strong> to <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations</a>
#  View run at <a href='https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/c3899hua' target="_blank">https://wandb.ai/yucheng_shao-carnegie-mellon-university/project_ssvep-ablations/runs/c3899hua</a>

# %%
# CLEAR RAM!!
import gc


torch.cuda.empty_cache()
gc.collect()
# Out:
# 578

# %%
def save_model(model, optimizer, scheduler, metrics, epoch, path):
    torch.save(
        {'model_state_dict'         : model.state_dict(),
         'optimizer_state_dict'     : optimizer.state_dict(),
         'scheduler_state_dict'     : scheduler.state_dict(),
         'metric'                   : metrics,
         'epoch'                    : epoch},
         path)

# %%
# Train & Evaluate
checkpoint_dir = config['checkpoint_dir']
'''
args = argparse.Namespace()
args.device = device
args.subject = "ALL"
args.root_dir = subject_chars_dir
subject = args.subject

num_epochs = config['epochs_AEs']
test_period = 1
start_test = test_period
alpha = config['alpha']
beta = config['beta']

best_acc = 0
best_f1 = 0
best_recall = 0
best_precision = 0
best_auc = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}

with tqdm(total=num_epochs, desc=f"Method ALL - Joint Training on All Subjects - Autoencoders") as pbar:
    for epoch in range(num_epochs):
        ddpm.train()
        diffe.train()

        epoch_loss = 0
        num_batches = 0
        epoch_acc = 0
        total_samples = 0

        ############################## Train ###########################################
        for x, y in train_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)
            # Train DDPM
            optim1.zero_grad()
            x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            x_hat, x = safe_align_2d(x_hat, x)

            # needed if we wish to use x_hat again after first backward call
            x_hat_detached = x_hat.detach()

            loss_ddpm = F.l1_loss(x_hat, x, reduction="none")
            loss_ddpm.mean().backward()
            optim1.step()
            ddpm_out = x_hat, down, up, t

            # Train Diff-E
            optim2.zero_grad()
            decoder_out, fc_out = diffe(x, ddpm_out)

            #loss_gap = criterion(decoder_out, loss_ddpm.detach())
            loss_gap = criterion(decoder_out, x_hat_detached)
            loss_c = criterion_class(fc_out, y_cat)
            loss = beta * loss_gap + alpha * loss_c
            loss.backward()
            optim2.step()

            # Optimizer scheduler step
            scheduler1.step()
            scheduler2.step()

            # EMA update
            fc_ema.update()

            epoch_loss += loss.item()
            num_batches += 1

            pred_labels = torch.argmax(fc_out, dim=1)
            correct = (pred_labels == y).sum().item()
            epoch_acc += correct
            total_samples += y.size(0)

        history["train_loss"].append(epoch_loss / num_batches)
        history["train_acc"].append(epoch_acc / total_samples)

        metrics = {
            'train_loss': history["train_loss"][-1],
            'train_acc': history["train_acc"][-1],
        }

        ############################## validation ###########################################
        with torch.no_grad():
            if epoch > start_test:
                test_period = 1
            if epoch % test_period == 0:
                ddpm.eval()
                diffe.eval()

                metrics_val = evaluate(diffe.encoder, fc_ema, val_loader, device)

                val_acc = metrics_val["accuracy"]
                history["val_acc"].append(val_acc)
                f1 = metrics_val["f1"]
                recall = metrics_val["recall"]
                precision = metrics_val["precision"]
                auc = metrics_val["auc"]

                val_loss = 0
                with torch.no_grad():
                    for x, y in val_loader:
                        x, y = x.to(device), y.type(torch.LongTensor).to(device)
                        y_cat = F.one_hot(y, num_classes=26).float().to(device)

                        x_hat, down, up, noise, t = ddpm(x)
                        ddpm_out = x_hat, down, up, t

                        # Align the temporal dimension of x_hat and x
                        x_hat, x = safe_align_2d(x_hat, x)

                        loss_ddpm = F.l1_loss(x_hat, x, reduction="none")
                        decoder_out, fc_out = diffe(x, ddpm_out)

                        #loss_gap = criterion(decoder_out, loss_ddpm)
                        loss_gap = criterion(decoder_out, x_hat)
                        loss_c = criterion_class(fc_out, y_cat)

                        val_loss += (beta * loss_gap + alpha * loss_c).item()
                history["val_loss"].append(val_loss / len(val_loader))

                metrics.update({
                    'valid_loss': history["val_loss"][-1],
                    'valid_acc': val_acc,
                })

                best_acc_bool = val_acc > best_acc
                best_f1_bool = f1 > best_f1
                best_recall_bool = recall > best_recall
                best_precision_bool = precision > best_precision
                best_auc_bool = auc > best_auc

                save_model(ddpm, optim1, scheduler1, metrics, epoch, os.path.join(checkpoint_dir, 'ddpm_all_subjects.pth'))
                save_model(diffe, optim2, scheduler2, metrics, epoch, os.path.join(checkpoint_dir, 'diffe_all_subjects.pth'))

                if best_acc_bool:
                    best_acc = val_acc
                    #torch.save(diffe.state_dict(), f'/content/drive/MyDrive/project/model/ssvep/diffe_{subject}.pth')
                    #torch.save(ddpm.state_dict(), os.path.join(checkpoint_dir, 'ddpm_all_subjects.pth'))
                    save_model(ddpm, optim1, scheduler1, metrics, epoch, os.path.join(checkpoint_dir, 'best_ddpm_all_subjects.pth'))
                    save_model(diffe, optim2, scheduler2, metrics, epoch, os.path.join(checkpoint_dir, 'best_diffe_all_subjects.pth'))
                    #torch.save(diffe.state_dict(), r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated\diffe_all_subjects.pth')

                    wandb.save(os.path.join(checkpoint_dir, 'best_ddpm_all_subjects.pth'))
                    wandb.save(os.path.join(checkpoint_dir, 'best_diffe_all_subjects.pth'))
                    
                if best_f1_bool:
                    best_f1 = f1
                if best_recall_bool:
                    best_recall = recall
                if best_precision_bool:
                    best_precision = precision
                if best_auc_bool:
                    best_auc = auc

                description = f"Val Accuracy: {val_acc*100:.2f}% | Best: {best_acc*100:.2f}%"
                pbar.set_description(f"Method ALL – Processing subject {subject} – {description}"
                )
        #print(f"[Epoch {epoch+1}/{num_epochs}] Train Loss: {history['train_loss'][-1]:.4f} | Val Acc: {val_acc*100:.2f}%")
        print(f"[Epoch {epoch+1}/{num_epochs}]")
        print(f"Train Loss: {history['train_loss'][-1]:.4f} | Train Acc: {history['train_acc'][-1]*100:.2f}%")
        print(f"Valid Loss: {history['val_loss'][-1]:.4f} | Valid Acc: {val_acc*100:.2f}%")
        pbar.update(1)

        if run is not None:
            run.log(metrics)'''
# Out:
# '\nargs = argparse.Namespace()\nargs.device = device\nargs.subject = "ALL"\nargs.root_dir = subject_chars_dir\nsubject = args.subject\n\nnum_epochs = config[\'epochs_AEs\']\ntest_period = 1\nstart_test = test_period\nalpha = config[\'alpha\']\nbeta = config[\'beta\']\n\nbest_acc = 0\nbest_f1 = 0\nbest_recall = 0\nbest_precision = 0\nbest_auc = 0\n\nhistory = {\n    "train_loss": [],\n    "train_acc": [],\n    "val_loss": [],\n    "val_acc": []\n}\n\nwith tqdm(total=num_epochs, desc=f"Method ALL - Joint Training on All Subjects - Autoencoders") as pbar:\n    for epoch in range(num_epochs):\n        ddpm.train()\n        diffe.train()\n\n        epoch_loss = 0\n        num_batches = 0\n        epoch_acc = 0\n        total_samples = 0\n\n        ############################## Train ###########################################\n        for x, y in train_loader:\n            x, y = x.to(device), y.type(torch.LongTensor).to(device)\n            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)\n            # Train DDPM\n            optim1.zero_grad()\n            x_hat, down, up, noise, t = ddpm(x)\n\n            # Align the temporal dimension of x_hat and x\n            x_hat, x = safe_align_2d(x_hat, x)\n\n            # needed if we wish to use x_hat again after first backward call\n            x_hat_detached = x_hat.detach()\n\n            loss_ddpm = F.l1_loss(x_hat, x, reduction="none")\n            loss_ddpm.mean().backward()\n            optim1.step()\n            ddpm_out = x_hat, down, up, t\n\n            # Train Diff-E\n            optim2.zero_grad()\n            decoder_out, fc_out = diffe(x, ddpm_out)\n\n            #loss_gap = criterion(decoder_out, loss_ddpm.detach())\n            loss_gap = criterion(decoder_out, x_hat_detached)\n            loss_c = criterion_class(fc_out, y_cat)\n            loss = beta * loss_gap + alpha * loss_c\n            loss.backward()\n            optim2.step()\n\n            # Optimizer scheduler step\n            scheduler1.step()\n            scheduler2.step()\n\n            # EMA update\n            fc_ema.update()\n\n            epoch_loss += loss.item()\n            num_batches += 1\n\n            pred_labels = torch.argmax(fc_out, dim=1)\n            correct = (pred_labels == y).sum().item()\n            epoch_acc += correct\n            total_samples += y.size(0)\n\n        history["train_loss"].append(epoch_loss / num_batches)\n        history["train_acc"].append(epoch_acc / total_samples)\n\n        metrics = {\n            \'train_loss\': history["train_loss"][-1],\n            \'train_acc\': history["train_acc"][-1],\n        }\n\n        ############################## validation ###########################################\n        with torch.no_grad():\n            if epoch > start_test:\n                test_period = 1\n            if epoch % test_period == 0:\n                ddpm.eval()\n                diffe.eval()\n\n                metrics_val = evaluate(diffe.encoder, fc_ema, val_loader, device)\n\n                val_acc = metrics_val["accuracy"]\n                history["val_acc"].append(val_acc)\n                f1 = metrics_val["f1"]\n                recall = metrics_val["recall"]\n                precision = metrics_val["precision"]\n                auc = metrics_val["auc"]\n\n                val_loss = 0\n                with torch.no_grad():\n                    for x, y in val_loader:\n                        x, y = x.to(device), y.type(torch.LongTensor).to(device)\n                        y_cat = F.one_hot(y, num_classes=26).float().to(device)\n\n                        x_hat, down, up, noise, t = ddpm(x)\n                        ddpm_out = x_hat, down, up, t\n\n                        # Align the temporal dimension of x_hat and x\n                        x_hat, x = safe_align_2d(x_hat, x)\n\n                        loss_ddpm = F.l1_loss(x_hat, x, reduction="none")\n                        decoder_out, fc_out = diffe(x, ddpm_out)\n\n         ...

# %%
#val_losses = []
#val_accuracies = []
#initializer = RandomNormal(mean=0.0, stddev=0.1)

# %%
def evaluate2(diffe, ddpm, EEGNet, generator, device):
    labels = np.arange(0, 26)
    Y = []
    Y_hat = []
    for x, y in generator:
        x, y = x.to(device), y.type(torch.LongTensor).to(device)
        y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

        #x_hat, down, up, noise, t = ddpm(x)

        # Align the temporal dimension of x_hat and x
        #x_hat, x = safe_align_2d(x_hat, x)

        #ddpm_out = x_hat, down, up, t
        #ddpm_out = x, down, up, t

        #decoder_out, fc_out = diffe(x, ddpm_out)
        
        #X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
        X_eegnet = x.view(x.size(0), 64, -1)
        y_hat = EEGNet(X_eegnet)
        
        y_hat = F.softmax(y_hat, dim=1)

        Y.append(y.detach().cpu())
        Y_hat.append(y_hat.detach().cpu())

    # List of tensors to tensor to numpy
    Y = torch.cat(Y, dim=0).numpy()  # (N, )
    Y_hat = torch.cat(Y_hat, dim=0).numpy()  # (N, 13): has to sum to 1 for each row

    # Accuracy and Confusion Matrix
    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    f1 = f1_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    recall = recall_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels)
    precision = precision_score(Y, Y_hat.argmax(axis=1), average="macro", labels=labels, zero_division=0)
    auc = roc_auc_score(Y, Y_hat, average="macro", multi_class="ovo", labels=labels)

    metrics = {
        "accuracy": accuracy,
        "f1": f1,
        "recall": recall,
        "precision": precision,
        "auc": auc,
    }
    # df_cm = pd.DataFrame(confusion_matrix(Y, Y_hat.argmax(axis=1)))
    return metrics

# %%
# Train & Evaluate
args = argparse.Namespace()
args.device = device
args.subject = "ALL"
args.root_dir = subject_chars_dir
subject = args.subject

num_epochs = config['epochs_EEG']
test_period = 1
start_test = test_period
alpha = 1
beta = 0

best_acc = 0
best_f1 = 0
best_recall = 0
best_precision = 0
best_auc = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}

with tqdm(total=num_epochs, desc=f"Method ALL - Joint Training on All Subjects - EEGNet") as pbar:
    for epoch in range(num_epochs):
        ddpm.train()
        diffe.train()
        eegnet_model.train()

        epoch_loss = 0
        num_batches = 0
        epoch_acc = 0
        total_samples = 0

        ############################## Train ###########################################
        for x, y in train_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

            #x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            #x_hat, x = safe_align_2d(x_hat, x)

            #ddpm_out = x_hat, down, up, t

            # Train Diff-E
            #decoder_out, fc_out = diffe(x, ddpm_out)

            # EMA update
            #fc_ema.update()
            #print(decoder_out.shape)
            #X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
            #print(X_eegnet.shape)
            #outputs = eegnet_model(X_eegnet)

            X_eegnet2 = x.view(x.size(0), 64, -1)
            outputs2 = eegnet_model(X_eegnet2)
            
            #loss = criterion_eeg(outputs, y_cat) + criterion_eeg(outputs2, y_cat)
            loss = criterion_eeg(outputs2, y_cat)
            optimizer_eeg.zero_grad()
            loss.backward()
            optimizer_eeg.step()

            epoch_loss += loss.item()
            num_batches += 1

            pred_labels = torch.argmax(outputs2, dim=1)
            correct = (pred_labels == y).sum().item()
            epoch_acc += correct
            total_samples += y.size(0)

        history["train_loss"].append(epoch_loss / num_batches)
        history["train_acc"].append(epoch_acc / total_samples)

        metrics = {
            'train_loss': history["train_loss"][-1],
            'train_acc': history["train_acc"][-1],
        }

        ############################## validation ###########################################
        eegnet_model.eval()
        with torch.no_grad():
            if epoch > start_test:
                test_period = 1
            if epoch % test_period == 0:
                ddpm.eval()
                diffe.eval()

                metrics_val = evaluate2(diffe, ddpm, eegnet_model, val_loader, device)

                val_acc = metrics_val["accuracy"]
                history["val_acc"].append(val_acc)
                f1 = metrics_val["f1"]
                recall = metrics_val["recall"]
                precision = metrics_val["precision"]
                auc = metrics_val["auc"]

                val_loss = 0
                with torch.no_grad():
                    for x, y in val_loader:
                        x, y = x.to(device), y.type(torch.LongTensor).to(device)
                        y_cat = F.one_hot(y, num_classes=26).float().to(device)

                        #x_hat, down, up, noise, t = ddpm(x)
                        
                        # Align the temporal dimension of x_hat and x
                        #x_hat, x = safe_align_2d(x_hat, x)
                        
                        #ddpm_out = x_hat, down, up, t
                        #ddpm_out = x, down, up, t

                        #decoder_out, fc_out = diffe(x, ddpm_out)

                        #X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
                        X_eegnet = x.view(x.size(0), 64, -1)
                        outputs = eegnet_model(X_eegnet)

                        val_loss += criterion_eeg(outputs, y).item()

                history["val_loss"].append(val_loss / len(val_loader))


                metrics.update({
                    'valid_loss': history["val_loss"][-1],
                    'valid_acc': val_acc,
                })

                best_acc_bool = val_acc > best_acc
                best_f1_bool = f1 > best_f1
                best_recall_bool = recall > best_recall
                best_precision_bool = precision > best_precision
                best_auc_bool = auc > best_auc

                save_model(eegnet_model, optimizer_eeg, scheduler_eeg, metrics, epoch, os.path.join(checkpoint_dir, 'eegnet_all_subjects.pth'))

                if best_acc_bool:
                    best_acc = val_acc
                    #torch.save(diffe.state_dict(), f'/content/drive/MyDrive/project/model/ssvep/diffe_{subject}.pth')
                    #torch.save(diffe.state_dict(), '/content/drive/MyDrive/project/model/ssvep/diffe_all_subjects.pth')
                    #torch.save(eegnet_model.state_dict(), r'C:\LTI 11785 Introduction to deep learning\project\SSVEP\checkpoints_separated\eegnet_model_all_subjects.pth')
                    save_model(eegnet_model, optimizer_eeg, scheduler_eeg, metrics, epoch, os.path.join(checkpoint_dir, 'best_eegnet_all_subjects.pth'))
                if best_f1_bool:
                    best_f1 = f1
                if best_recall_bool:
                    best_recall = recall
                if best_precision_bool:
                    best_precision = precision
                if best_auc_bool:
                    best_auc = auc

                description = f"Val Accuracy: {val_acc*100:.2f}% | Best: {best_acc*100:.2f}%"
                pbar.set_description(f"Method ALL – Processing subject {subject} – {description}"
                )
        print(f"[Epoch {epoch+1}/{num_epochs}]")
        print(f"Train Loss: {history['train_loss'][-1]:.4f} | Train Acc: {history['train_acc'][-1]*100:.2f}%")
        print(f"Valid Loss: {history['val_loss'][-1]:.4f} | Valid Acc: {val_acc*100:.2f}%")
        pbar.update(1)

        if run is not None:
            run.log(metrics)
# Out:
# Method ALL - Joint Training on All Subjects - EEGNet:   0%|          | 0/300 [00:00<?, ?it/s]
# [Epoch 1/300]
# Train Loss: 3.2397 | Train Acc: 7.21%
# Valid Loss: 3.1743 | Valid Acc: 19.04%
# [Epoch 2/300]
# Train Loss: 3.1324 | Train Acc: 22.31%
# Valid Loss: 3.0918 | Valid Acc: 25.00%
# [Epoch 3/300]
# Train Loss: 3.0581 | Train Acc: 31.44%
# Valid Loss: 3.0493 | Valid Acc: 28.08%
# [Epoch 4/300]
# Train Loss: 3.0077 | Train Acc: 36.25%
# Valid Loss: 3.0333 | Valid Acc: 30.58%
# [Epoch 5/300]
# Train Loss: 2.9544 | Train Acc: 42.69%
# Valid Loss: 2.9991 | Valid Acc: 34.23%
# [Epoch 6/300]
# Train Loss: 2.9043 | Train Acc: 48.41%
# Valid Loss: 2.9779 | Valid Acc: 35.38%
# [Epoch 7/300]
# Train Loss: 2.8618 | Train Acc: 53.61%
# Valid Loss: 2.9562 | Valid Acc: 37.12%
# [Epoch 8/300]
# Train Loss: 2.8252 | Train Acc: 56.63%
# Valid Loss: 2.9282 | Valid Acc: 39.81%
# [Epoch 9/300]
# Train Loss: 2.8024 | Train Acc: 58.37%
# Valid Loss: 2.9267 | Valid Acc: 41.92%
# [Epoch 10/300]
# Train Loss: 2.7667 | Train Acc: 61.88%
# Valid Loss: 2.9064 | Valid Acc: 41.15%
# [Epoch 11/300]
# Train Loss: 2.7460 | Train Acc: 63.99%
# Valid Loss: 2.8954 | Valid Acc: 45.58%
# [Epoch 12/300]
# Train Loss: 2.7239 | Train Acc: 67.12%
# Valid Loss: 2.8874 | Valid Acc: 45.38%
# [Epoch 13/300]
# Train Loss: 2.6977 | Train Acc: 68.32%
# Valid Loss: 2.8737 | Valid Acc: 46.92%
# [Epoch 14/300]
# Train Loss: 2.6767 | Train Acc: 70.38%
# Valid Loss: 2.8762 | Valid Acc: 46.54%
# [Epoch 15/300]
# Train Loss: 2.6592 | Train Acc: 72.31%
# Valid Loss: 2.8762 | Valid Acc: 46.54%
# [Epoch 16/300]
# Train Loss: 2.6500 | Train Acc: 72.69%
# Valid Loss: 2.8615 | Valid Acc: 45.96%
# [Epoch 17/300]
# Train Loss: 2.6324 | Train Acc: 74.38%
# Valid Loss: 2.8473 | Valid Acc: 47.12%
# [Epoch 18/300]
# Train Loss: 2.6132 | Train Acc: 76.06%
# Valid Loss: 2.8432 | Valid Acc: 49.42%
# [Epoch 19/300]
# Train Loss: 2.6079 | Train Acc: 76.44%
# Valid Loss: 2.8411 | Valid Acc: 48.65%
# [Epoch 20/300]
# Train Loss: 2.5937 | Train Acc: 77.36%
# Valid Loss: 2.8269 | Valid Acc: 50.19%
# [Epoch 21/300]
# Train Loss: 2.5849 | Train Acc: 78.03%
# Valid Loss: 2.8332 | Valid Acc: 50.38%
# [Epoch 22/300]
# Train Loss: 2.5675 | Train Acc: 80.10%
# Valid Loss: 2.8248 | Valid Acc: 51.15%
# [Epoch 23/300]
# Train Loss: 2.5600 | Train Acc: 80.62%
# Valid Loss: 2.8182 | Valid Acc: 50.00%
# [Epoch 24/300]
# Train Loss: 2.5552 | Train Acc: 80.48%
# Valid Loss: 2.8148 | Valid Acc: 51.15%
# [Epoch 25/300]
# Train Loss: 2.5446 | Train Acc: 81.59%
# Valid Loss: 2.8022 | Valid Acc: 53.08%
# [Epoch 26/300]
# Train Loss: 2.5430 | Train Acc: 81.15%
# Valid Loss: 2.8067 | Valid Acc: 51.73%
# [Epoch 27/300]
# Train Loss: 2.5370 | Train Acc: 82.36%
# Valid Loss: 2.8092 | Valid Acc: 53.08%
# [Epoch 28/300]
# Train Loss: 2.5288 | Train Acc: 83.41%
# Valid Loss: 2.8019 | Valid Acc: 52.69%
# [Epoch 29/300]
# Train Loss: 2.5292 | Train Acc: 82.50%
# Valid Loss: 2.8075 | Valid Acc: 51.92%
# [Epoch 30/300]
# Train Loss: 2.5179 | Train Acc: 83.32%
# Valid Loss: 2.8081 | Valid Acc: 50.96%
# [Epoch 31/300]
# Train Loss: 2.5178 | Train Acc: 83.80%
# Valid Loss: 2.8047 | Valid Acc: 51.15%
# [Epoch 32/300]
# Train Loss: 2.5140 | Train Acc: 83.89%
# Valid Loss: 2.8036 | Valid Acc: 51.15%
# [Epoch 33/300]
# Train Loss: 2.5071 | Train Acc: 84.52%
# Valid Loss: 2.8028 | Valid Acc: 51.54%
# [Epoch 34/300]
# Train Loss: 2.5074 | Train Acc: 84.86%
# Valid Loss: 2.7927 | Valid Acc: 53.46%
# [Epoch 35/300]
# Train Loss: 2.4967 | Train Acc: 85.34%
# Valid Loss: 2.7941 | Valid Acc: 53.08%
# [Epoch 36/300]
# Train Loss: 2.4938 | Train Acc: 85.10%
# Valid Loss: 2.7932 | Valid Acc: 52.69%
# [Epoch 37/300]
# Train Loss: 2.4892 | Train Acc: 85.77%
# Valid Loss: 2.7828 | Valid Acc: 52.88%
# [Epoch 38/300]
# Train Loss: 2.4863 | Train Acc: 86.01%
# Valid Loss: 2.7902 | Valid Acc: 50.77%
# [Epoch 39/300]
# Train Loss: 2.4818 | Train Acc: 86.35%
# Valid Loss: 2.7922 | Valid Acc: 53.46%
# [Epoch 40/300]
# Train Loss: 2.4790 | Train Acc: 86.63%
# Valid Loss: 2.7874 | Valid Acc: 51.92%
# [Epoch 41/300]
# Train Loss: 2.4801 | Train Acc: 86.83%
# Valid Loss: 2.7945 | Valid Acc: 50.58%
# [Epoch 42/300]
# Train Loss: 2.4795 | Train Acc: 86.63%
# Valid Loss: 2.7870 | Valid Acc: 54.23%
# [Epoch 43/300]
# Train Loss: 2.4752 | Train Acc: 87.16%
# Valid Loss: 2.7873 | Valid Acc: 52.12%
# [Epoch 44/300]
# Train Loss: 2.4712 | Train Acc: 87.40%
# Valid Loss: 2.7954 | Valid Acc: 51.73%
# [Epoch 45/300]
# Train Loss: 2.4644 | Train Acc: 87.79%
# Valid Loss: 2.7731 | Valid Acc: 54.23%
# [Epoch 46/300]
# Train Loss: 2.4653 | Train Acc: 87.64%
# Valid Loss: 2.7861 | Valid Acc: 52.88%
# [Epoch 47/300]
# Train Loss: 2.4651 | Train Acc: 87.60%
# Valid Loss: 2.7810 | Valid Acc: 53.85%
# [Epoch 48/300]
# Train Loss: 2.4674 | Train Acc: 87.79%
# Valid Loss: 2.7915 | Valid Acc: 52.50%
# [Epoch 49/300]
# Train Loss: 2.4568 | Train Acc: 88.46%
# Valid Loss: 2.7907 | Valid Acc: 51.73%
# [Epoch 50/300]
# Train Loss: 2.4581 | Train Acc: 88.89%
# Valid Loss: 2.7919 | Valid Acc: 52.12%
# [Epoch 51/300]
# Train Loss: 2.4531 | Train Acc: 88.61%
# Valid Loss: 2.7812 | Valid Acc: 53.65%
# [Epoch 52/300]
# Train Loss: 2.4525 | Train Acc: 88.75%
# Valid Loss: 2.7834 | Valid Acc: 52.69%
# [Epoch 53/300]
# Train Loss: 2.4491 | Train Acc: 88.75%
# Valid Loss: 2.7745 | Valid Acc: 53.85%
# [Epoch 54/300]
# Train Loss: 2.4496 | Train Acc: 89.28%
# Valid Loss: 2.7707 | Valid Acc: 53.85%
# [Epoch 55/300]
# Train Loss: 2.4459 | Train Acc: 89.52%
# Valid Loss: 2.7807 | Valid Acc: 52.88%
# [Epoch 56/300]
# Train Loss: 2.4468 | Train Acc: 89.13%
# Valid Loss: 2.7880 | Valid Acc: 51.92%
# [Epoch 57/300]
# Train Loss: 2.4446 | Train Acc: 89.57%
# Valid Loss: 2.7902 | Valid Acc: 51.92%
# [Epoch 58/300]
# Train Loss: 2.4455 | Train Acc: 89.04%
# Valid Loss: 2.7774 | Valid Acc: 52.88%
# [Epoch 59/300]
# Train Loss: 2.4455 | Train Acc: 89.23%
# Valid Loss: 2.7784 | Valid Acc: 52.31%
# [Epoch 60/300]
# Train Loss: 2.4422 | Train Acc: 89.52%
# Valid Loss: 2.7793 | Valid Acc: 52.12%
# [Epoch 61/300]
# Train Loss: 2.4362 | Train Acc: 90.00%
# Valid Loss: 2.7778 | Valid Acc: 52.50%
# [Epoch 62/300]
# Train Loss: 2.4379 | Train Acc: 90.10%
# Valid Loss: 2.7777 | Valid Acc: 54.04%
# [Epoch 63/300]
# Train Loss: 2.4362 | Train Acc: 90.14%
# Valid Loss: 2.7927 | Valid Acc: 51.73%
# [Epoch 64/300]
# Train Loss: 2.4313 | Train Acc: 90.62%
# Valid Loss: 2.7676 | Valid Acc: 54.04%
# [Epoch 65/300]
# Train Loss: 2.4307 | Train Acc: 90.72%
# Valid Loss: 2.7892 | Valid Acc: 51.92%
# [Epoch 66/300]
# Train Loss: 2.4333 | Train Acc: 90.24%
# Valid Loss: 2.7777 | Valid Acc: 54.81%
# [Epoch 67/300]
# Train Loss: 2.4404 | Train Acc: 89.47%
# Valid Loss: 2.7649 | Valid Acc: 55.00%
# [Epoch 68/300]
# Train Loss: 2.4309 | Train Acc: 90.82%
# Valid Loss: 2.7759 | Valid Acc: 55.00%
# [Epoch 69/300]
# Train Loss: 2.4315 | Train Acc: 90.10%
# Valid Loss: 2.7726 | Valid Acc: 54.23%
# [Epoch 70/300]
# Train Loss: 2.4276 | Train Acc: 90.72%
# Valid Loss: 2.7784 | Valid Acc: 52.88%
# [Epoch 71/300]
# Train Loss: 2.4269 | Train Acc: 90.67%
# Valid Loss: 2.7767 | Valid Acc: 53.27%
# [Epoch 72/300]
# Train Loss: 2.4295 | Train Acc: 90.58%
# Valid Loss: 2.7624 | Valid Acc: 54.62%
# [Epoch 73/300]
# Train Loss: 2.4288 | Train Acc: 90.48%
# Valid Loss: 2.7684 | Valid Acc: 52.50%
# [Epoch 74/300]
# Train Loss: 2.4265 | Train Acc: 91.11%
# Valid Loss: 2.7656 | Valid Acc: 53.46%
# [Epoch 75/300]
# Train Loss: 2.4222 | Train Acc: 91.25%
# Valid Loss: 2.7576 | Valid Acc: 54.23%
# [Epoch 76/300]
# Train Loss: 2.4260 | Train Acc: 90.72%
# Valid Loss: 2.7616 | Valid Acc: 55.38%
# [Epoch 77/300]
# Train Loss: 2.4245 | Train Acc: 91.01%
# Valid Loss: 2.7626 | Valid Acc: 55.19%
# [Epoch 78/300]
# Train Loss: 2.4249 | Train Acc: 90.87%
# Valid Loss: 2.7725 | Valid Acc: 54.23%
# [Epoch 79/300]
# Train Loss: 2.4214 | Train Acc: 91.35%
# Valid Loss: 2.7617 | Valid Acc: 55.38%
# [Epoch 80/300]
# Train Loss: 2.4221 | Train Acc: 91.44%
# Valid Loss: 2.7762 | Valid Acc: 53.65%
# [Epoch 81/300]
# Train Loss: 2.4223 | Train Acc: 91.20%
# Valid Loss: 2.7745 | Valid Acc: 54.23%
# [Epoch 82/300]
# Train Loss: 2.4179 | Train Acc: 91.44%
# Valid Loss: 2.7754 | Valid Acc: 52.88%
# [Epoch 83/300]
# Train Loss: 2.4157 | Train Acc: 91.73%
# Valid Loss: 2.7669 | Valid Acc: 53.85%
# [Epoch 84/300]
# Train Loss: 2.4156 | Train Acc: 91.63%
# Valid Loss: 2.7527 | Valid Acc: 56.15%
# [Epoch 85/300]
# Train Loss: 2.4151 | Train Acc: 91.92%
# Valid Loss: 2.7621 | Valid Acc: 55.19%
# [Epoch 86/300]
# Train Loss: 2.4108 | Train Acc: 91.78%
# Valid Loss: 2.7569 | Valid Acc: 56.15%
# [Epoch 87/300]
# Train Loss: 2.4119 | Train Acc: 92.21%
# Valid Loss: 2.7632 | Valid Acc: 55.00%
# [Epoch 88/300]
# Train Loss: 2.4182 | Train Acc: 91.25%
# Valid Loss: 2.7563 | Valid Acc: 55.96%
# [Epoch 89/300]
# Train Loss: 2.4107 | Train Acc: 92.31%
# Valid Loss: 2.7513 | Valid Acc: 55.77%
# [Epoch 90/300]
# Train Loss: 2.4137 | Train Acc: 91.78%
# Valid Loss: 2.7568 | Valid Acc: 55.38%
# [Epoch 91/300]
# Train Loss: 2.4171 | Train Acc: 91.35%
# Valid Loss: 2.7631 | Valid Acc: 55.58%
# [Epoch 92/300]
# Train Loss: 2.4102 | Train Acc: 92.31%
# Valid Loss: 2.7576 | Valid Acc: 54.42%
# [Epoch 93/300]
# Train Loss: 2.4053 | Train Acc: 92.55%
# Valid Loss: 2.7628 | Valid Acc: 54.62%
# [Epoch 94/300]
# Train Loss: 2.4052 | Train Acc: 92.64%
# Valid Loss: 2.7601 | Valid Acc: 53.65%
# [Epoch 95/300]
# Train Loss: 2.4069 | Train Acc: 92.45%
# Valid Loss: 2.7681 | Valid Acc: 54.42%
# [Epoch 96/300]
# Train Loss: 2.4072 | Train Acc: 92.40%
# Valid Loss: 2.7478 | Valid Acc: 55.58%
# [Epoch 97/300]
# Train Loss: 2.4142 | Train Acc: 91.63%
# Valid Loss: 2.7637 | Valid Acc: 54.04%
# [Epoch 98/300]
# Train Loss: 2.4050 | Train Acc: 92.74%
# Valid Loss: 2.7513 | Valid Acc: 55.19%
# [Epoch 99/300]
# Train Loss: 2.4096 | Train Acc: 91.92%
# Valid Loss: 2.7580 | Valid Acc: 54.23%
# [Epoch 100/300]
# Train Loss: 2.4122 | Train Acc: 91.97%
# Valid Loss: 2.7630 | Valid Acc: 53.65%
# [Epoch 101/300]
# Train Loss: 2.4083 | Train Acc: 92.16%
# Valid Loss: 2.7745 | Valid Acc: 53.08%
# [Epoch 102/300]
# Train Loss: 2.4036 | Train Acc: 92.60%
# Valid Loss: 2.7608 | Valid Acc: 54.23%
# [Epoch 103/300]
# Train Loss: 2.4009 | Train Acc: 92.74%
# Valid Loss: 2.7567 | Valid Acc: 54.42%
# [Epoch 104/300]
# Train Loss: 2.4025 | Train Acc: 92.88%
# Valid Loss: 2.7656 | Valid Acc: 54.04%
# [Epoch 105/300]
# Train Loss: 2.4013 | Train Acc: 92.93%
# Valid Loss: 2.7578 | Valid Acc: 55.00%
# [Epoch 106/300]
# Train Loss: 2.4009 | Train Acc: 92.93%
# Valid Loss: 2.7543 | Valid Acc: 54.81%
# [Epoch 107/300]
# Train Loss: 2.4021 | Train Acc: 92.84%
# Valid Loss: 2.7519 | Valid Acc: 55.58%
# [Epoch 108/300]
# Train Loss: 2.4051 | Train Acc: 92.40%
# Valid Loss: 2.7561 | Valid Acc: 55.00%
# [Epoch 109/300]
# Train Loss: 2.4058 | Train Acc: 92.31%
# Valid Loss: 2.7568 | Valid Acc: 54.23%
# [Epoch 110/300]
# Train Loss: 2.4015 | Train Acc: 92.69%
# Valid Loss: 2.7512 | Valid Acc: 55.77%
# [Epoch 111/300]
# Train Loss: 2.4064 | Train Acc: 92.36%
# Valid Loss: 2.7534 | Valid Acc: 55.00%
# [Epoch 112/300]
# Train Loss: 2.4025 | Train Acc: 92.84%
# Valid Loss: 2.7612 | Valid Acc: 54.62%
# [Epoch 113/300]
# Train Loss: 2.4054 | Train Acc: 92.40%
# Valid Loss: 2.7639 | Valid Acc: 54.42%
# [Epoch 114/300]
# Train Loss: 2.4015 | Train Acc: 92.98%
# Valid Loss: 2.7563 | Valid Acc: 55.00%
# [Epoch 115/300]
# Train Loss: 2.3999 | Train Acc: 93.08%
# Valid Loss: 2.7431 | Valid Acc: 56.54%
# [Epoch 116/300]
# Train Loss: 2.4007 | Train Acc: 92.88%
# Valid Loss: 2.7549 | Valid Acc: 55.38%
# [Epoch 117/300]
# Train Loss: 2.4013 | Train Acc: 93.03%
# Valid Loss: 2.7418 | Valid Acc: 56.15%
# [Epoch 118/300]
# Train Loss: 2.3974 | Train Acc: 93.17%
# Valid Loss: 2.7475 | Valid Acc: 55.77%
# [Epoch 119/300]
# Train Loss: 2.4005 | Train Acc: 92.79%
# Valid Loss: 2.7462 | Valid Acc: 55.38%
# [Epoch 120/300]
# Train Loss: 2.4002 | Train Acc: 93.03%
# Valid Loss: 2.7624 | Valid Acc: 54.81%
# [Epoch 121/300]
# Train Loss: 2.3992 | Train Acc: 92.88%
# Valid Loss: 2.7640 | Valid Acc: 54.23%
# [Epoch 122/300]
# Train Loss: 2.3975 | Train Acc: 93.17%
# Valid Loss: 2.7434 | Valid Acc: 55.58%
# [Epoch 123/300]
# Train Loss: 2.3944 | Train Acc: 93.61%
# Valid Loss: 2.7573 | Valid Acc: 55.38%
# [Epoch 124/300]
# Train Loss: 2.3997 | Train Acc: 92.88%
# Valid Loss: 2.7505 | Valid Acc: 55.58%
# [Epoch 125/300]
# Train Loss: 2.4005 | Train Acc: 92.74%
# Valid Loss: 2.7504 | Valid Acc: 55.96%
# [Epoch 126/300]
# Train Loss: 2.3968 | Train Acc: 93.27%
# Valid Loss: 2.7488 | Valid Acc: 54.81%
# [Epoch 127/300]
# Train Loss: 2.3950 | Train Acc: 93.32%
# Valid Loss: 2.7456 | Valid Acc: 56.54%
# [Epoch 128/300]
# Train Loss: 2.3965 | Train Acc: 93.41%
# Valid Loss: 2.7421 | Valid Acc: 56.54%
# [Epoch 129/300]
# Train Loss: 2.3960 | Train Acc: 93.56%
# Valid Loss: 2.7604 | Valid Acc: 54.62%
# [Epoch 130/300]
# Train Loss: 2.3936 | Train Acc: 93.80%
# Valid Loss: 2.7540 | Valid Acc: 55.19%
# [Epoch 131/300]
# Train Loss: 2.3926 | Train Acc: 93.61%
# Valid Loss: 2.7418 | Valid Acc: 55.96%
# [Epoch 132/300]
# Train Loss: 2.3972 | Train Acc: 92.98%
# Valid Loss: 2.7391 | Valid Acc: 56.92%
# [Epoch 133/300]
# Train Loss: 2.3954 | Train Acc: 93.12%
# Valid Loss: 2.7437 | Valid Acc: 56.54%
# [Epoch 134/300]
# Train Loss: 2.3937 | Train Acc: 93.80%
# Valid Loss: 2.7401 | Valid Acc: 56.73%
# [Epoch 135/300]
# Train Loss: 2.3919 | Train Acc: 93.51%
# Valid Loss: 2.7355 | Valid Acc: 57.88%
# [Epoch 136/300]
# Train Loss: 2.3935 | Train Acc: 93.51%
# Valid Loss: 2.7367 | Valid Acc: 57.69%
# [Epoch 137/300]
# Train Loss: 2.3889 | Train Acc: 93.99%
# Valid Loss: 2.7411 | Valid Acc: 56.35%
# [Epoch 138/300]
# Train Loss: 2.3870 | Train Acc: 93.99%
# Valid Loss: 2.7541 | Valid Acc: 54.42%
# [Epoch 139/300]
# Train Loss: 2.3932 | Train Acc: 93.32%
# Valid Loss: 2.7340 | Valid Acc: 57.88%
# [Epoch 140/300]
# Train Loss: 2.3923 | Train Acc: 93.85%
# Valid Loss: 2.7484 | Valid Acc: 56.15%
# [Epoch 141/300]
# Train Loss: 2.3928 | Train Acc: 93.65%
# Valid Loss: 2.7332 | Valid Acc: 57.50%
# [Epoch 142/300]
# Train Loss: 2.3931 | Train Acc: 93.56%
# Valid Loss: 2.7420 | Valid Acc: 56.35%
# [Epoch 143/300]
# Train Loss: 2.3911 | Train Acc: 93.80%
# Valid Loss: 2.7397 | Valid Acc: 56.73%
# [Epoch 144/300]
# Train Loss: 2.3893 | Train Acc: 93.75%
# Valid Loss: 2.7357 | Valid Acc: 56.92%
# [Epoch 145/300]
# Train Loss: 2.3865 | Train Acc: 93.80%
# Valid Loss: 2.7478 | Valid Acc: 56.54%
# [Epoch 146/300]
# Train Loss: 2.3912 | Train Acc: 93.56%
# Valid Loss: 2.7507 | Valid Acc: 55.19%
# [Epoch 147/300]
# Train Loss: 2.3904 | Train Acc: 93.75%
# Valid Loss: 2.7431 | Valid Acc: 56.15%
# [Epoch 148/300]
# Train Loss: 2.3876 | Train Acc: 94.04%
# Valid Loss: 2.7370 | Valid Acc: 57.69%
# [Epoch 149/300]
# Train Loss: 2.3918 | Train Acc: 93.65%
# Valid Loss: 2.7583 | Valid Acc: 53.85%
# [Epoch 150/300]
# Train Loss: 2.3894 | Train Acc: 93.70%
# Valid Loss: 2.7458 | Valid Acc: 55.58%
# [Epoch 151/300]
# Train Loss: 2.3892 | Train Acc: 93.70%
# Valid Loss: 2.7441 | Valid Acc: 55.77%
# [Epoch 152/300]
# Train Loss: 2.3908 | Train Acc: 93.75%
# Valid Loss: 2.7441 | Valid Acc: 56.35%
# [Epoch 153/300]
# Train Loss: 2.3929 | Train Acc: 93.32%
# Valid Loss: 2.7301 | Valid Acc: 58.08%
# [Epoch 154/300]
# Train Loss: 2.3878 | Train Acc: 94.13%
# Valid Loss: 2.7432 | Valid Acc: 55.77%
# [Epoch 155/300]
# Train Loss: 2.3881 | Train Acc: 94.09%
# Valid Loss: 2.7388 | Valid Acc: 57.12%
# [Epoch 156/300]
# Train Loss: 2.3880 | Train Acc: 93.85%
# Valid Loss: 2.7375 | Valid Acc: 56.73%
# [Epoch 157/300]
# Train Loss: 2.3896 | Train Acc: 93.94%
# Valid Loss: 2.7382 | Valid Acc: 56.15%
# [Epoch 158/300]
# Train Loss: 2.3873 | Train Acc: 94.28%
# Valid Loss: 2.7426 | Valid Acc: 56.15%
# [Epoch 159/300]
# Train Loss: 2.3854 | Train Acc: 94.13%
# Valid Loss: 2.7329 | Valid Acc: 57.31%
# [Epoch 160/300]
# Train Loss: 2.3881 | Train Acc: 93.85%
# Valid Loss: 2.7305 | Valid Acc: 56.73%
# [Epoch 161/300]
# Train Loss: 2.3902 | Train Acc: 93.89%
# Valid Loss: 2.7329 | Valid Acc: 57.88%
# [Epoch 162/300]
# Train Loss: 2.3849 | Train Acc: 94.28%
# Valid Loss: 2.7408 | Valid Acc: 56.92%
# [Epoch 163/300]
# Train Loss: 2.3887 | Train Acc: 93.65%
# Valid Loss: 2.7358 | Valid Acc: 57.31%
# [Epoch 164/300]
# Train Loss: 2.3864 | Train Acc: 94.04%
# Valid Loss: 2.7266 | Valid Acc: 58.65%
# [Epoch 165/300]
# Train Loss: 2.3876 | Train Acc: 93.94%
# Valid Loss: 2.7324 | Valid Acc: 56.92%
# [Epoch 166/300]
# Train Loss: 2.3846 | Train Acc: 94.38%
# Valid Loss: 2.7359 | Valid Acc: 57.31%
# [Epoch 167/300]
# Train Loss: 2.3853 | Train Acc: 94.18%
# Valid Loss: 2.7231 | Valid Acc: 59.81%
# [Epoch 168/300]
# Train Loss: 2.3882 | Train Acc: 94.04%
# Valid Loss: 2.7295 | Valid Acc: 58.08%
# [Epoch 169/300]
# Train Loss: 2.3903 | Train Acc: 93.65%
# Valid Loss: 2.7348 | Valid Acc: 56.73%
# [Epoch 170/300]
# Train Loss: 2.3850 | Train Acc: 94.28%
# Valid Loss: 2.7422 | Valid Acc: 56.92%
# [Epoch 171/300]
# Train Loss: 2.3869 | Train Acc: 94.13%
# Valid Loss: 2.7435 | Valid Acc: 56.35%
# [Epoch 172/300]
# Train Loss: 2.3875 | Train Acc: 93.89%
# Valid Loss: 2.7324 | Valid Acc: 57.12%
# [Epoch 173/300]
# Train Loss: 2.3903 | Train Acc: 93.70%
# Valid Loss: 2.7392 | Valid Acc: 56.35%
# [Epoch 174/300]
# Train Loss: 2.3840 | Train Acc: 94.28%
# Valid Loss: 2.7364 | Valid Acc: 56.54%
# [Epoch 175/300]
# Train Loss: 2.3803 | Train Acc: 94.66%
# Valid Loss: 2.7350 | Valid Acc: 57.31%
# [Epoch 176/300]
# Train Loss: 2.3839 | Train Acc: 94.23%
# Valid Loss: 2.7309 | Valid Acc: 57.88%
# [Epoch 177/300]
# Train Loss: 2.3812 | Train Acc: 94.52%
# Valid Loss: 2.7289 | Valid Acc: 58.65%
# [Epoch 178/300]
# Train Loss: 2.3821 | Train Acc: 94.62%
# Valid Loss: 2.7295 | Valid Acc: 56.92%
# [Epoch 179/300]
# Train Loss: 2.3857 | Train Acc: 94.23%
# Valid Loss: 2.7374 | Valid Acc: 56.35%
# [Epoch 180/300]
# Train Loss: 2.3803 | Train Acc: 94.66%
# Valid Loss: 2.7289 | Valid Acc: 57.31%
# [Epoch 181/300]
# Train Loss: 2.3832 | Train Acc: 94.33%
# Valid Loss: 2.7301 | Valid Acc: 56.54%
# [Epoch 182/300]
# Train Loss: 2.3833 | Train Acc: 94.42%
# Valid Loss: 2.7223 | Valid Acc: 59.42%
# [Epoch 183/300]
# Train Loss: 2.3776 | Train Acc: 94.95%
# Valid Loss: 2.7359 | Valid Acc: 57.88%
# [Epoch 184/300]
# Train Loss: 2.3867 | Train Acc: 93.89%
# Valid Loss: 2.7312 | Valid Acc: 56.73%
# [Epoch 185/300]
# Train Loss: 2.3800 | Train Acc: 94.81%
# Valid Loss: 2.7281 | Valid Acc: 56.92%
# [Epoch 186/300]
# Train Loss: 2.3785 | Train Acc: 94.86%
# Valid Loss: 2.7252 | Valid Acc: 59.04%
# [Epoch 187/300]
# Train Loss: 2.3772 | Train Acc: 95.14%
# Valid Loss: 2.7252 | Valid Acc: 58.65%
# [Epoch 188/300]
# Train Loss: 2.3805 | Train Acc: 94.66%
# Valid Loss: 2.7255 | Valid Acc: 57.88%
# [Epoch 189/300]
# Train Loss: 2.3819 | Train Acc: 94.76%
# Valid Loss: 2.7271 | Valid Acc: 57.12%
# [Epoch 190/300]
# Train Loss: 2.3746 | Train Acc: 95.10%
# Valid Loss: 2.7275 | Valid Acc: 56.92%
# [Epoch 191/300]
# Train Loss: 2.3754 | Train Acc: 95.14%
# Valid Loss: 2.7207 | Valid Acc: 58.08%
# [Epoch 192/300]
# Train Loss: 2.3760 | Train Acc: 95.00%
# Valid Loss: 2.7313 | Valid Acc: 57.88%
# [Epoch 193/300]
# Train Loss: 2.3772 | Train Acc: 94.86%
# Valid Loss: 2.7301 | Valid Acc: 57.31%
# [Epoch 194/300]
# Train Loss: 2.3789 | Train Acc: 94.81%
# Valid Loss: 2.7286 | Valid Acc: 57.88%
# [Epoch 195/300]
# Train Loss: 2.3786 | Train Acc: 94.71%
# Valid Loss: 2.7445 | Valid Acc: 56.15%
# [Epoch 196/300]
# Train Loss: 2.3782 | Train Acc: 94.95%
# Valid Loss: 2.7323 | Valid Acc: 58.08%
# [Epoch 197/300]
# Train Loss: 2.3783 | Train Acc: 94.86%
# Valid Loss: 2.7302 | Valid Acc: 57.88%
# [Epoch 198/300]
# Train Loss: 2.3761 | Train Acc: 95.00%
# Valid Loss: 2.7423 | Valid Acc: 55.96%
# [Epoch 199/300]
# Train Loss: 2.3762 | Train Acc: 94.95%
# Valid Loss: 2.7237 | Valid Acc: 58.65%
# [Epoch 200/300]
# Train Loss: 2.3787 | Train Acc: 94.66%
# Valid Loss: 2.7303 | Valid Acc: 57.50%
# [Epoch 201/300]
# Train Loss: 2.3774 | Train Acc: 94.90%
# Valid Loss: 2.7435 | Valid Acc: 55.19%
# [Epoch 202/300]
# Train Loss: 2.3802 | Train Acc: 94.38%
# Valid Loss: 2.7323 | Valid Acc: 56.92%
# [Epoch 203/300]
# Train Loss: 2.3791 | Train Acc: 94.71%
# Valid Loss: 2.7316 | Valid Acc: 57.12%
# [Epoch 204/300]
# Train Loss: 2.3767 | Train Acc: 94.95%
# Valid Loss: 2.7338 | Valid Acc: 57.69%
# [Epoch 205/300]
# Train Loss: 2.3780 | Train Acc: 94.76%
# Valid Loss: 2.7245 | Valid Acc: 57.69%
# [Epoch 206/300]
# Train Loss: 2.3754 | Train Acc: 95.10%
# Valid Loss: 2.7338 | Valid Acc: 57.69%
# [Epoch 207/300]
# Train Loss: 2.3762 | Train Acc: 94.86%
# Valid Loss: 2.7413 | Valid Acc: 58.08%
# [Epoch 208/300]
# Train Loss: 2.3776 | Train Acc: 94.86%
# Valid Loss: 2.7341 | Valid Acc: 56.73%
# [Epoch 209/300]
# Train Loss: 2.3763 | Train Acc: 94.95%
# Valid Loss: 2.7314 | Valid Acc: 56.35%
# [Epoch 210/300]
# Train Loss: 2.3752 | Train Acc: 94.86%
# Valid Loss: 2.7300 | Valid Acc: 56.35%
# [Epoch 211/300]
# Train Loss: 2.3789 | Train Acc: 94.81%
# Valid Loss: 2.7363 | Valid Acc: 56.54%
# [Epoch 212/300]
# Train Loss: 2.3731 | Train Acc: 95.14%
# Valid Loss: 2.7341 | Valid Acc: 56.54%
# [Epoch 213/300]
# Train Loss: 2.3741 | Train Acc: 95.29%
# Valid Loss: 2.7345 | Valid Acc: 56.92%
# [Epoch 214/300]
# Train Loss: 2.3757 | Train Acc: 94.90%
# Valid Loss: 2.7324 | Valid Acc: 56.54%
# [Epoch 215/300]
# Train Loss: 2.3781 | Train Acc: 94.95%
# Valid Loss: 2.7276 | Valid Acc: 57.69%
# [Epoch 216/300]
# Train Loss: 2.3755 | Train Acc: 95.00%
# Valid Loss: 2.7218 | Valid Acc: 58.65%
# [Epoch 217/300]
# Train Loss: 2.3752 | Train Acc: 95.10%
# Valid Loss: 2.7271 | Valid Acc: 57.88%
# [Epoch 218/300]
# Train Loss: 2.3756 | Train Acc: 95.14%
# Valid Loss: 2.7278 | Valid Acc: 57.31%
# [Epoch 219/300]
# Train Loss: 2.3736 | Train Acc: 95.29%
# Valid Loss: 2.7288 | Valid Acc: 56.92%
# [Epoch 220/300]
# Train Loss: 2.3765 | Train Acc: 94.95%
# Valid Loss: 2.7347 | Valid Acc: 55.96%
# [Epoch 221/300]
# Train Loss: 2.3780 | Train Acc: 94.86%
# Valid Loss: 2.7272 | Valid Acc: 57.69%
# [Epoch 222/300]
# Train Loss: 2.3729 | Train Acc: 95.34%
# Valid Loss: 2.7402 | Valid Acc: 56.35%
# [Epoch 223/300]
# Train Loss: 2.3716 | Train Acc: 95.43%
# Valid Loss: 2.7349 | Valid Acc: 55.96%
# [Epoch 224/300]
# Train Loss: 2.3762 | Train Acc: 94.81%
# Valid Loss: 2.7277 | Valid Acc: 58.08%
# [Epoch 225/300]
# Train Loss: 2.3768 | Train Acc: 94.90%
# Valid Loss: 2.7215 | Valid Acc: 58.65%
# [Epoch 226/300]
# Train Loss: 2.3761 | Train Acc: 94.81%
# Valid Loss: 2.7176 | Valid Acc: 59.42%
# [Epoch 227/300]
# Train Loss: 2.3749 | Train Acc: 95.05%
# Valid Loss: 2.7198 | Valid Acc: 58.65%
# [Epoch 228/300]
# Train Loss: 2.3740 | Train Acc: 95.05%
# Valid Loss: 2.7291 | Valid Acc: 56.92%
# [Epoch 229/300]
# Train Loss: 2.3718 | Train Acc: 95.43%
# Valid Loss: 2.7215 | Valid Acc: 57.88%
# [Epoch 230/300]
# Train Loss: 2.3706 | Train Acc: 95.48%
# Valid Loss: 2.7316 | Valid Acc: 56.73%
# [Epoch 231/300]
# Train Loss: 2.3744 | Train Acc: 95.10%
# Valid Loss: 2.7290 | Valid Acc: 58.27%
# [Epoch 232/300]
# Train Loss: 2.3748 | Train Acc: 95.05%
# Valid Loss: 2.7213 | Valid Acc: 58.08%
# [Epoch 233/300]
# Train Loss: 2.3752 | Train Acc: 95.10%
# Valid Loss: 2.7261 | Valid Acc: 58.27%
# [Epoch 234/300]
# Train Loss: 2.3753 | Train Acc: 95.05%
# Valid Loss: 2.7263 | Valid Acc: 57.50%
# [Epoch 235/300]
# Train Loss: 2.3766 | Train Acc: 94.71%
# Valid Loss: 2.7317 | Valid Acc: 56.73%
# [Epoch 236/300]
# Train Loss: 2.3756 | Train Acc: 95.10%
# Valid Loss: 2.7163 | Valid Acc: 59.62%
# [Epoch 237/300]
# Train Loss: 2.3748 | Train Acc: 94.90%
# Valid Loss: 2.7205 | Valid Acc: 58.27%
# [Epoch 238/300]
# Train Loss: 2.3714 | Train Acc: 95.38%
# Valid Loss: 2.7183 | Valid Acc: 59.23%
# [Epoch 239/300]
# Train Loss: 2.3779 | Train Acc: 94.66%
# Valid Loss: 2.7092 | Valid Acc: 58.85%
# [Epoch 240/300]
# Train Loss: 2.3731 | Train Acc: 95.38%
# Valid Loss: 2.7172 | Valid Acc: 58.27%
# [Epoch 241/300]
# Train Loss: 2.3746 | Train Acc: 95.05%
# Valid Loss: 2.7169 | Valid Acc: 58.46%
# [Epoch 242/300]
# Train Loss: 2.3746 | Train Acc: 95.19%
# Valid Loss: 2.7064 | Valid Acc: 59.42%
# [Epoch 243/300]
# Train Loss: 2.3738 | Train Acc: 95.10%
# Valid Loss: 2.7060 | Valid Acc: 60.19%
# [Epoch 244/300]
# Train Loss: 2.3743 | Train Acc: 95.19%
# Valid Loss: 2.7129 | Valid Acc: 60.19%
# [Epoch 245/300]
# Train Loss: 2.3737 | Train Acc: 95.19%
# Valid Loss: 2.7211 | Valid Acc: 59.42%
# [Epoch 246/300]
# Train Loss: 2.3761 | Train Acc: 95.00%
# Valid Loss: 2.7111 | Valid Acc: 60.96%
# [Epoch 247/300]
# Train Loss: 2.3735 | Train Acc: 95.38%
# Valid Loss: 2.7011 | Valid Acc: 60.38%
# [Epoch 248/300]
# Train Loss: 2.3737 | Train Acc: 95.19%
# Valid Loss: 2.7195 | Valid Acc: 57.88%
# [Epoch 249/300]
# Train Loss: 2.3735 | Train Acc: 95.38%
# Valid Loss: 2.7160 | Valid Acc: 59.04%
# [Epoch 250/300]
# Train Loss: 2.3757 | Train Acc: 95.10%
# Valid Loss: 2.7113 | Valid Acc: 59.04%
# [Epoch 251/300]
# Train Loss: 2.3719 | Train Acc: 95.43%
# Valid Loss: 2.7186 | Valid Acc: 59.62%
# [Epoch 252/300]
# Train Loss: 2.3748 | Train Acc: 95.00%
# Valid Loss: 2.7098 | Valid Acc: 59.23%
# [Epoch 253/300]
# Train Loss: 2.3712 | Train Acc: 95.53%
# Valid Loss: 2.7195 | Valid Acc: 58.27%
# [Epoch 254/300]
# Train Loss: 2.3745 | Train Acc: 95.10%
# Valid Loss: 2.7148 | Valid Acc: 59.04%
# [Epoch 255/300]
# Train Loss: 2.3716 | Train Acc: 95.34%
# Valid Loss: 2.7156 | Valid Acc: 58.85%
# [Epoch 256/300]
# Train Loss: 2.3720 | Train Acc: 95.38%
# Valid Loss: 2.7225 | Valid Acc: 58.65%
# [Epoch 257/300]
# Train Loss: 2.3731 | Train Acc: 95.38%
# Valid Loss: 2.7233 | Valid Acc: 57.88%
# [Epoch 258/300]
# Train Loss: 2.3677 | Train Acc: 95.67%
# Valid Loss: 2.7240 | Valid Acc: 57.50%
# [Epoch 259/300]
# Train Loss: 2.3705 | Train Acc: 95.34%
# Valid Loss: 2.7178 | Valid Acc: 59.04%
# [Epoch 260/300]
# Train Loss: 2.3725 | Train Acc: 95.24%
# Valid Loss: 2.7195 | Valid Acc: 59.62%
# [Epoch 261/300]
# Train Loss: 2.3683 | Train Acc: 95.48%
# Valid Loss: 2.7136 | Valid Acc: 59.04%
# [Epoch 262/300]
# Train Loss: 2.3687 | Train Acc: 95.58%
# Valid Loss: 2.7216 | Valid Acc: 57.69%
# [Epoch 263/300]
# Train Loss: 2.3693 | Train Acc: 95.53%
# Valid Loss: 2.7228 | Valid Acc: 57.69%
# [Epoch 264/300]
# Train Loss: 2.3728 | Train Acc: 95.24%
# Valid Loss: 2.7207 | Valid Acc: 58.85%
# [Epoch 265/300]
# Train Loss: 2.3757 | Train Acc: 94.95%
# Valid Loss: 2.7312 | Valid Acc: 56.54%
# [Epoch 266/300]
# Train Loss: 2.3748 | Train Acc: 95.14%
# Valid Loss: 2.7222 | Valid Acc: 58.27%
# [Epoch 267/300]
# Train Loss: 2.3732 | Train Acc: 95.19%
# Valid Loss: 2.7176 | Valid Acc: 59.23%
# [Epoch 268/300]
# Train Loss: 2.3716 | Train Acc: 95.38%
# Valid Loss: 2.7230 | Valid Acc: 58.08%
# [Epoch 269/300]
# Train Loss: 2.3709 | Train Acc: 95.48%
# Valid Loss: 2.7108 | Valid Acc: 59.42%
# [Epoch 270/300]
# Train Loss: 2.3715 | Train Acc: 95.38%
# Valid Loss: 2.7144 | Valid Acc: 59.42%
# [Epoch 271/300]
# Train Loss: 2.3707 | Train Acc: 95.43%
# Valid Loss: 2.7137 | Valid Acc: 59.23%
# [Epoch 272/300]
# Train Loss: 2.3716 | Train Acc: 95.34%
# Valid Loss: 2.7172 | Valid Acc: 59.23%
# [Epoch 273/300]
# Train Loss: 2.3682 | Train Acc: 95.62%
# Valid Loss: 2.7181 | Valid Acc: 59.04%
# [Epoch 274/300]
# Train Loss: 2.3700 | Train Acc: 95.53%
# Valid Loss: 2.7261 | Valid Acc: 57.12%
# [Epoch 275/300]
# Train Loss: 2.3713 | Train Acc: 95.34%
# Valid Loss: 2.7272 | Valid Acc: 57.50%
# [Epoch 276/300]
# Train Loss: 2.3742 | Train Acc: 95.19%
# Valid Loss: 2.7258 | Valid Acc: 57.88%
# [Epoch 277/300]
# Train Loss: 2.3698 | Train Acc: 95.53%
# Valid Loss: 2.7218 | Valid Acc: 57.50%
# [Epoch 278/300]
# Train Loss: 2.3705 | Train Acc: 95.48%
# Valid Loss: 2.7171 | Valid Acc: 58.65%
# [Epoch 279/300]
# Train Loss: 2.3721 | Train Acc: 95.38%
# Valid Loss: 2.7175 | Valid Acc: 58.46%
# [Epoch 280/300]
# Train Loss: 2.3696 | Train Acc: 95.62%
# Valid Loss: 2.7168 | Valid Acc: 58.27%
# [Epoch 281/300]
# Train Loss: 2.3707 | Train Acc: 95.38%
# Valid Loss: 2.7216 | Valid Acc: 57.31%
# [Epoch 282/300]
# Train Loss: 2.3705 | Train Acc: 95.43%
# Valid Loss: 2.7259 | Valid Acc: 58.08%
# [Epoch 283/300]
# Train Loss: 2.3706 | Train Acc: 95.43%
# Valid Loss: 2.7146 | Valid Acc: 58.85%
# [Epoch 284/300]
# Train Loss: 2.3711 | Train Acc: 95.29%
# Valid Loss: 2.7104 | Valid Acc: 59.81%
# [Epoch 285/300]
# Train Loss: 2.3685 | Train Acc: 95.62%
# Valid Loss: 2.7104 | Valid Acc: 60.00%
# [Epoch 286/300]
# Train Loss: 2.3704 | Train Acc: 95.34%
# Valid Loss: 2.7126 | Valid Acc: 59.04%
# [Epoch 287/300]
# Train Loss: 2.3724 | Train Acc: 95.19%
# Valid Loss: 2.7189 | Valid Acc: 58.65%
# [Epoch 288/300]
# Train Loss: 2.3722 | Train Acc: 95.29%
# Valid Loss: 2.7183 | Valid Acc: 59.42%
# [Epoch 289/300]
# Train Loss: 2.3698 | Train Acc: 95.53%
# Valid Loss: 2.7047 | Valid Acc: 59.62%
# [Epoch 290/300]
# Train Loss: 2.3709 | Train Acc: 95.29%
# Valid Loss: 2.7205 | Valid Acc: 58.08%
# [Epoch 291/300]
# Train Loss: 2.3712 | Train Acc: 95.38%
# Valid Loss: 2.7145 | Valid Acc: 59.23%
# [Epoch 292/300]
# Train Loss: 2.3688 | Train Acc: 95.67%
# Valid Loss: 2.7240 | Valid Acc: 57.50%
# [Epoch 293/300]
# Train Loss: 2.3730 | Train Acc: 95.19%
# Valid Loss: 2.7242 | Valid Acc: 57.69%
# [Epoch 294/300]
# Train Loss: 2.3702 | Train Acc: 95.48%
# Valid Loss: 2.7081 | Valid Acc: 60.58%
# [Epoch 295/300]
# Train Loss: 2.3700 | Train Acc: 95.58%
# Valid Loss: 2.7210 | Valid Acc: 58.65%
# [Epoch 296/300]
# Train Loss: 2.3685 | Train Acc: 95.53%
# Valid Loss: 2.7173 | Valid Acc: 58.85%
# [Epoch 297/300]
# Train Loss: 2.3687 | Train Acc: 95.48%
# Valid Loss: 2.7240 | Valid Acc: 57.12%
# [Epoch 298/300]
# Train Loss: 2.3713 | Train Acc: 95.29%
# Valid Loss: 2.7182 | Valid Acc: 59.23%
# [Epoch 299/300]
# Train Loss: 2.3686 | Train Acc: 95.67%
# Valid Loss: 2.7117 | Valid Acc: 59.42%
# [Epoch 300/300]
# Train Loss: 2.3699 | Train Acc: 95.53%
# Valid Loss: 2.7036 | Valid Acc: 60.58%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.style.use('tableau-colorblind10')

# Plot training & validation loss
plt.subplot(1, 2, 1)
plt.plot(history["train_loss"], label="Training Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot([v * 100 for v in history["train_acc"]], label="Training Accuracy")
plt.plot([v * 100 for v in history["val_acc"]], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()

plt.suptitle("Training Progress (Loss & Accuracy)")
plt.tight_layout()
plt.show()

# %%
def evaluate_on_loader(test_loader, name="test"):
    diffe.eval()
    labels = np.arange(0, 26)
    Y, Y_hat = [], []
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.type(torch.LongTensor).to(device)
            y_cat = F.one_hot(y, num_classes=26).type(torch.FloatTensor).to(device)

            x_hat, down, up, noise, t = ddpm(x)

            # Align the temporal dimension of x_hat and x
            #x_hat, x = safe_align_2d(x_hat, x)

            #ddpm_out = x_hat, down, up, t
            #ddpm_out = x, down, up, t
            #decoder_out, fc_out = diffe(x, ddpm_out)

            # EMA update
            #fc_ema.update()
            #print(decoder_out.shape)
            #X_eegnet = decoder_out.view(decoder_out.size(0), 64, -1)  # (samples, 64, 396)
            X_eegnet = x.view(x.size(0), 64, -1)
            #print(X_eegnet.shape)
            outputs = eegnet_model(X_eegnet)

            #encoder_out = diffe.encoder(x)
            #y_hat = diffe.fc(encoder_out[1])
            y_hat = F.softmax(outputs, dim=1)

            Y.append(y.detach().cpu())
            Y_hat.append(y_hat.detach().cpu())

    Y = torch.cat(Y, dim=0).numpy()
    Y_hat = torch.cat(Y_hat, dim=0).numpy()

    accuracy = top_k_accuracy_score(Y, Y_hat, k=1, labels=labels)
    print(f" {name} Accuracy: {accuracy:.2%}")
    return accuracy

# %% [markdown]
# #Evaluate on test data

# %%
acc1 = evaluate_on_loader(test1_loader, name="Test1 (Seen Subject)")
acc2 = evaluate_on_loader(test2_loader, name="Test2 (Unseen Subject)")

# %%
if USE_WANDB:
    run.finish()
